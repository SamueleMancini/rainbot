# %%
import shutil
import os
# Path to the segmented directory
segmented_root = os.path.join("..", "datasets", "segmented")

# Loop through each segment type
for segment_type in os.listdir(segmented_root):
    segment_type_path = os.path.join(segmented_root, segment_type)
    if not os.path.isdir(segment_type_path):
        continue

    # Loop through each country in the segment type
    for country in os.listdir(segment_type_path):
        country_path = os.path.join(segment_type_path, country)
        if not os.path.isdir(country_path):
            continue

        # Move files from train and val to country root
        for split in ['train', 'val']:
            split_path = os.path.join(country_path, split)
            if os.path.isdir(split_path):
                # Move all files from split directory to country directory
                for file in os.listdir(split_path):
                    src = os.path.join(split_path, file)
                    dst = os.path.join(country_path, file)
                    shutil.move(src, dst)
                
                # Remove the now empty split directory
                os.rmdir(split_path)

print("Files have been moved successfully!")
# Out:
# Files have been moved successfully!

# %%
import os
from collections import defaultdict

# Path to the segmented directory (adjust if running from a different location)
segmented_root = os.path.join("..", "datasets", "segmented")

# Dictionary to store results
segment_type_country_counts = {}
segment_type_country_image_counts = {}

# Loop through each segment type (e.g., 'bicycle', etc.)
for segment_type in os.listdir(segmented_root):
    segment_type_path = os.path.join(segmented_root, segment_type)
    if not os.path.isdir(segment_type_path):
        continue

    countries = []
    country_image_counts = defaultdict(int)

    # Loop through each country in the segment type
    for country in os.listdir(segment_type_path):
        country_path = os.path.join(segment_type_path, country)
        if not os.path.isdir(country_path):
            continue
        countries.append(country)

        # Count images directly in country folder
        num_images = len([
            f for f in os.listdir(country_path)
            if os.path.isfile(os.path.join(country_path, f))
        ])
        country_image_counts[country] = num_images

    segment_type_country_counts[segment_type] = len(countries)
    segment_type_country_image_counts[segment_type] = dict(country_image_counts)

# Print results
for segment_type in segment_type_country_counts:
    print(f"Segment type: {segment_type}")
    print(f"  Number of countries: {segment_type_country_counts[segment_type]}")
    print(f"  Images per country:")
    for country, count in segment_type_country_image_counts[segment_type].items():
        print(f"    {country}: {count}")
    print()
# Out:
# Segment type: terrain
#   Number of countries: 79
#   Images per country:
#     Montenegro: 376
#     Ukraine: 366
#     Germany: 351
#     Australia: 387
#     Kenya: 392
#     Belgium: 371
#     Ecuador: 311
#     Bulgaria: 382
#     Hungary: 390
#     Italy: 337
#     Canada: 395
#     Russia: 382
#     Peru: 345
#     Bolivia: 304
#     Ghana: 364
#     Indonesia: 357
#     Jordan: 283
#     Botswana: 395
#     Slovakia: 381
#     New Zealand: 390
#     Taiwan: 355
#     Luxembourg: 360
#     United States: 381
#     Portugal: 369
#     South Korea: 293
#     Sri Lanka: 355
#     Bangladesh: 351
#     Estonia: 394
#     Bhutan: 386
#     Argentina: 366
#     Guatemala: 335
#     Finland: 397
#     Mexico: 317
#     Czechia: 381
#     Mongolia: 357
#     Greece: 338
#     Singapore: 385
#     Austria: 287
#     United Arab Emirates: 322
#     Romania: 372
#     South Africa: 383
#     Poland: 386
#     Albania: 334
#     Netherlands: 377
#     Uruguay: 372
#     Iceland: 391
#     Kyrgyzstan: 375
#     Switzerland: 366
#     Sweden: 391
#     Nigeria: 369
#     Colombia: 345
#     France: 326
#     Turkey: 334
#     Ireland: 370
#     North Macedonia: 360
#     Israel: 289
#     Japan: 334
#     Dominican Republic: 291
#     Lesotho: 403
#     Greenland: 370
#     Latvia: 396
#     Denmark: 376
#     Serbia: 372
#     Eswatini: 405
#     Norway: 384
#     United Kingdom: 345
#     Thailand: 379
#     Chile: 348
#     Cambodia: 385
#     Brazil: 326
#     Palestine: 367
#     Spain: 322
#     Senegal: 283
#     Slovenia: 379
#     Lithuania: 395
#     Croatia: 378
#     Malaysia: 390
#     Philippines: 318
#     Andorra: 349
#
# Segment type: road
#   Number of countries: 79
#   Images per country:
#     Montenegro: 404
#     Ukraine: 383
#     Germany: 403
#     Australia: 402
#     Kenya: 401
#     Belgium: 398
#     Ecuador: 405
#     Bulgaria: 397
#     Hungary: 383
#     Italy: 400
#     Canada: 403
#     Russia: 404
#     Peru: 401
#     Bolivia: 404
#     Ghana: 404
#     Indonesia: 398
#     Jordan: 405
#     Botswana: 388
#     Slovakia: 377
#     New Zealand: 401
#     Taiwan: 402
#     Luxembourg: 405
#     United States: 405
#     Portugal: 393
#     South Korea: 401
#     Sri Lanka: 402
#     Bangladesh: 389
#     Estonia: 342
#     Bhutan: 366
#     Argentina: 401
#     Guatemala: 404
#     Finland: 400
#     Mexico: 400
#     Czechia: 403
#     Mongolia: 405
#     Greece: 399
#     Singapore: 403
#     Austria: 404
#     United Arab Emirates: 394
#     Romania: 382
#     South Africa: 402
#     Poland: 396
#     Albania: 404
#     Netherlands: 396
#     Uruguay: 405
#     Iceland: 380
#     Kyrgyzstan: 405
#     Switzerland: 397
#     Sweden: 399
#     Nigeria: 403
#     Colombia: 392
#     France: 405
#     Turkey: 404
#     Ireland: 392
#     North Macedonia: 404
#     Israel: 397
#     Japan: 405
#     Dominican Republic: 405
#     Lesotho: 405
#     Greenland: 405
#     Latvia: 381
#     Denmark: 393
#     Serbia: 405
#     Eswatini: 368
#     Norway: 402
#     United Kingdom: 404
#     Thailand: 396
#     Chile: 392
#     Cambodia: 372
#     Brazil: 402
#     Palestine: 405
#     Spain: 401
#     Senegal: 404
#     Slovenia: 367
#     Lithuania: 379
#     Croatia: 378
#     Malaysia: 397
#     Philippines: 396
#     Andorra: 389
#
# Segment type: bus
#   Number of countries: 79
#   Images per country:
#     Montenegro: 46
#     Ukraine: 29
#     Germany: 33
#     Australia: 48
#     Kenya: 50
#     Belgium: 22
#     Ecuador: 96
#     Bulgaria: 13
#     Hungary: 16
#     Italy: 19
#     Canada: 30
#     Russia: 40
#     Peru: 25
#     Bolivia: 50
#     Ghana: 94
#     Indonesia: 41
#     Jordan: 54
#     Botswana: 20
#     Slovakia: 34
#     New Zealand: 56
#     Taiwan: 51
#     Luxembourg: 39
#     United States: 30
#     Portugal: 22
#     South Korea: 49
#     Sri Lanka: 48
#     Bangladesh: 81
#     Estonia: 13
#     Bhutan: 9
#     Argentina: 36
#     Guatemala: 86
#     Finland: 32
#     Mexico: 50
#     Czechia: 22
#     Mongolia: 64
#     Greece: 11
#     Singapore: 77
#     Austria: 34
#     United Arab Emirates: 36
#     Romania: 24
#     South Africa: 31
#     Poland: 31
#     Albania: 44
#     Netherlands: 35
#     Uruguay: 48
#     Iceland: 30
#     Kyrgyzstan: 66
#     Switzerland: 38
#     Sweden: 27
#     Nigeria: 36
#     Colombia: 51
#     France: 25
#     Turkey: 51
#     Ireland: 32
#     North Macedonia: 55
#     Israel: 17
#     Japan: 41
#     Dominican Republic: 63
#     Lesotho: 51
#     Greenland: 129
#     Latvia: 15
#     Denmark: 40
#     Serbia: 46
#     Eswatini: 14
#     Norway: 43
#     United Kingdom: 38
#     Thailand: 58
#     Chile: 29
#     Cambodia: 17
#     Brazil: 33
#     Palestine: 15
#     Spain: 31
#     Senegal: 24
#     Slovenia: 21
#     Lithuania: 14
#     Croatia: 17
#     Malaysia: 36
#     Philippines: 54
#     Andorra: 18
#
# Segment type: train
#   Number of countries: 79
#   Images per country:
#     Montenegro: 43
#     Ukraine: 22
#     Germany: 42
#     Australia: 65
#     Kenya: 44
#     Belgium: 39
#     Ecuador: 153
#     Bulgaria: 17
#     Hungary: 40
#     Italy: 25
#     Canada: 37
#     Russia: 52
#     Peru: 64
#     Bolivia: 133
#     Ghana: 80
#     Indonesia: 77
#     Jordan: 82
#     Botswana: 26
#     Slovakia: 53
#     New Zealand: 50
#     Taiwan: 54
#     Luxembourg: 41
#     United States: 29
#     Portugal: 37
#     South Korea: 90
#     Sri Lanka: 54
#     Bangladesh: 43
#     Estonia: 6
#     Bhutan: 7
#     Argentina: 54
#     Guatemala: 160
#     Finland: 25
#     Mexico: 94
#     Czechia: 27
#     Mongolia: 117
#     Greece: 33
#     Singapore: 50
#     Austria: 42
#     United Arab Emirates: 32
#     Romania: 42
#     South Africa: 53
#     Poland: 24
#     Albania: 79
#     Netherlands: 43
#     Uruguay: 111
#     Iceland: 30
#     Kyrgyzstan: 104
#     Switzerland: 24
#     Sweden: 24
#     Nigeria: 47
#     Colombia: 96
#     France: 35
#     Turkey: 32
#     Ireland: 23
#     North Macedonia: 75
#     Israel: 41
#     Japan: 66
#     Dominican Republic: 206
#     Lesotho: 32
#     Greenland: 80
#     Latvia: 18
#     Denmark: 33
#     Serbia: 41
#     Eswatini: 22
#     Norway: 32
#     United Kingdom: 52
#     Thailand: 48
#     Chile: 79
#     Cambodia: 19
#     Brazil: 82
#     Palestine: 23
#     Spain: 44
#     Senegal: 66
#     Slovenia: 15
#     Lithuania: 12
#     Croatia: 22
#     Malaysia: 56
#     Philippines: 61
#     Andorra: 16
#
# Segment type: car
#   Number of countries: 79
#   Images per country:
#     Montenegro: 331
#     Ukraine: 280
#     Germany: 367
#     Australia: 311
#     Kenya: 308
#     Belgium: 286
#     Ecuador: 354
#     Bulgaria: 196
#     Hungary: 210
#     Italy: 263
#     Canada: 327
#     Russia: 285
#     Peru: 258
#     Bolivia: 328
#     Ghana: 344
#     Indonesia: 295
#     Jordan: 365
#     Botswana: 184
#     Slovakia: 240
#     New Zealand: 285
#     Taiwan: 295
#     Luxembourg: 329
#     United States: 338
#     Portugal: 234
#     South Korea: 335
#     Sri Lanka: 293
#     Bangladesh: 269
#     Estonia: 144
#     Bhutan: 180
#     Argentina: 257
#     Guatemala: 365
#     Finland: 238
#     Mexico: 286
#     Czechia: 246
#     Mongolia: 339
#     Greece: 243
#     Singapore: 303
#     Austria: 355
#     United Arab Emirates: 250
#     Romania: 227
#     South Africa: 268
#     Poland: 263
#     Albania: 325
#     Netherlands: 344
#     Uruguay: 317
#     Iceland: 270
#     Kyrgyzstan: 348
#     Switzerland: 284
#     Sweden: 244
#     Nigeria: 276
#     Colombia: 279
#     France: 311
#     Turkey: 277
#     Ireland: 259
#     North Macedonia: 352
#     Israel: 317
#     Japan: 274
#     Dominican Republic: 368
#     Lesotho: 329
#     Greenland: 381
#     Latvia: 168
#     Denmark: 262
#     Serbia: 352
#     Eswatini: 171
#     Norway: 268
#     United Kingdom: 340
#     Thailand: 251
#     Chile: 248
#     Cambodia: 202
#     Brazil: 272
#     Palestine: 261
#     Spain: 288
#     Senegal: 323
#     Slovenia: 223
#     Lithuania: 226
#     Croatia: 225
#     Malaysia: 289
#     Philippines: 289
#     Andorra: 221
#
# Segment type: building
#   Number of countries: 79
#   Images per country:
#     Montenegro: 358
#     Ukraine: 378
#     Germany: 391
#     Australia: 383
#     Kenya: 320
#     Belgium: 379
#     Ecuador: 390
#     Bulgaria: 319
#     Hungary: 330
#     Italy: 352
#     Canada: 365
#     Russia: 372
#     Peru: 374
#     Bolivia: 389
#     Ghana: 355
#     Indonesia: 378
#     Jordan: 400
#     Botswana: 250
#     Slovakia: 328
#     New Zealand: 342
#     Taiwan: 373
#     Luxembourg: 336
#     United States: 383
#     Portugal: 326
#     South Korea: 385
#     Sri Lanka: 377
#     Bangladesh: 372
#     Estonia: 228
#     Bhutan: 235
#     Argentina: 341
#     Guatemala: 388
#     Finland: 296
#     Mexico: 372
#     Czechia: 333
#     Mongolia: 369
#     Greece: 335
#     Singapore: 402
#     Austria: 387
#     United Arab Emirates: 378
#     Romania: 356
#     South Africa: 361
#     Poland: 373
#     Albania: 389
#     Netherlands: 382
#     Uruguay: 378
#     Iceland: 330
#     Kyrgyzstan: 391
#     Switzerland: 348
#     Sweden: 302
#     Nigeria: 329
#     Colombia: 358
#     France: 396
#     Turkey: 345
#     Ireland: 310
#     North Macedonia: 379
#     Israel: 388
#     Japan: 394
#     Dominican Republic: 405
#     Lesotho: 377
#     Greenland: 380
#     Latvia: 231
#     Denmark: 309
#     Serbia: 384
#     Eswatini: 272
#     Norway: 317
#     United Kingdom: 394
#     Thailand: 351
#     Chile: 370
#     Cambodia: 303
#     Brazil: 384
#     Palestine: 357
#     Spain: 375
#     Senegal: 361
#     Slovenia: 288
#     Lithuania: 282
#     Croatia: 316
#     Malaysia: 346
#     Philippines: 358
#     Andorra: 333
#
# Segment type: pole
#   Number of countries: 79
#   Images per country:
#     Montenegro: 331
#     Ukraine: 354
#     Germany: 367
#     Australia: 349
#     Kenya: 270
#     Belgium: 360
#     Ecuador: 353
#     Bulgaria: 265
#     Hungary: 309
#     Italy: 349
#     Canada: 354
#     Russia: 361
#     Peru: 305
#     Bolivia: 363
#     Ghana: 327
#     Indonesia: 359
#     Jordan: 374
#     Botswana: 243
#     Slovakia: 311
#     New Zealand: 321
#     Taiwan: 371
#     Luxembourg: 304
#     United States: 354
#     Portugal: 328
#     South Korea: 369
#     Sri Lanka: 347
#     Bangladesh: 349
#     Estonia: 231
#     Bhutan: 203
#     Argentina: 278
#     Guatemala: 369
#     Finland: 347
#     Mexico: 368
#     Czechia: 318
#     Mongolia: 298
#     Greece: 296
#     Singapore: 392
#     Austria: 342
#     United Arab Emirates: 306
#     Romania: 342
#     South Africa: 313
#     Poland: 353
#     Albania: 365
#     Netherlands: 362
#     Uruguay: 358
#     Iceland: 192
#     Kyrgyzstan: 365
#     Switzerland: 328
#     Sweden: 327
#     Nigeria: 269
#     Colombia: 362
#     France: 363
#     Turkey: 318
#     Ireland: 305
#     North Macedonia: 358
#     Israel: 374
#     Japan: 376
#     Dominican Republic: 389
#     Lesotho: 316
#     Greenland: 289
#     Latvia: 277
#     Denmark: 266
#     Serbia: 362
#     Eswatini: 281
#     Norway: 329
#     United Kingdom: 351
#     Thailand: 364
#     Chile: 352
#     Cambodia: 314
#     Brazil: 365
#     Palestine: 312
#     Spain: 341
#     Senegal: 293
#     Slovenia: 287
#     Lithuania: 291
#     Croatia: 308
#     Malaysia: 367
#     Philippines: 341
#     Andorra: 289
#
# Segment type: vegetation
#   Number of countries: 79
#   Images per country:
#     Montenegro: 403
#     Ukraine: 402
#     Germany: 403
#     Australia: 404
#     Kenya: 402
#     Belgium: 396
#     Ecuador: 396
#     Bulgaria: 402
#     Hungary: 404
#     Italy: 400
#     Canada: 404
#     Russia: 401
#     Peru: 393
#     Bolivia: 398
#     Ghana: 403
#     Indonesia: 402
#     Jordan: 396
#     Botswana: 400
#     Slovakia: 400
#     New Zealand: 403
#     Taiwan: 402
#     Luxembourg: 400
#     United States: 404
#     Portugal: 399
#     South Korea: 389
#     Sri Lanka: 404
#     Bangladesh: 401
#     Estonia: 403
#     Bhutan: 404
#     Argentina: 397
#     Guatemala: 404
#     Finland: 405
#     Mexico: 399
#     Czechia: 401
#     Mongolia: 394
#     Greece: 398
#     Singapore: 404
#     Austria: 373
#     United Arab Emirates: 359
#     Romania: 404
#     South Africa: 403
#     Poland: 400
#     Albania: 404
#     Netherlands: 405
#     Uruguay: 403
#     Iceland: 374
#     Kyrgyzstan: 405
#     Switzerland: 401
#     Sweden: 404
#     Nigeria: 388
#     Colombia: 401
#     France: 403
#     Turkey: 387
#     Ireland: 404
#     North Macedonia: 403
#     Israel: 401
#     Japan: 400
#     Dominican Republic: 404
#     Lesotho: 404
#     Greenland: 398
#     Latvia: 405
#     Denmark: 398
#     Serbia: 404
#     Eswatini: 403
#     Norway: 405
#     United Kingdom: 403
#     Thailand: 405
#     Chile: 403
#     Cambodia: 405
#     Brazil: 405
#     Palestine: 399
#     Spain: 398
#     Senegal: 398
#     Slovenia: 403
#     Lithuania: 397
#     Croatia: 399
#     Malaysia: 405
#     Philippines: 401
#     Andorra: 401
#
# Segment type: rider
#   Number of countries: 79
#   Images per country:
#     Montenegro: 13
#     Ukraine: 30
#     Germany: 107
#     Australia: 45
#     Kenya: 56
#     Belgium: 22
#     Ecuador: 23
#     Bulgaria: 10
#     Hungary: 21
#     Italy: 25
#     Canada: 30
#     Russia: 25
#     Peru: 39
#     Bolivia: 36
#     Ghana: 66
#     Indonesia: 94
#     Jordan: 30
#     Botswana: 12
#     Slovakia: 21
#     New Zealand: 18
#     Taiwan: 33
#     Luxembourg: 10
#     United States: 31
#     Portugal: 12
#     South Korea: 57
#     Sri Lanka: 29
#     Bangladesh: 114
#     Estonia: 3
#     Bhutan: 16
#     Argentina: 33
#     Guatemala: 51
#     Finland: 23
#     Mexico: 35
#     Czechia: 22
#     Mongolia: 47
#     Greece: 23
#     Singapore: 22
#     Austria: 47
#     United Arab Emirates: 28
#     Romania: 24
#     South Africa: 23
#     Poland: 20
#     Albania: 37
#     Netherlands: 29
#     Uruguay: 26
#     Iceland: 9
#     Kyrgyzstan: 28
#     Switzerland: 28
#     Sweden: 37
#     Nigeria: 55
#     Colombia: 50
#     France: 41
#     Turkey: 25
#     Ireland: 28
#     North Macedonia: 35
#     Israel: 55
#     Japan: 10
#     Dominican Republic: 38
#     Lesotho: 20
#     Greenland: 27
#     Latvia: 14
#     Denmark: 17
#     Serbia: 33
#     Eswatini: 13
#     Norway: 20
#     United Kingdom: 42
#     Thailand: 39
#     Chile: 30
#     Cambodia: 47
#     Brazil: 34
#     Palestine: 7
#     Spain: 23
#     Senegal: 50
#     Slovenia: 10
#     Lithuania: 15
#     Croatia: 13
#     Malaysia: 38
#     Philippines: 114
#     Andorra: 20
#
# Segment type: traffic_light
#   Number of countries: 79
#   Images per country:
#     Montenegro: 63
#     Ukraine: 73
#     Germany: 78
#     Australia: 74
#     Kenya: 60
#     Belgium: 69
#     Ecuador: 141
#     Bulgaria: 35
#     Hungary: 55
#     Italy: 51
#     Canada: 66
#     Russia: 101
#     Peru: 97
#     Bolivia: 111
#     Ghana: 79
#     Indonesia: 51
#     Jordan: 167
#     Botswana: 31
#     Slovakia: 66
#     New Zealand: 60
#     Taiwan: 103
#     Luxembourg: 59
#     United States: 55
#     Portugal: 62
#     South Korea: 140
#     Sri Lanka: 53
#     Bangladesh: 71
#     Estonia: 23
#     Bhutan: 17
#     Argentina: 69
#     Guatemala: 130
#     Finland: 53
#     Mexico: 93
#     Czechia: 57
#     Mongolia: 85
#     Greece: 49
#     Singapore: 80
#     Austria: 93
#     United Arab Emirates: 91
#     Romania: 62
#     South Africa: 54
#     Poland: 64
#     Albania: 109
#     Netherlands: 82
#     Uruguay: 123
#     Iceland: 46
#     Kyrgyzstan: 117
#     Switzerland: 54
#     Sweden: 54
#     Nigeria: 55
#     Colombia: 91
#     France: 66
#     Turkey: 70
#     Ireland: 70
#     North Macedonia: 83
#     Israel: 93
#     Japan: 85
#     Dominican Republic: 155
#     Lesotho: 50
#     Greenland: 113
#     Latvia: 30
#     Denmark: 51
#     Serbia: 90
#     Eswatini: 49
#     Norway: 51
#     United Kingdom: 81
#     Thailand: 69
#     Chile: 57
#     Cambodia: 41
#     Brazil: 88
#     Palestine: 72
#     Spain: 73
#     Senegal: 64
#     Slovenia: 34
#     Lithuania: 49
#     Croatia: 51
#     Malaysia: 76
#     Philippines: 82
#     Andorra: 43
#
# Segment type: bicycle
#   Number of countries: 79
#   Images per country:
#     Montenegro: 50
#     Ukraine: 74
#     Germany: 167
#     Australia: 69
#     Kenya: 82
#     Belgium: 53
#     Ecuador: 101
#     Bulgaria: 49
#     Hungary: 39
#     Italy: 60
#     Canada: 62
#     Russia: 50
#     Peru: 99
#     Bolivia: 103
#     Ghana: 138
#     Indonesia: 173
#     Jordan: 107
#     Botswana: 31
#     Slovakia: 38
#     New Zealand: 35
#     Taiwan: 92
#     Luxembourg: 54
#     United States: 67
#     Portugal: 46
#     South Korea: 133
#     Sri Lanka: 70
#     Bangladesh: 191
#     Estonia: 10
#     Bhutan: 53
#     Argentina: 71
#     Guatemala: 110
#     Finland: 47
#     Mexico: 76
#     Czechia: 54
#     Mongolia: 69
#     Greece: 84
#     Singapore: 100
#     Austria: 104
#     United Arab Emirates: 68
#     Romania: 36
#     South Africa: 61
#     Poland: 43
#     Albania: 87
#     Netherlands: 96
#     Uruguay: 89
#     Iceland: 20
#     Kyrgyzstan: 62
#     Switzerland: 51
#     Sweden: 57
#     Nigeria: 72
#     Colombia: 122
#     France: 81
#     Turkey: 67
#     Ireland: 49
#     North Macedonia: 82
#     Israel: 112
#     Japan: 87
#     Dominican Republic: 117
#     Lesotho: 62
#     Greenland: 105
#     Latvia: 17
#     Denmark: 27
#     Serbia: 82
#     Eswatini: 30
#     Norway: 34
#     United Kingdom: 71
#     Thailand: 89
#     Chile: 72
#     Cambodia: 103
#     Brazil: 77
#     Palestine: 45
#     Spain: 69
#     Senegal: 128
#     Slovenia: 41
#     Lithuania: 36
#     Croatia: 41
#     Malaysia: 98
#     Philippines: 153
#     Andorra: 74
#
# Segment type: fence
#   Number of countries: 79
#   Images per country:
#     Montenegro: 273
#     Ukraine: 283
#     Germany: 322
#     Australia: 305
#     Kenya: 214
#     Belgium: 267
#     Ecuador: 348
#     Bulgaria: 204
#     Hungary: 276
#     Italy: 307
#     Canada: 242
#     Russia: 310
#     Peru: 268
#     Bolivia: 338
#     Ghana: 290
#     Indonesia: 335
#     Jordan: 354
#     Botswana: 159
#     Slovakia: 274
#     New Zealand: 245
#     Taiwan: 310
#     Luxembourg: 250
#     United States: 260
#     Portugal: 231
#     South Korea: 348
#     Sri Lanka: 306
#     Bangladesh: 317
#     Estonia: 128
#     Bhutan: 127
#     Argentina: 226
#     Guatemala: 325
#     Finland: 248
#     Mexico: 321
#     Czechia: 260
#     Mongolia: 293
#     Greece: 227
#     Singapore: 377
#     Austria: 285
#     United Arab Emirates: 310
#     Romania: 300
#     South Africa: 286
#     Poland: 303
#     Albania: 328
#     Netherlands: 302
#     Uruguay: 330
#     Iceland: 132
#     Kyrgyzstan: 346
#     Switzerland: 268
#     Sweden: 245
#     Nigeria: 224
#     Colombia: 312
#     France: 364
#     Turkey: 246
#     Ireland: 186
#     North Macedonia: 317
#     Israel: 349
#     Japan: 371
#     Dominican Republic: 384
#     Lesotho: 265
#     Greenland: 269
#     Latvia: 142
#     Denmark: 176
#     Serbia: 319
#     Eswatini: 140
#     Norway: 228
#     United Kingdom: 331
#     Thailand: 271
#     Chile: 310
#     Cambodia: 227
#     Brazil: 351
#     Palestine: 218
#     Spain: 286
#     Senegal: 291
#     Slovenia: 186
#     Lithuania: 185
#     Croatia: 211
#     Malaysia: 297
#     Philippines: 305
#     Andorra: 248
#
# Segment type: person
#   Number of countries: 79
#   Images per country:
#     Montenegro: 177
#     Ukraine: 178
#     Germany: 165
#     Australia: 196
#     Kenya: 176
#     Belgium: 177
#     Ecuador: 228
#     Bulgaria: 101
#     Hungary: 117
#     Italy: 152
#     Canada: 214
#     Russia: 191
#     Peru: 185
#     Bolivia: 232
#     Ghana: 235
#     Indonesia: 248
#     Jordan: 251
#     Botswana: 87
#     Slovakia: 142
#     New Zealand: 136
#     Taiwan: 206
#     Luxembourg: 129
#     United States: 195
#     Portugal: 121
#     South Korea: 245
#     Sri Lanka: 160
#     Bangladesh: 254
#     Estonia: 66
#     Bhutan: 83
#     Argentina: 154
#     Guatemala: 265
#     Finland: 132
#     Mexico: 201
#     Czechia: 152
#     Mongolia: 213
#     Greece: 161
#     Singapore: 206
#     Austria: 189
#     United Arab Emirates: 176
#     Romania: 143
#     South Africa: 181
#     Poland: 168
#     Albania: 216
#     Netherlands: 202
#     Uruguay: 232
#     Iceland: 54
#     Kyrgyzstan: 210
#     Switzerland: 156
#     Sweden: 147
#     Nigeria: 169
#     Colombia: 197
#     France: 183
#     Turkey: 174
#     Ireland: 170
#     North Macedonia: 216
#     Israel: 211
#     Japan: 193
#     Dominican Republic: 258
#     Lesotho: 165
#     Greenland: 181
#     Latvia: 92
#     Denmark: 125
#     Serbia: 217
#     Eswatini: 77
#     Norway: 128
#     United Kingdom: 192
#     Thailand: 189
#     Chile: 181
#     Cambodia: 156
#     Brazil: 183
#     Palestine: 103
#     Spain: 187
#     Senegal: 194
#     Slovenia: 110
#     Lithuania: 132
#     Croatia: 142
#     Malaysia: 187
#     Philippines: 231
#     Andorra: 119
#
# Segment type: truck
#   Number of countries: 79
#   Images per country:
#     Montenegro: 54
#     Ukraine: 47
#     Germany: 81
#     Australia: 55
#     Kenya: 46
#     Belgium: 29
#     Ecuador: 74
#     Bulgaria: 25
#     Hungary: 21
#     Italy: 33
#     Canada: 53
#     Russia: 64
#     Peru: 60
#     Bolivia: 68
#     Ghana: 94
#     Indonesia: 73
#     Jordan: 111
#     Botswana: 27
#     Slovakia: 46
#     New Zealand: 33
#     Taiwan: 75
#     Luxembourg: 35
#     United States: 48
#     Portugal: 26
#     South Korea: 119
#     Sri Lanka: 44
#     Bangladesh: 83
#     Estonia: 22
#     Bhutan: 20
#     Argentina: 41
#     Guatemala: 117
#     Finland: 35
#     Mexico: 84
#     Czechia: 36
#     Mongolia: 63
#     Greece: 33
#     Singapore: 75
#     Austria: 63
#     United Arab Emirates: 55
#     Romania: 36
#     South Africa: 30
#     Poland: 39
#     Albania: 60
#     Netherlands: 59
#     Uruguay: 53
#     Iceland: 23
#     Kyrgyzstan: 62
#     Switzerland: 61
#     Sweden: 23
#     Nigeria: 57
#     Colombia: 63
#     France: 48
#     Turkey: 65
#     Ireland: 22
#     North Macedonia: 55
#     Israel: 55
#     Japan: 68
#     Dominican Republic: 112
#     Lesotho: 30
#     Greenland: 117
#     Latvia: 21
#     Denmark: 35
#     Serbia: 50
#     Eswatini: 27
#     Norway: 43
#     United Kingdom: 40
#     Thailand: 61
#     Chile: 48
#     Cambodia: 30
#     Brazil: 57
#     Palestine: 41
#     Spain: 59
#     Senegal: 56
#     Slovenia: 32
#     Lithuania: 16
#     Croatia: 33
#     Malaysia: 55
#     Philippines: 100
#     Andorra: 37
#
# Segment type: sidewalk
#   Number of countries: 79
#   Images per country:
#     Montenegro: 317
#     Ukraine: 362
#     Germany: 389
#     Australia: 377
#     Kenya: 289
#     Belgium: 348
#     Ecuador: 371
#     Bulgaria: 276
#     Hungary: 321
#     Italy: 354
#     Canada: 374
#     Russia: 352
#     Peru: 357
#     Bolivia: 386
#     Ghana: 333
#     Indonesia: 371
#     Jordan: 401
#     Botswana: 325
#     Slovakia: 283
#     New Zealand: 293
#     Taiwan: 337
#     Luxembourg: 324
#     United States: 383
#     Portugal: 317
#     South Korea: 366
#     Sri Lanka: 336
#     Bangladesh: 362
#     Estonia: 166
#     Bhutan: 226
#     Argentina: 329
#     Guatemala: 359
#     Finland: 301
#     Mexico: 370
#     Czechia: 309
#     Mongolia: 358
#     Greece: 322
#     Singapore: 388
#     Austria: 382
#     United Arab Emirates: 375
#     Romania: 308
#     South Africa: 344
#     Poland: 335
#     Albania: 358
#     Netherlands: 372
#     Uruguay: 343
#     Iceland: 249
#     Kyrgyzstan: 380
#     Switzerland: 344
#     Sweden: 322
#     Nigeria: 306
#     Colombia: 345
#     France: 391
#     Turkey: 357
#     Ireland: 251
#     North Macedonia: 353
#     Israel: 389
#     Japan: 393
#     Dominican Republic: 395
#     Lesotho: 330
#     Greenland: 366
#     Latvia: 219
#     Denmark: 289
#     Serbia: 344
#     Eswatini: 237
#     Norway: 305
#     United Kingdom: 393
#     Thailand: 321
#     Chile: 359
#     Cambodia: 291
#     Brazil: 390
#     Palestine: 385
#     Spain: 344
#     Senegal: 352
#     Slovenia: 235
#     Lithuania: 250
#     Croatia: 280
#     Malaysia: 332
#     Philippines: 336
#     Andorra: 294
#
# Segment type: motorcycle
#   Number of countries: 79
#   Images per country:
#     Montenegro: 39
#     Ukraine: 21
#     Germany: 115
#     Australia: 40
#     Kenya: 48
#     Belgium: 29
#     Ecuador: 28
#     Bulgaria: 20
#     Hungary: 15
#     Italy: 42
#     Canada: 40
#     Russia: 29
#     Peru: 39
#     Bolivia: 57
#     Ghana: 75
#     Indonesia: 116
#     Jordan: 73
#     Botswana: 13
#     Slovakia: 21
#     New Zealand: 21
#     Taiwan: 57
#     Luxembourg: 48
#     United States: 35
#     Portugal: 19
#     South Korea: 74
#     Sri Lanka: 35
#     Bangladesh: 74
#     Estonia: 4
#     Bhutan: 23
#     Argentina: 40
#     Guatemala: 82
#     Finland: 16
#     Mexico: 42
#     Czechia: 15
#     Mongolia: 59
#     Greece: 32
#     Singapore: 49
#     Austria: 66
#     United Arab Emirates: 33
#     Romania: 15
#     South Africa: 25
#     Poland: 17
#     Albania: 64
#     Netherlands: 52
#     Uruguay: 52
#     Iceland: 12
#     Kyrgyzstan: 41
#     Switzerland: 25
#     Sweden: 26
#     Nigeria: 46
#     Colombia: 62
#     France: 44
#     Turkey: 41
#     Ireland: 36
#     North Macedonia: 51
#     Israel: 57
#     Japan: 27
#     Dominican Republic: 65
#     Lesotho: 24
#     Greenland: 34
#     Latvia: 8
#     Denmark: 18
#     Serbia: 64
#     Eswatini: 10
#     Norway: 30
#     United Kingdom: 39
#     Thailand: 44
#     Chile: 28
#     Cambodia: 55
#     Brazil: 37
#     Palestine: 23
#     Spain: 42
#     Senegal: 65
#     Slovenia: 13
#     Lithuania: 17
#     Croatia: 20
#     Malaysia: 47
#     Philippines: 90
#     Andorra: 32
#
# Segment type: traffic_sign
#   Number of countries: 79
#   Images per country:
#     Montenegro: 220
#     Ukraine: 206
#     Germany: 233
#     Australia: 191
#     Kenya: 232
#     Belgium: 214
#     Ecuador: 261
#     Bulgaria: 128
#     Hungary: 163
#     Italy: 205
#     Canada: 214
#     Russia: 250
#     Peru: 188
#     Bolivia: 228
#     Ghana: 279
#     Indonesia: 247
#     Jordan: 249
#     Botswana: 97
#     Slovakia: 180
#     New Zealand: 169
#     Taiwan: 257
#     Luxembourg: 216
#     United States: 209
#     Portugal: 171
#     South Korea: 295
#     Sri Lanka: 248
#     Bangladesh: 215
#     Estonia: 87
#     Bhutan: 79
#     Argentina: 186
#     Guatemala: 301
#     Finland: 162
#     Mexico: 215
#     Czechia: 210
#     Mongolia: 236
#     Greece: 172
#     Singapore: 265
#     Austria: 274
#     United Arab Emirates: 126
#     Romania: 192
#     South Africa: 191
#     Poland: 220
#     Albania: 254
#     Netherlands: 228
#     Uruguay: 232
#     Iceland: 97
#     Kyrgyzstan: 236
#     Switzerland: 199
#     Sweden: 197
#     Nigeria: 195
#     Colombia: 239
#     France: 221
#     Turkey: 193
#     Ireland: 198
#     North Macedonia: 250
#     Israel: 220
#     Japan: 235
#     Dominican Republic: 293
#     Lesotho: 241
#     Greenland: 257
#     Latvia: 111
#     Denmark: 161
#     Serbia: 265
#     Eswatini: 75
#     Norway: 187
#     United Kingdom: 212
#     Thailand: 233
#     Chile: 165
#     Cambodia: 145
#     Brazil: 218
#     Palestine: 131
#     Spain: 207
#     Senegal: 206
#     Slovenia: 136
#     Lithuania: 134
#     Croatia: 158
#     Malaysia: 246
#     Philippines: 274
#     Andorra: 153

# %%
# Find segment types that don't have all 79 countries
missing_countries = {}
for segment_type, country_counts in segment_type_country_counts.items():
    if country_counts < 79:  # 79 is the total number of countries in COUNTRIES list
        missing_countries[segment_type] = country_counts

# Print results
print("Segment types with missing countries:")
for segment_type, count in missing_countries.items():
    print(f"{segment_type}: {count} countries (missing {79 - count} countries)")
# Out:
# Segment types with missing countries:

# %%
# Calculate and print bottom 5 segments with lowest sum of bottom 5 countries
print("Bottom 10 segments with lowest sum of bottom 5 countries:")
print("-" * 50)

# Calculate sum of bottom 5 countries for each segment type
segment_sums = {}
for segment_type in segment_type_country_image_counts:
    sorted_countries = sorted(
        segment_type_country_image_counts[segment_type].items(),
        key=lambda x: x[1]
    )
    bottom_5_sum = sum(count for _, count in sorted_countries[:5])
    segment_sums[segment_type] = bottom_5_sum

# Sort segments by their bottom 5 sum
sorted_segments = sorted(segment_sums.items(), key=lambda x: x[1])

# Print bottom 5 segments
for segment_type, total in sorted_segments[:10]:
    print(f"\n{segment_type}:")
    print(f"  Total images in bottom 5 countries: {total}")
    # Print the individual countries and their counts
    sorted_countries = sorted(
        segment_type_country_image_counts[segment_type].items(),
        key=lambda x: x[1]
    )
    for country, count in sorted_countries[:5]:
        print(f"    {country}: {count} images")
# Out:
# Bottom 10 segments with lowest sum of bottom 5 countries:
# --------------------------------------------------
#
# rider:
#   Total images in bottom 5 countries: 39
#     Estonia: 3 images
#     Palestine: 7 images
#     Iceland: 9 images
#     Bulgaria: 10 images
#     Luxembourg: 10 images
#
# motorcycle:
#   Total images in bottom 5 countries: 47
#     Estonia: 4 images
#     Latvia: 8 images
#     Eswatini: 10 images
#     Iceland: 12 images
#     Botswana: 13 images
#
# train:
#   Total images in bottom 5 countries: 56
#     Estonia: 6 images
#     Bhutan: 7 images
#     Lithuania: 12 images
#     Slovenia: 15 images
#     Andorra: 16 images
#
# bus:
#   Total images in bottom 5 countries: 60
#     Bhutan: 9 images
#     Greece: 11 images
#     Bulgaria: 13 images
#     Estonia: 13 images
#     Eswatini: 14 images
#
# truck:
#   Total images in bottom 5 countries: 100
#     Lithuania: 16 images
#     Bhutan: 20 images
#     Hungary: 21 images
#     Latvia: 21 images
#     Estonia: 22 images
#
# bicycle:
#   Total images in bottom 5 countries: 104
#     Estonia: 10 images
#     Latvia: 17 images
#     Iceland: 20 images
#     Denmark: 27 images
#     Eswatini: 30 images
#
# traffic_light:
#   Total images in bottom 5 countries: 135
#     Bhutan: 17 images
#     Estonia: 23 images
#     Latvia: 30 images
#     Botswana: 31 images
#     Slovenia: 34 images
#
# person:
#   Total images in bottom 5 countries: 367
#     Iceland: 54 images
#     Estonia: 66 images
#     Eswatini: 77 images
#     Bhutan: 83 images
#     Botswana: 87 images
#
# traffic_sign:
#   Total images in bottom 5 countries: 435
#     Eswatini: 75 images
#     Bhutan: 79 images
#     Estonia: 87 images
#     Botswana: 97 images
#     Iceland: 97 images
#
# fence:
#   Total images in bottom 5 countries: 669
#     Bhutan: 127 images
#     Estonia: 128 images
#     Iceland: 132 images
#     Eswatini: 140 images
#     Latvia: 142 images

# %%
segment_type_country_image_counts.keys()
# Out:
# dict_keys(['terrain', 'road', 'bus', 'train', 'car', 'building', 'pole', 'vegetation', 'rider', 'traffic_light', 'bicycle', 'fence', 'person', 'truck', 'sidewalk', 'motorcycle', 'traffic_sign'])

# %%
import os
import shutil
import random

def create_train_val_split(source_dir, train_dir, val_dir, test_dir, train_ratio=0.8, val_ratio=0.1):
    """
    Create exact 80:10:10 train/val/test split while preserving existing test images
    """
    # All images in the source
    all_images = [f for f in os.listdir(source_dir) if f.endswith(('.jpg', '.png', '.jpeg'))]
    
    # Existing test images
    existing_test_images = set(os.listdir(test_dir))
    n_test = len(existing_test_images)
    
    # Desired total number of images based on existing test count
    total_images_needed = int(n_test / (1 - train_ratio - val_ratio))
    
    # Compute how many more are needed for train and val
    n_train = int(total_images_needed * train_ratio)
    n_val = int(total_images_needed * val_ratio)
    
    # Exclude test images from all
    remaining_images = [img for img in all_images if img not in existing_test_images]
    
    # Sanity check
    if len(remaining_images) < (n_train + n_val):
        print(f"Not enough images to fulfill desired split. Need {n_train + n_val}, but only {len(remaining_images)} available.")
    
    # Shuffle and sample
    random.shuffle(remaining_images)
    train_images = remaining_images[:n_train]
    val_images = remaining_images[n_train:n_train + n_val]
    
    # Copy images
    for img in train_images:
        shutil.copy2(os.path.join(source_dir, img), os.path.join(train_dir, img))
        
    for img in val_images:
        shutil.copy2(os.path.join(source_dir, img), os.path.join(val_dir, img))

def clear_train_val_dirs(base_dir):
    for segment_type in segment_type_country_image_counts.keys():
        segment_dir = os.path.join(base_dir, segment_type)
        for country in segment_type_country_image_counts[segment_type].keys():
            country_dir = os.path.join(segment_dir, country)
            train_dir = os.path.join(country_dir, "train")
            val_dir = os.path.join(country_dir, "val")
            
            if os.path.exists(train_dir):
                shutil.rmtree(train_dir)
            if os.path.exists(val_dir):
                shutil.rmtree(val_dir)

# Base directory containing all segment types
base_dir = "/home/andreafabbricatore/rainbot/datasets/segmented"  # Replace with your actual base directory

clear_train_val_dirs(base_dir)

# Process each segment type
for segment_type in segment_type_country_image_counts.keys():
    segment_dir = os.path.join(base_dir, segment_type)
    
    # Process each country
    for country in segment_type_country_image_counts[segment_type].keys():
        country_dir = os.path.join(segment_dir, country)
        
        # Create train/val/test directories if they don't exist
        train_dir = os.path.join(country_dir, "train")
        val_dir = os.path.join(country_dir, "val")
        test_dir = os.path.join(country_dir, "test")
        
        os.makedirs(train_dir, exist_ok=True)
        os.makedirs(val_dir, exist_ok=True)
        os.makedirs(test_dir, exist_ok=True)
        
        # Create splits while preserving test images
        create_train_val_split(
            source_dir=country_dir,
            train_dir=train_dir,
            val_dir=val_dir,
            test_dir=test_dir
        )

print("Dataset splitting completed successfully!")
# Out:
# Not enough images to fulfill desired split. Need 378, but only 376 available.
# Not enough images to fulfill desired split. Need 387, but only 366 available.
# Not enough images to fulfill desired split. Need 405, but only 387 available.
# Not enough images to fulfill desired split. Need 405, but only 392 available.
# Not enough images to fulfill desired split. Need 378, but only 371 available.
# Not enough images to fulfill desired split. Need 405, but only 390 available.
# Not enough images to fulfill desired split. Need 405, but only 395 available.
# Not enough images to fulfill desired split. Need 387, but only 382 available.
# Not enough images to fulfill desired split. Need 351, but only 345 available.
# Not enough images to fulfill desired split. Need 324, but only 283 available.
# Not enough images to fulfill desired split. Need 396, but only 395 available.
# Not enough images to fulfill desired split. Need 387, but only 355 available.
# Not enough images to fulfill desired split. Need 378, but only 369 available.
# Not enough images to fulfill desired split. Need 306, but only 293 available.
# Not enough images to fulfill desired split. Need 360, but only 355 available.
# Not enough images to fulfill desired split. Need 396, but only 394 available.
# Not enough images to fulfill desired split. Need 405, but only 386 available.
# Not enough images to fulfill desired split. Need 378, but only 366 available.
# Not enough images to fulfill desired split. Need 351, but only 335 available.
# Not enough images to fulfill desired split. Need 360, but only 338 available.
# Not enough images to fulfill desired split. Need 387, but only 385 available.
# Not enough images to fulfill desired split. Need 324, but only 322 available.
# Not enough images to fulfill desired split. Need 387, but only 383 available.
# Not enough images to fulfill desired split. Need 387, but only 386 available.
# Not enough images to fulfill desired split. Need 378, but only 345 available.
# Not enough images to fulfill desired split. Need 405, but only 396 available.
# Not enough images to fulfill desired split. Need 396, but only 384 available.
# Not enough images to fulfill desired split. Need 387, but only 379 available.
# Not enough images to fulfill desired split. Need 351, but only 348 available.
# Not enough images to fulfill desired split. Need 378, but only 367 available.
# Not enough images to fulfill desired split. Need 288, but only 283 available.
# Not enough images to fulfill desired split. Need 405, but only 395 available.
# Not enough images to fulfill desired split. Need 396, but only 390 available.
# Not enough images to fulfill desired split. Need 324, but only 318 available.
# Not enough images to fulfill desired split. Need 360, but only 349 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 396, but only 383 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 405, but only 397 available.
# Not enough images to fulfill desired split. Need 396, but only 383 available.
# Not enough images to fulfill desired split. Need 405, but only 400 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 388 available.
# Not enough images to fulfill desired split. Need 378, but only 377 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 396, but only 393 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 396, but only 342 available.
# Not enough images to fulfill desired split. Need 378, but only 366 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 399 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 396, but only 394 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 396, but only 380 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 396, but only 392 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 396, but only 381 available.
# Not enough images to fulfill desired split. Need 396, but only 393 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 396 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 387, but only 367 available.
# Not enough images to fulfill desired split. Need 396, but only 379 available.
# Not enough images to fulfill desired split. Need 396, but only 378 available.
# Not enough images to fulfill desired split. Need 396, but only 389 available.
# Not enough images to fulfill desired split. Need 36, but only 29 available.
# Not enough images to fulfill desired split. Need 36, but only 33 available.
# Not enough images to fulfill desired split. Need 54, but only 48 available.
# Not enough images to fulfill desired split. Need 27, but only 22 available.
# Not enough images to fulfill desired split. Need 108, but only 96 available.
# Not enough images to fulfill desired split. Need 27, but only 16 available.
# Not enough images to fulfill desired split. Need 54, but only 40 available.
# Not enough images to fulfill desired split. Need 36, but only 25 available.
# Not enough images to fulfill desired split. Need 99, but only 94 available.
# Not enough images to fulfill desired split. Need 45, but only 41 available.
# Not enough images to fulfill desired split. Need 81, but only 56 available.
# Not enough images to fulfill desired split. Need 117, but only 51 available.
# Not enough images to fulfill desired split. Need 36, but only 22 available.
# Not enough images to fulfill desired split. Need 36, but only 9 available.
# Not enough images to fulfill desired split. Need 54, but only 36 available.
# Not enough images to fulfill desired split. Need 99, but only 86 available.
# Not enough images to fulfill desired split. Need 63, but only 32 available.
# Not enough images to fulfill desired split. Need 54, but only 50 available.
# Not enough images to fulfill desired split. Need 27, but only 11 available.
# Not enough images to fulfill desired split. Need 63, but only 34 available.
# Not enough images to fulfill desired split. Need 54, but only 36 available.
# Not enough images to fulfill desired split. Need 45, but only 31 available.
# Not enough images to fulfill desired split. Need 108, but only 44 available.
# Not enough images to fulfill desired split. Need 36, but only 35 available.
# Not enough images to fulfill desired split. Need 144, but only 66 available.
# Not enough images to fulfill desired split. Need 81, but only 51 available.
# Not enough images to fulfill desired split. Need 63, but only 55 available.
# Not enough images to fulfill desired split. Need 18, but only 17 available.
# Not enough images to fulfill desired split. Need 63, but only 51 available.
# Not enough images to fulfill desired split. Need 72, but only 46 available.
# Not enough images to fulfill desired split. Need 18, but only 14 available.
# Not enough images to fulfill desired split. Need 27, but only 14 available.
# Not enough images to fulfill desired split. Need 63, but only 54 available.
# Not enough images to fulfill desired split. Need 36, but only 22 available.
# Not enough images to fulfill desired split. Need 45, but only 42 available.
# Not enough images to fulfill desired split. Need 54, but only 44 available.
# Not enough images to fulfill desired split. Need 72, but only 39 available.
# Not enough images to fulfill desired split. Need 180, but only 153 available.
# Not enough images to fulfill desired split. Need 54, but only 37 available.
# Not enough images to fulfill desired split. Need 144, but only 133 available.
# Not enough images to fulfill desired split. Need 90, but only 80 available.
# Not enough images to fulfill desired split. Need 81, but only 77 available.
# Not enough images to fulfill desired split. Need 27, but only 26 available.
# Not enough images to fulfill desired split. Need 72, but only 53 available.
# Not enough images to fulfill desired split. Need 81, but only 50 available.
# Not enough images to fulfill desired split. Need 117, but only 54 available.
# Not enough images to fulfill desired split. Need 63, but only 29 available.
# Not enough images to fulfill desired split. Need 45, but only 37 available.
# Not enough images to fulfill desired split. Need 72, but only 43 available.
# Not enough images to fulfill desired split. Need 9, but only 7 available.
# Not enough images to fulfill desired split. Need 189, but only 160 available.
# Not enough images to fulfill desired split. Need 27, but only 25 available.
# Not enough images to fulfill desired split. Need 144, but only 94 available.
# Not enough images to fulfill desired split. Need 81, but only 27 available.
# Not enough images to fulfill desired split. Need 36, but only 33 available.
# Not enough images to fulfill desired split. Need 45, but only 32 available.
# Not enough images to fulfill desired split. Need 45, but only 42 available.
# Not enough images to fulfill desired split. Need 135, but only 79 available.
# Not enough images to fulfill desired split. Need 63, but only 43 available.
# Not enough images to fulfill desired split. Need 135, but only 104 available.
# Not enough images to fulfill desired split. Need 27, but only 24 available.
# Not enough images to fulfill desired split. Need 45, but only 35 available.
# Not enough images to fulfill desired split. Need 45, but only 32 available.
# Not enough images to fulfill desired split. Need 72, but only 41 available.
# Not enough images to fulfill desired split. Need 72, but only 66 available.
# Not enough images to fulfill desired split. Need 72, but only 32 available.
# Not enough images to fulfill desired split. Need 90, but only 80 available.
# Not enough images to fulfill desired split. Need 63, but only 41 available.
# Not enough images to fulfill desired split. Need 90, but only 82 available.
# Not enough images to fulfill desired split. Need 63, but only 23 available.
# Not enough images to fulfill desired split. Need 27, but only 15 available.
# Not enough images to fulfill desired split. Need 18, but only 12 available.
# Not enough images to fulfill desired split. Need 45, but only 22 available.
# Not enough images to fulfill desired split. Need 27, but only 16 available.
# Not enough images to fulfill desired split. Need 297, but only 280 available.
# Not enough images to fulfill desired split. Need 378, but only 367 available.
# Not enough images to fulfill desired split. Need 297, but only 286 available.
# Not enough images to fulfill desired split. Need 378, but only 354 available.
# Not enough images to fulfill desired split. Need 333, but only 263 available.
# Not enough images to fulfill desired split. Need 333, but only 327 available.
# Not enough images to fulfill desired split. Need 297, but only 285 available.
# Not enough images to fulfill desired split. Need 351, but only 328 available.
# Not enough images to fulfill desired split. Need 360, but only 344 available.
# Not enough images to fulfill desired split. Need 261, but only 240 available.
# Not enough images to fulfill desired split. Need 306, but only 285 available.
# Not enough images to fulfill desired split. Need 351, but only 295 available.
# Not enough images to fulfill desired split. Need 342, but only 335 available.
# Not enough images to fulfill desired split. Need 270, but only 269 available.
# Not enough images to fulfill desired split. Need 171, but only 144 available.
# Not enough images to fulfill desired split. Need 216, but only 180 available.
# Not enough images to fulfill desired split. Need 261, but only 257 available.
# Not enough images to fulfill desired split. Need 369, but only 365 available.
# Not enough images to fulfill desired split. Need 243, but only 238 available.
# Not enough images to fulfill desired split. Need 288, but only 286 available.
# Not enough images to fulfill desired split. Need 279, but only 246 available.
# Not enough images to fulfill desired split. Need 351, but only 339 available.
# Not enough images to fulfill desired split. Need 270, but only 243 available.
# Not enough images to fulfill desired split. Need 324, but only 303 available.
# Not enough images to fulfill desired split. Need 270, but only 250 available.
# Not enough images to fulfill desired split. Need 234, but only 227 available.
# Not enough images to fulfill desired split. Need 270, but only 263 available.
# Not enough images to fulfill desired split. Need 360, but only 325 available.
# Not enough images to fulfill desired split. Need 351, but only 344 available.
# Not enough images to fulfill desired split. Need 342, but only 317 available.
# Not enough images to fulfill desired split. Need 378, but only 348 available.
# Not enough images to fulfill desired split. Need 297, but only 276 available.
# Not enough images to fulfill desired split. Need 315, but only 311 available.
# Not enough images to fulfill desired split. Need 297, but only 277 available.
# Not enough images to fulfill desired split. Need 270, but only 259 available.
# Not enough images to fulfill desired split. Need 360, but only 352 available.
# Not enough images to fulfill desired split. Need 297, but only 274 available.
# Not enough images to fulfill desired split. Need 378, but only 368 available.
# Not enough images to fulfill desired split. Need 351, but only 329 available.
# Not enough images to fulfill desired split. Need 405, but only 381 available.
# Not enough images to fulfill desired split. Need 171, but only 168 available.
# Not enough images to fulfill desired split. Need 270, but only 262 available.
# Not enough images to fulfill desired split. Need 288, but only 268 available.
# Not enough images to fulfill desired split. Need 369, but only 340 available.
# Not enough images to fulfill desired split. Need 261, but only 251 available.
# Not enough images to fulfill desired split. Need 252, but only 248 available.
# Not enough images to fulfill desired split. Need 234, but only 202 available.
# Not enough images to fulfill desired split. Need 306, but only 272 available.
# Not enough images to fulfill desired split. Need 270, but only 261 available.
# Not enough images to fulfill desired split. Need 297, but only 288 available.
# Not enough images to fulfill desired split. Need 252, but only 225 available.
# Not enough images to fulfill desired split. Need 306, but only 289 available.
# Not enough images to fulfill desired split. Need 342, but only 289 available.
# Not enough images to fulfill desired split. Need 243, but only 221 available.
# Not enough images to fulfill desired split. Need 405, but only 391 available.
# Not enough images to fulfill desired split. Need 396, but only 383 available.
# Not enough images to fulfill desired split. Need 324, but only 320 available.
# Not enough images to fulfill desired split. Need 387, but only 379 available.
# Not enough images to fulfill desired split. Need 396, but only 390 available.
# Not enough images to fulfill desired split. Need 324, but only 319 available.
# Not enough images to fulfill desired split. Need 387, but only 365 available.
# Not enough images to fulfill desired split. Need 405, but only 372 available.
# Not enough images to fulfill desired split. Need 387, but only 374 available.
# Not enough images to fulfill desired split. Need 405, but only 378 available.
# Not enough images to fulfill desired split. Need 252, but only 250 available.
# Not enough images to fulfill desired split. Need 369, but only 328 available.
# Not enough images to fulfill desired split. Need 396, but only 373 available.
# Not enough images to fulfill desired split. Need 387, but only 383 available.
# Not enough images to fulfill desired split. Need 387, but only 377 available.
# Not enough images to fulfill desired split. Need 243, but only 235 available.
# Not enough images to fulfill desired split. Need 405, but only 388 available.
# Not enough images to fulfill desired split. Need 315, but only 296 available.
# Not enough images to fulfill desired split. Need 387, but only 372 available.
# Not enough images to fulfill desired split. Need 387, but only 369 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 396, but only 387 available.
# Not enough images to fulfill desired split. Need 405, but only 378 available.
# Not enough images to fulfill desired split. Need 378, but only 356 available.
# Not enough images to fulfill desired split. Need 378, but only 373 available.
# Not enough images to fulfill desired split. Need 405, but only 389 available.
# Not enough images to fulfill desired split. Need 396, but only 391 available.
# Not enough images to fulfill desired split. Need 333, but only 329 available.
# Not enough images to fulfill desired split. Need 405, but only 396 available.
# Not enough images to fulfill desired split. Need 351, but only 345 available.
# Not enough images to fulfill desired split. Need 351, but only 310 available.
# Not enough images to fulfill desired split. Need 387, but only 379 available.
# Not enough images to fulfill desired split. Need 396, but only 394 available.
# Not enough images to fulfill desired split. Need 387, but only 380 available.
# Not enough images to fulfill desired split. Need 342, but only 309 available.
# Not enough images to fulfill desired split. Need 396, but only 384 available.
# Not enough images to fulfill desired split. Need 288, but only 272 available.
# Not enough images to fulfill desired split. Need 324, but only 317 available.
# Not enough images to fulfill desired split. Need 306, but only 303 available.
# Not enough images to fulfill desired split. Need 378, but only 357 available.
# Not enough images to fulfill desired split. Need 369, but only 361 available.
# Not enough images to fulfill desired split. Need 297, but only 288 available.
# Not enough images to fulfill desired split. Need 333, but only 316 available.
# Not enough images to fulfill desired split. Need 396, but only 346 available.
# Not enough images to fulfill desired split. Need 360, but only 358 available.
# Not enough images to fulfill desired split. Need 396, but only 353 available.
# Not enough images to fulfill desired split. Need 315, but only 305 available.
# Not enough images to fulfill desired split. Need 369, but only 359 available.
# Not enough images to fulfill desired split. Need 387, but only 374 available.
# Not enough images to fulfill desired split. Need 342, but only 311 available.
# Not enough images to fulfill desired split. Need 369, but only 321 available.
# Not enough images to fulfill desired split. Need 333, but only 304 available.
# Not enough images to fulfill desired split. Need 378, but only 354 available.
# Not enough images to fulfill desired split. Need 378, but only 347 available.
# Not enough images to fulfill desired split. Need 297, but only 278 available.
# Not enough images to fulfill desired split. Need 378, but only 369 available.
# Not enough images to fulfill desired split. Need 351, but only 347 available.
# Not enough images to fulfill desired split. Need 378, but only 368 available.
# Not enough images to fulfill desired split. Need 333, but only 318 available.
# Not enough images to fulfill desired split. Need 396, but only 392 available.
# Not enough images to fulfill desired split. Need 378, but only 342 available.
# Not enough images to fulfill desired split. Need 351, but only 342 available.
# Not enough images to fulfill desired split. Need 315, but only 313 available.
# Not enough images to fulfill desired split. Need 396, but only 365 available.
# Not enough images to fulfill desired split. Need 378, but only 358 available.
# Not enough images to fulfill desired split. Need 396, but only 365 available.
# Not enough images to fulfill desired split. Need 378, but only 363 available.
# Not enough images to fulfill desired split. Need 342, but only 318 available.
# Not enough images to fulfill desired split. Need 306, but only 305 available.
# Not enough images to fulfill desired split. Need 378, but only 374 available.
# Not enough images to fulfill desired split. Need 396, but only 376 available.
# Not enough images to fulfill desired split. Need 405, but only 389 available.
# Not enough images to fulfill desired split. Need 297, but only 277 available.
# Not enough images to fulfill desired split. Need 306, but only 266 available.
# Not enough images to fulfill desired split. Need 387, but only 362 available.
# Not enough images to fulfill desired split. Need 297, but only 281 available.
# Not enough images to fulfill desired split. Need 360, but only 351 available.
# Not enough images to fulfill desired split. Need 369, but only 364 available.
# Not enough images to fulfill desired split. Need 360, but only 352 available.
# Not enough images to fulfill desired split. Need 333, but only 314 available.
# Not enough images to fulfill desired split. Need 360, but only 312 available.
# Not enough images to fulfill desired split. Need 360, but only 341 available.
# Not enough images to fulfill desired split. Need 333, but only 293 available.
# Not enough images to fulfill desired split. Need 342, but only 341 available.
# Not enough images to fulfill desired split. Need 306, but only 289 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 396 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 396, but only 393 available.
# Not enough images to fulfill desired split. Need 405, but only 398 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 405, but only 402 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 399 available.
# Not enough images to fulfill desired split. Need 405, but only 389 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 397 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 399 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 396, but only 394 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 387, but only 373 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 400 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 400 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 404 available.
# Not enough images to fulfill desired split. Need 405, but only 398 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 403 available.
# Not enough images to fulfill desired split. Need 405, but only 397 available.
# Not enough images to fulfill desired split. Need 405, but only 401 available.
# Not enough images to fulfill desired split. Need 171, but only 107 available.
# Not enough images to fulfill desired split. Need 72, but only 56 available.
# Not enough images to fulfill desired split. Need 36, but only 22 available.
# Not enough images to fulfill desired split. Need 36, but only 23 available.
# Not enough images to fulfill desired split. Need 36, but only 10 available.
# Not enough images to fulfill desired split. Need 45, but only 30 available.
# Not enough images to fulfill desired split. Need 54, but only 25 available.
# Not enough images to fulfill desired split. Need 72, but only 66 available.
# Not enough images to fulfill desired split. Need 153, but only 94 available.
# Not enough images to fulfill desired split. Need 45, but only 21 available.
# Not enough images to fulfill desired split. Need 27, but only 18 available.
# Not enough images to fulfill desired split. Need 54, but only 33 available.
# Not enough images to fulfill desired split. Need 54, but only 31 available.
# Not enough images to fulfill desired split. Need 45, but only 29 available.
# Not enough images to fulfill desired split. Need 45, but only 16 available.
# Not enough images to fulfill desired split. Need 36, but only 33 available.
# Not enough images to fulfill desired split. Need 63, but only 23 available.
# Not enough images to fulfill desired split. Need 36, but only 35 available.
# Not enough images to fulfill desired split. Need 27, but only 22 available.
# Not enough images to fulfill desired split. Need 54, but only 23 available.
# Not enough images to fulfill desired split. Need 54, but only 22 available.
# Not enough images to fulfill desired split. Need 90, but only 47 available.
# Not enough images to fulfill desired split. Need 27, but only 23 available.
# Not enough images to fulfill desired split. Need 45, but only 20 available.
# Not enough images to fulfill desired split. Need 54, but only 29 available.
# Not enough images to fulfill desired split. Need 36, but only 26 available.
# Not enough images to fulfill desired split. Need 18, but only 9 available.
# Not enough images to fulfill desired split. Need 45, but only 28 available.
# Not enough images to fulfill desired split. Need 54, but only 50 available.
# Not enough images to fulfill desired split. Need 72, but only 41 available.
# Not enough images to fulfill desired split. Need 54, but only 25 available.
# Not enough images to fulfill desired split. Need 45, but only 28 available.
# Not enough images to fulfill desired split. Need 18, but only 10 available.
# Not enough images to fulfill desired split. Need 27, but only 14 available.
# Not enough images to fulfill desired split. Need 36, but only 33 available.
# Not enough images to fulfill desired split. Need 18, but only 13 available.
# Not enough images to fulfill desired split. Need 27, but only 20 available.
# Not enough images to fulfill desired split. Need 63, but only 42 available.
# Not enough images to fulfill desired split. Need 54, but only 39 available.
# Not enough images to fulfill desired split. Need 9, but only 7 available.
# Not enough images to fulfill desired split. Need 63, but only 23 available.
# Not enough images to fulfill desired split. Need 54, but only 50 available.
# Not enough images to fulfill desired split. Need 18, but only 10 available.
# Not enough images to fulfill desired split. Need 126, but only 114 available.
# Not enough images to fulfill desired split. Need 144, but only 78 available.
# Not enough images to fulfill desired split. Need 90, but only 69 available.
# Not enough images to fulfill desired split. Need 180, but only 141 available.
# Not enough images to fulfill desired split. Need 90, but only 66 available.
# Not enough images to fulfill desired split. Need 117, but only 111 available.
# Not enough images to fulfill desired split. Need 117, but only 79 available.
# Not enough images to fulfill desired split. Need 72, but only 51 available.
# Not enough images to fulfill desired split. Need 90, but only 66 available.
# Not enough images to fulfill desired split. Need 72, but only 60 available.
# Not enough images to fulfill desired split. Need 108, but only 103 available.
# Not enough images to fulfill desired split. Need 72, but only 62 available.
# Not enough images to fulfill desired split. Need 81, but only 71 available.
# Not enough images to fulfill desired split. Need 27, but only 23 available.
# Not enough images to fulfill desired split. Need 27, but only 17 available.
# Not enough images to fulfill desired split. Need 153, but only 130 available.
# Not enough images to fulfill desired split. Need 63, but only 53 available.
# Not enough images to fulfill desired split. Need 126, but only 85 available.
# Not enough images to fulfill desired split. Need 63, but only 49 available.
# Not enough images to fulfill desired split. Need 117, but only 80 available.
# Not enough images to fulfill desired split. Need 108, but only 93 available.
# Not enough images to fulfill desired split. Need 63, but only 54 available.
# Not enough images to fulfill desired split. Need 117, but only 82 available.
# Not enough images to fulfill desired split. Need 126, but only 123 available.
# Not enough images to fulfill desired split. Need 144, but only 117 available.
# Not enough images to fulfill desired split. Need 99, but only 54 available.
# Not enough images to fulfill desired split. Need 117, but only 66 available.
# Not enough images to fulfill desired split. Need 126, but only 70 available.
# Not enough images to fulfill desired split. Need 99, but only 93 available.
# Not enough images to fulfill desired split. Need 54, but only 30 available.
# Not enough images to fulfill desired split. Need 54, but only 51 available.
# Not enough images to fulfill desired split. Need 117, but only 90 available.
# Not enough images to fulfill desired split. Need 54, but only 49 available.
# Not enough images to fulfill desired split. Need 72, but only 51 available.
# Not enough images to fulfill desired split. Need 72, but only 57 available.
# Not enough images to fulfill desired split. Need 63, but only 41 available.
# Not enough images to fulfill desired split. Need 117, but only 72 available.
# Not enough images to fulfill desired split. Need 81, but only 64 available.
# Not enough images to fulfill desired split. Need 45, but only 34 available.
# Not enough images to fulfill desired split. Need 72, but only 49 available.
# Not enough images to fulfill desired split. Need 54, but only 51 available.
# Not enough images to fulfill desired split. Need 99, but only 82 available.
# Not enough images to fulfill desired split. Need 63, but only 43 available.
# Not enough images to fulfill desired split. Need 216, but only 167 available.
# Not enough images to fulfill desired split. Need 144, but only 82 available.
# Not enough images to fulfill desired split. Need 99, but only 53 available.
# Not enough images to fulfill desired split. Need 126, but only 101 available.
# Not enough images to fulfill desired split. Need 72, but only 60 available.
# Not enough images to fulfill desired split. Need 99, but only 62 available.
# Not enough images to fulfill desired split. Need 63, but only 50 available.
# Not enough images to fulfill desired split. Need 108, but only 99 available.
# Not enough images to fulfill desired split. Need 117, but only 103 available.
# Not enough images to fulfill desired split. Need 180, but only 138 available.
# Not enough images to fulfill desired split. Need 180, but only 173 available.
# Not enough images to fulfill desired split. Need 45, but only 31 available.
# Not enough images to fulfill desired split. Need 63, but only 38 available.
# Not enough images to fulfill desired split. Need 63, but only 35 available.
# Not enough images to fulfill desired split. Need 117, but only 92 available.
# Not enough images to fulfill desired split. Need 81, but only 67 available.
# Not enough images to fulfill desired split. Need 18, but only 10 available.
# Not enough images to fulfill desired split. Need 72, but only 53 available.
# Not enough images to fulfill desired split. Need 72, but only 71 available.
# Not enough images to fulfill desired split. Need 144, but only 110 available.
# Not enough images to fulfill desired split. Need 99, but only 47 available.
# Not enough images to fulfill desired split. Need 63, but only 54 available.
# Not enough images to fulfill desired split. Need 108, but only 69 available.
# Not enough images to fulfill desired split. Need 99, but only 84 available.
# Not enough images to fulfill desired split. Need 108, but only 100 available.
# Not enough images to fulfill desired split. Need 81, but only 68 available.
# Not enough images to fulfill desired split. Need 72, but only 61 available.
# Not enough images to fulfill desired split. Need 72, but only 43 available.
# Not enough images to fulfill desired split. Need 90, but only 87 available.
# Not enough images to fulfill desired split. Need 90, but only 89 available.
# Not enough images to fulfill desired split. Need 36, but only 20 available.
# Not enough images to fulfill desired split. Need 99, but only 62 available.
# Not enough images to fulfill desired split. Need 72, but only 51 available.
# Not enough images to fulfill desired split. Need 126, but only 81 available.
# Not enough images to fulfill desired split. Need 63, but only 49 available.
# Not enough images to fulfill desired split. Need 135, but only 117 available.
# Not enough images to fulfill desired split. Need 63, but only 62 available.
# Not enough images to fulfill desired split. Need 126, but only 105 available.
# Not enough images to fulfill desired split. Need 36, but only 17 available.
# Not enough images to fulfill desired split. Need 45, but only 27 available.
# Not enough images to fulfill desired split. Need 108, but only 82 available.
# Not enough images to fulfill desired split. Need 36, but only 30 available.
# Not enough images to fulfill desired split. Need 81, but only 34 available.
# Not enough images to fulfill desired split. Need 81, but only 72 available.
# Not enough images to fulfill desired split. Need 117, but only 103 available.
# Not enough images to fulfill desired split. Need 117, but only 77 available.
# Not enough images to fulfill desired split. Need 153, but only 128 available.
# Not enough images to fulfill desired split. Need 45, but only 41 available.
# Not enough images to fulfill desired split. Need 72, but only 41 available.
# Not enough images to fulfill desired split. Need 99, but only 98 available.
# Not enough images to fulfill desired split. Need 162, but only 153 available.
# Not enough images to fulfill desired split. Need 99, but only 74 available.
# Not enough images to fulfill desired split. Need 324, but only 283 available.
# Not enough images to fulfill desired split. Need 333, but only 322 available.
# Not enough images to fulfill desired split. Need 333, but only 305 available.
# Not enough images to fulfill desired split. Need 225, but only 204 available.
# Not enough images to fulfill desired split. Need 279, but only 242 available.
# Not enough images to fulfill desired split. Need 333, but only 310 available.
# Not enough images to fulfill desired split. Need 270, but only 268 available.
# Not enough images to fulfill desired split. Need 342, but only 335 available.
# Not enough images to fulfill desired split. Need 180, but only 159 available.
# Not enough images to fulfill desired split. Need 288, but only 274 available.
# Not enough images to fulfill desired split. Need 252, but only 245 available.
# Not enough images to fulfill desired split. Need 360, but only 310 available.
# Not enough images to fulfill desired split. Need 270, but only 260 available.
# Not enough images to fulfill desired split. Need 243, but only 231 available.
# Not enough images to fulfill desired split. Need 369, but only 306 available.
# Not enough images to fulfill desired split. Need 135, but only 128 available.
# Not enough images to fulfill desired split. Need 153, but only 127 available.
# Not enough images to fulfill desired split. Need 351, but only 325 available.
# Not enough images to fulfill desired split. Need 270, but only 248 available.
# Not enough images to fulfill desired split. Need 324, but only 321 available.
# Not enough images to fulfill desired split. Need 306, but only 260 available.
# Not enough images to fulfill desired split. Need 378, but only 377 available.
# Not enough images to fulfill desired split. Need 351, but only 285 available.
# Not enough images to fulfill desired split. Need 315, but only 300 available.
# Not enough images to fulfill desired split. Need 378, but only 328 available.
# Not enough images to fulfill desired split. Need 351, but only 346 available.
# Not enough images to fulfill desired split. Need 306, but only 268 available.
# Not enough images to fulfill desired split. Need 396, but only 364 available.
# Not enough images to fulfill desired split. Need 207, but only 186 available.
# Not enough images to fulfill desired split. Need 351, but only 317 available.
# Not enough images to fulfill desired split. Need 270, but only 269 available.
# Not enough images to fulfill desired split. Need 153, but only 142 available.
# Not enough images to fulfill desired split. Need 225, but only 176 available.
# Not enough images to fulfill desired split. Need 333, but only 319 available.
# Not enough images to fulfill desired split. Need 153, but only 140 available.
# Not enough images to fulfill desired split. Need 234, but only 228 available.
# Not enough images to fulfill desired split. Need 333, but only 331 available.
# Not enough images to fulfill desired split. Need 378, but only 351 available.
# Not enough images to fulfill desired split. Need 261, but only 218 available.
# Not enough images to fulfill desired split. Need 207, but only 186 available.
# Not enough images to fulfill desired split. Need 306, but only 305 available.
# Not enough images to fulfill desired split. Need 180, but only 178 available.
# Not enough images to fulfill desired split. Need 198, but only 165 available.
# Not enough images to fulfill desired split. Need 180, but only 176 available.
# Not enough images to fulfill desired split. Need 207, but only 177 available.
# Not enough images to fulfill desired split. Need 108, but only 101 available.
# Not enough images to fulfill desired split. Need 162, but only 117 available.
# Not enough images to fulfill desired split. Need 162, but only 152 available.
# Not enough images to fulfill desired split. Need 243, but only 191 available.
# Not enough images to fulfill desired split. Need 252, but only 235 available.
# Not enough images to fulfill desired split. Need 198, but only 142 available.
# Not enough images to fulfill desired split. Need 180, but only 136 available.
# Not enough images to fulfill desired split. Need 243, but only 206 available.
# Not enough images to fulfill desired split. Need 198, but only 195 available.
# Not enough images to fulfill desired split. Need 144, but only 121 available.
# Not enough images to fulfill desired split. Need 90, but only 66 available.
# Not enough images to fulfill desired split. Need 270, but only 265 available.
# Not enough images to fulfill desired split. Need 216, but only 201 available.
# Not enough images to fulfill desired split. Need 171, but only 152 available.
# Not enough images to fulfill desired split. Need 180, but only 161 available.
# Not enough images to fulfill desired split. Need 225, but only 206 available.
# Not enough images to fulfill desired split. Need 198, but only 189 available.
# Not enough images to fulfill desired split. Need 243, but only 216 available.
# Not enough images to fulfill desired split. Need 234, but only 232 available.
# Not enough images to fulfill desired split. Need 225, but only 210 available.
# Not enough images to fulfill desired split. Need 216, but only 183 available.
# Not enough images to fulfill desired split. Need 189, but only 174 available.
# Not enough images to fulfill desired split. Need 261, but only 258 available.
# Not enough images to fulfill desired split. Need 99, but only 92 available.
# Not enough images to fulfill desired split. Need 153, but only 125 available.
# Not enough images to fulfill desired split. Need 198, but only 181 available.
# Not enough images to fulfill desired split. Need 171, but only 156 available.
# Not enough images to fulfill desired split. Need 189, but only 187 available.
# Not enough images to fulfill desired split. Need 153, but only 110 available.
# Not enough images to fulfill desired split. Need 81, but only 47 available.
# Not enough images to fulfill desired split. Need 36, but only 29 available.
# Not enough images to fulfill desired split. Need 90, but only 74 available.
# Not enough images to fulfill desired split. Need 36, but only 21 available.
# Not enough images to fulfill desired split. Need 54, but only 53 available.
# Not enough images to fulfill desired split. Need 81, but only 64 available.
# Not enough images to fulfill desired split. Need 108, but only 68 available.
# Not enough images to fulfill desired split. Need 63, but only 33 available.
# Not enough images to fulfill desired split. Need 117, but only 75 available.
# Not enough images to fulfill desired split. Need 90, but only 48 available.
# Not enough images to fulfill desired split. Need 36, but only 26 available.
# Not enough images to fulfill desired split. Need 36, but only 22 available.
# Not enough images to fulfill desired split. Need 27, but only 20 available.
# Not enough images to fulfill desired split. Need 144, but only 117 available.
# Not enough images to fulfill desired split. Need 90, but only 84 available.
# Not enough images to fulfill desired split. Need 63, but only 36 available.
# Not enough images to fulfill desired split. Need 81, but only 63 available.
# Not enough images to fulfill desired split. Need 45, but only 33 available.
# Not enough images to fulfill desired split. Need 72, but only 30 available.
# Not enough images to fulfill desired split. Need 45, but only 39 available.
# Not enough images to fulfill desired split. Need 72, but only 60 available.
# Not enough images to fulfill desired split. Need 72, but only 59 available.
# Not enough images to fulfill desired split. Need 63, but only 62 available.
# Not enough images to fulfill desired split. Need 99, but only 65 available.
# Not enough images to fulfill desired split. Need 63, but only 55 available.
# Not enough images to fulfill desired split. Need 99, but only 68 available.
# Not enough images to fulfill desired split. Need 36, but only 30 available.
# Not enough images to fulfill desired split. Need 144, but only 117 available.
# Not enough images to fulfill desired split. Need 54, but only 43 available.
# Not enough images to fulfill desired split. Need 63, but only 48 available.
# Not enough images to fulfill desired split. Need 54, but only 30 available.
# Not enough images to fulfill desired split. Need 81, but only 56 available.
# Not enough images to fulfill desired split. Need 45, but only 32 available.
# Not enough images to fulfill desired split. Need 27, but only 16 available.
# Not enough images to fulfill desired split. Need 36, but only 33 available.
# Not enough images to fulfill desired split. Need 108, but only 100 available.
# Not enough images to fulfill desired split. Need 45, but only 37 available.
# Not enough images to fulfill desired split. Need 378, but only 362 available.
# Not enough images to fulfill desired split. Need 405, but only 389 available.
# Not enough images to fulfill desired split. Need 396, but only 377 available.
# Not enough images to fulfill desired split. Need 378, but only 348 available.
# Not enough images to fulfill desired split. Need 396, but only 371 available.
# Not enough images to fulfill desired split. Need 315, but only 276 available.
# Not enough images to fulfill desired split. Need 378, but only 352 available.
# Not enough images to fulfill desired split. Need 396, but only 357 available.
# Not enough images to fulfill desired split. Need 405, but only 371 available.
# Not enough images to fulfill desired split. Need 342, but only 283 available.
# Not enough images to fulfill desired split. Need 315, but only 293 available.
# Not enough images to fulfill desired split. Need 342, but only 337 available.
# Not enough images to fulfill desired split. Need 396, but only 383 available.
# Not enough images to fulfill desired split. Need 351, but only 317 available.
# Not enough images to fulfill desired split. Need 387, but only 366 available.
# Not enough images to fulfill desired split. Need 351, but only 336 available.
# Not enough images to fulfill desired split. Need 180, but only 166 available.
# Not enough images to fulfill desired split. Need 234, but only 226 available.
# Not enough images to fulfill desired split. Need 387, but only 359 available.
# Not enough images to fulfill desired split. Need 324, but only 301 available.
# Not enough images to fulfill desired split. Need 324, but only 309 available.
# Not enough images to fulfill desired split. Need 324, but only 322 available.
# Not enough images to fulfill desired split. Need 405, but only 382 available.
# Not enough images to fulfill desired split. Need 333, but only 308 available.
# Not enough images to fulfill desired split. Need 378, but only 358 available.
# Not enough images to fulfill desired split. Need 351, but only 343 available.
# Not enough images to fulfill desired split. Need 387, but only 380 available.
# Not enough images to fulfill desired split. Need 378, but only 344 available.
# Not enough images to fulfill desired split. Need 324, but only 306 available.
# Not enough images to fulfill desired split. Need 360, but only 353 available.
# Not enough images to fulfill desired split. Need 405, but only 393 available.
# Not enough images to fulfill desired split. Need 396, but only 395 available.
# Not enough images to fulfill desired split. Need 351, but only 330 available.
# Not enough images to fulfill desired split. Need 369, but only 366 available.
# Not enough images to fulfill desired split. Need 243, but only 219 available.
# Not enough images to fulfill desired split. Need 342, but only 289 available.
# Not enough images to fulfill desired split. Need 396, but only 344 available.
# Not enough images to fulfill desired split. Need 396, but only 393 available.
# Not enough images to fulfill desired split. Need 297, but only 291 available.
# Not enough images to fulfill desired split. Need 279, but only 235 available.
# Not enough images to fulfill desired split. Need 360, but only 336 available.
# Not enough images to fulfill desired split. Need 162, but only 115 available.
# Not enough images to fulfill desired split. Need 72, but only 48 available.
# Not enough images to fulfill desired split. Need 36, but only 28 available.
# Not enough images to fulfill desired split. Need 45, but only 29 available.
# Not enough images to fulfill desired split. Need 54, but only 39 available.
# Not enough images to fulfill desired split. Need 126, but only 116 available.
# Not enough images to fulfill desired split. Need 18, but only 13 available.
# Not enough images to fulfill desired split. Need 54, but only 21 available.
# Not enough images to fulfill desired split. Need 36, but only 21 available.
# Not enough images to fulfill desired split. Need 63, but only 57 available.
# Not enough images to fulfill desired split. Need 63, but only 35 available.
# Not enough images to fulfill desired split. Need 45, but only 23 available.
# Not enough images to fulfill desired split. Need 27, but only 16 available.
# Not enough images to fulfill desired split. Need 45, but only 42 available.
# Not enough images to fulfill desired split. Need 27, but only 15 available.
# Not enough images to fulfill desired split. Need 63, but only 59 available.
# Not enough images to fulfill desired split. Need 63, but only 32 available.
# Not enough images to fulfill desired split. Need 63, but only 49 available.
# Not enough images to fulfill desired split. Need 99, but only 66 available.
# Not enough images to fulfill desired split. Need 27, but only 17 available.
# Not enough images to fulfill desired split. Need 54, but only 41 available.
# Not enough images to fulfill desired split. Need 45, but only 25 available.
# Not enough images to fulfill desired split. Need 81, but only 44 available.
# Not enough images to fulfill desired split. Need 54, but only 41 available.
# Not enough images to fulfill desired split. Need 81, but only 65 available.
# Not enough images to fulfill desired split. Need 36, but only 24 available.
# Not enough images to fulfill desired split. Need 9, but only 8 available.
# Not enough images to fulfill desired split. Need 63, but only 30 available.
# Not enough images to fulfill desired split. Need 63, but only 39 available.
# Not enough images to fulfill desired split. Need 63, but only 44 available.
# Not enough images to fulfill desired split. Need 36, but only 28 available.
# Not enough images to fulfill desired split. Need 63, but only 37 available.
# Not enough images to fulfill desired split. Need 99, but only 42 available.
# Not enough images to fulfill desired split. Need 45, but only 20 available.
# Not enough images to fulfill desired split. Need 54, but only 47 available.
# Not enough images to fulfill desired split. Need 108, but only 90 available.
# Not enough images to fulfill desired split. Need 36, but only 32 available.
# Not enough images to fulfill desired split. Need 207, but only 206 available.
# Not enough images to fulfill desired split. Need 288, but only 233 available.
# Not enough images to fulfill desired split. Need 225, but only 214 available.
# Not enough images to fulfill desired split. Need 297, but only 250 available.
# Not enough images to fulfill desired split. Need 315, but only 279 available.
# Not enough images to fulfill desired split. Need 270, but only 247 available.
# Not enough images to fulfill desired split. Need 279, but only 249 available.
# Not enough images to fulfill desired split. Need 189, but only 180 available.
# Not enough images to fulfill desired split. Need 288, but only 257 available.
# Not enough images to fulfill desired split. Need 243, but only 216 available.
# Not enough images to fulfill desired split. Need 225, but only 209 available.
# Not enough images to fulfill desired split. Need 225, but only 215 available.
# Not enough images to fulfill desired split. Need 117, but only 87 available.
# Not enough images to fulfill desired split. Need 189, but only 186 available.
# Not enough images to fulfill desired split. Need 333, but only 301 available.
# Not enough images to fulfill desired split. Need 216, but only 162 available.
# Not enough images to fulfill desired split. Need 216, but only 215 available.
# Not enough images to fulfill desired split. Need 297, but only 265 available.
# Not enough images to fulfill desired split. Need 135, but only 126 available.
# Not enough images to fulfill desired split. Need 297, but only 254 available.
# Not enough images to fulfill desired split. Need 243, but only 236 available.
# Not enough images to fulfill desired split. Need 234, but only 195 available.
# Not enough images to fulfill desired split. Need 288, but only 221 available.
# Not enough images to fulfill desired split. Need 207, but only 193 available.
# Not enough images to fulfill desired split. Need 306, but only 250 available.
# Not enough images to fulfill desired split. Need 252, but only 220 available.
# Not enough images to fulfill desired split. Need 297, but only 257 available.
# Not enough images to fulfill desired split. Need 153, but only 111 available.
# Not enough images to fulfill desired split. Need 243, but only 161 available.
# Not enough images to fulfill desired split. Need 207, but only 187 available.
# Not enough images to fulfill desired split. Need 261, but only 212 available.
# Not enough images to fulfill desired split. Need 207, but only 165 available.
# Not enough images to fulfill desired split. Need 252, but only 218 available.
# Not enough images to fulfill desired split. Need 144, but only 131 available.
# Not enough images to fulfill desired split. Need 225, but only 206 available.
# Not enough images to fulfill desired split. Need 171, but only 158 available.
# Not enough images to fulfill desired split. Need 279, but only 274 available.
# Not enough images to fulfill desired split. Need 216, but only 153 available.
# Dataset splitting completed successfully!

# %%
# Calculate and print train:test:val ratios for each segment type
print("Train:Test:Val ratios (80:10:10) for each segment type:")

segments_to_skip = []

for segment_type in segment_type_country_image_counts.keys():
    print(f"\n{segment_type}:")
    for country in segment_type_country_image_counts[segment_type].keys():
        country_dir = os.path.join(base_dir, segment_type, country)
        
        # Count images in each split
        train_count = len(os.listdir(os.path.join(country_dir, "train")))
        test_count = len(os.listdir(os.path.join(country_dir, "test")))
        val_count = len(os.listdir(os.path.join(country_dir, "val")))
        
        total = train_count + test_count + val_count
        
        try:
            # Calculate actual ratios
            train_ratio = train_count / total
            test_ratio = test_count / total
            val_ratio = val_count / total
            
            print(f"{country}:")
            print(f"  Train: {train_ratio:.2%}")
            print(f"  Test:  {test_ratio:.2%}")
            print(f"  Val:   {val_ratio:.2%}")
        except ZeroDivisionError:
            segments_to_skip.append(f"{segment_type}/{country}")

if segments_to_skip:
    print("\nSegments with zero images (skipped):")
    for segment in segments_to_skip:
        print(f"- {segment}")
# Out:
# Train:Test:Val ratios (80:10:10) for each segment type:
#
# terrain:
# Montenegro:
#   Train: 80.38%
#   Test:  10.05%
#   Val:   9.57%
# Ukraine:
#   Train: 84.11%
#   Test:  10.51%
#   Val:   5.38%
# Germany:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Australia:
#   Train: 83.33%
#   Test:  10.42%
#   Val:   6.25%
# Kenya:
#   Train: 82.38%
#   Test:  10.30%
#   Val:   7.32%
# Belgium:
#   Train: 81.36%
#   Test:  10.17%
#   Val:   8.47%
# Ecuador:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 82.76%
#   Test:  10.34%
#   Val:   6.90%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 81.82%
#   Test:  10.23%
#   Val:   7.95%
# Russia:
#   Train: 80.94%
#   Test:  10.12%
#   Val:   8.94%
# Peru:
#   Train: 81.25%
#   Test:  10.16%
#   Val:   8.59%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Indonesia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Jordan:
#   Train: 88.71%
#   Test:  11.29%
#   Val:   0.00%
# Botswana:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.79%
# Slovakia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# New Zealand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Taiwan:
#   Train: 86.43%
#   Test:  10.80%
#   Val:   2.76%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Portugal:
#   Train: 81.75%
#   Test:  10.22%
#   Val:   8.03%
# South Korea:
#   Train: 83.18%
#   Test:  10.40%
#   Val:   6.42%
# Sri Lanka:
#   Train: 81.01%
#   Test:  10.13%
#   Val:   8.86%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 80.37%
#   Test:  10.05%
#   Val:   9.59%
# Bhutan:
#   Train: 83.53%
#   Test:  10.44%
#   Val:   6.03%
# Argentina:
#   Train: 82.35%
#   Test:  10.29%
#   Val:   7.35%
# Guatemala:
#   Train: 83.42%
#   Test:  10.43%
#   Val:   6.15%
# Finland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mexico:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Czechia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 84.66%
#   Test:  10.58%
#   Val:   4.76%
# Singapore:
#   Train: 80.37%
#   Test:  10.05%
#   Val:   9.58%
# Austria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Arab Emirates:
#   Train: 80.45%
#   Test:  10.06%
#   Val:   9.50%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 80.75%
#   Test:  10.09%
#   Val:   9.15%
# Poland:
#   Train: 80.19%
#   Test:  10.02%
#   Val:   9.79%
# Albania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 86.82%
#   Test:  10.85%
#   Val:   2.33%
# France:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Turkey:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 81.63%
#   Test:  10.20%
#   Val:   8.16%
# Denmark:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 82.24%
#   Test:  10.28%
#   Val:   7.48%
# United Kingdom:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Thailand:
#   Train: 81.52%
#   Test:  10.19%
#   Val:   8.29%
# Chile:
#   Train: 80.62%
#   Test:  10.08%
#   Val:   9.30%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 82.15%
#   Test:  10.27%
#   Val:   7.58%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 81.27%
#   Test:  10.16%
#   Val:   8.57%
# Slovenia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lithuania:
#   Train: 81.82%
#   Test:  10.23%
#   Val:   7.95%
# Croatia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Malaysia:
#   Train: 81.11%
#   Test:  10.14%
#   Val:   8.76%
# Philippines:
#   Train: 81.36%
#   Test:  10.17%
#   Val:   8.47%
# Andorra:
#   Train: 82.26%
#   Test:  10.28%
#   Val:   7.46%
#
# road:
# Montenegro:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Ukraine:
#   Train: 82.44%
#   Test:  10.30%
#   Val:   7.26%
# Germany:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Belgium:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ecuador:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bulgaria:
#   Train: 81.45%
#   Test:  10.18%
#   Val:   8.37%
# Hungary:
#   Train: 82.44%
#   Test:  10.30%
#   Val:   7.26%
# Italy:
#   Train: 80.90%
#   Test:  10.11%
#   Val:   8.99%
# Canada:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Russia:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Peru:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Bolivia:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Ghana:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Indonesia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 83.14%
#   Test:  10.39%
#   Val:   6.47%
# Slovakia:
#   Train: 80.19%
#   Test:  10.02%
#   Val:   9.79%
# New Zealand:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Taiwan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Portugal:
#   Train: 80.55%
#   Test:  10.07%
#   Val:   9.38%
# South Korea:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Sri Lanka:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 88.60%
#   Test:  11.40%
#   Val:   0.00%
# Bhutan:
#   Train: 82.35%
#   Test:  10.29%
#   Val:   7.35%
# Argentina:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Guatemala:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Finland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mexico:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Czechia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 81.08%
#   Test:  10.14%
#   Val:   8.78%
# Singapore:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Austria:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# United Arab Emirates:
#   Train: 80.37%
#   Test:  10.05%
#   Val:   9.59%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 83.02%
#   Test:  10.38%
#   Val:   6.60%
# Kyrgyzstan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Colombia:
#   Train: 80.73%
#   Test:  10.09%
#   Val:   9.17%
# France:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Turkey:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 82.82%
#   Test:  10.35%
#   Val:   6.82%
# Denmark:
#   Train: 80.55%
#   Test:  10.07%
#   Val:   9.38%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# United Kingdom:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Thailand:
#   Train: 81.63%
#   Test:  10.20%
#   Val:   8.16%
# Chile:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# Palestine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Spain:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Senegal:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Slovenia:
#   Train: 83.90%
#   Test:  10.49%
#   Val:   5.61%
# Lithuania:
#   Train: 83.22%
#   Test:  10.40%
#   Val:   6.38%
# Croatia:
#   Train: 83.41%
#   Test:  10.43%
#   Val:   6.16%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Andorra:
#   Train: 81.29%
#   Test:  10.16%
#   Val:   8.55%
#
# bus:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 87.88%
#   Test:  12.12%
#   Val:   0.00%
# Germany:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Australia:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 88.00%
#   Test:  12.00%
#   Val:   0.00%
# Ecuador:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 84.21%
#   Test:  15.79%
#   Val:   0.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Russia:
#   Train: 86.96%
#   Test:  13.04%
#   Val:   0.00%
# Peru:
#   Train: 86.21%
#   Test:  13.79%
#   Val:   0.00%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 83.81%
#   Test:  10.48%
#   Val:   5.71%
# Indonesia:
#   Train: 86.96%
#   Test:  10.87%
#   Val:   2.17%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# New Zealand:
#   Train: 86.15%
#   Test:  13.85%
#   Val:   0.00%
# Taiwan:
#   Train: 79.69%
#   Test:  20.31%
#   Val:   0.00%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Portugal:
#   Train: 84.62%
#   Test:  15.38%
#   Val:   0.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bhutan:
#   Train: 69.23%
#   Test:  30.77%
#   Val:   0.00%
# Argentina:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Guatemala:
#   Train: 88.66%
#   Test:  11.34%
#   Val:   0.00%
# Finland:
#   Train: 82.05%
#   Test:  17.95%
#   Val:   0.00%
# Mexico:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# Czechia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 78.57%
#   Test:  21.43%
#   Val:   0.00%
# Singapore:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Austria:
#   Train: 82.93%
#   Test:  17.07%
#   Val:   0.00%
# United Arab Emirates:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 86.11%
#   Test:  13.89%
#   Val:   0.00%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 78.57%
#   Test:  21.43%
#   Val:   0.00%
# Netherlands:
#   Train: 82.05%
#   Test:  10.26%
#   Val:   7.69%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 80.49%
#   Test:  19.51%
#   Val:   0.00%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Turkey:
#   Train: 85.00%
#   Test:  15.00%
#   Val:   0.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 88.71%
#   Test:  11.29%
#   Val:   0.00%
# Israel:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Japan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 87.93%
#   Test:  12.07%
#   Val:   0.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Denmark:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Serbia:
#   Train: 85.19%
#   Test:  14.81%
#   Val:   0.00%
# Eswatini:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Norway:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Kingdom:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovenia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lithuania:
#   Train: 82.35%
#   Test:  17.65%
#   Val:   0.00%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 88.52%
#   Test:  11.48%
#   Val:   0.00%
# Andorra:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
#
# train:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 84.62%
#   Test:  15.38%
#   Val:   0.00%
# Germany:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 88.00%
#   Test:  12.00%
#   Val:   0.00%
# Belgium:
#   Train: 82.98%
#   Test:  17.02%
#   Val:   0.00%
# Ecuador:
#   Train: 88.44%
#   Test:  11.56%
#   Val:   0.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 86.05%
#   Test:  13.95%
#   Val:   0.00%
# Russia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Peru:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bolivia:
#   Train: 85.91%
#   Test:  10.74%
#   Val:   3.36%
# Ghana:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Indonesia:
#   Train: 83.72%
#   Test:  10.47%
#   Val:   5.81%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 82.76%
#   Test:  10.34%
#   Val:   6.90%
# Slovakia:
#   Train: 86.89%
#   Test:  13.11%
#   Val:   0.00%
# New Zealand:
#   Train: 84.75%
#   Test:  15.25%
#   Val:   0.00%
# Taiwan:
#   Train: 80.60%
#   Test:  19.40%
#   Val:   0.00%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.56%
#   Test:  19.44%
#   Val:   0.00%
# Portugal:
#   Train: 88.10%
#   Test:  11.90%
#   Val:   0.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 84.31%
#   Test:  15.69%
#   Val:   0.00%
# Bhutan:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Argentina:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Guatemala:
#   Train: 88.40%
#   Test:  11.60%
#   Val:   0.00%
# Finland:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# Mexico:
#   Train: 85.45%
#   Test:  14.55%
#   Val:   0.00%
# Czechia:
#   Train: 75.00%
#   Test:  25.00%
#   Val:   0.00%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Singapore:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Austria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Arab Emirates:
#   Train: 86.49%
#   Test:  13.51%
#   Val:   0.00%
# Romania:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 84.04%
#   Test:  15.96%
#   Val:   0.00%
# Netherlands:
#   Train: 86.00%
#   Test:  14.00%
#   Val:   0.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 87.39%
#   Test:  12.61%
#   Val:   0.00%
# Switzerland:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Turkey:
#   Train: 86.49%
#   Test:  13.51%
#   Val:   0.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 83.67%
#   Test:  16.33%
#   Val:   0.00%
# Japan:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  20.00%
#   Val:   0.00%
# Greenland:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Latvia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Denmark:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Serbia:
#   Train: 85.42%
#   Test:  14.58%
#   Val:   0.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Kingdom:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 86.96%
#   Test:  10.87%
#   Val:   2.17%
# Palestine:
#   Train: 76.67%
#   Test:  23.33%
#   Val:   0.00%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovenia:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Lithuania:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Croatia:
#   Train: 81.48%
#   Test:  18.52%
#   Val:   0.00%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Andorra:
#   Train: 84.21%
#   Test:  15.79%
#   Val:   0.00%
#
# car:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 84.35%
#   Test:  10.54%
#   Val:   5.11%
# Germany:
#   Train: 82.15%
#   Test:  10.27%
#   Val:   7.58%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 82.76%
#   Test:  10.34%
#   Val:   6.90%
# Ecuador:
#   Train: 84.85%
#   Test:  10.61%
#   Val:   4.55%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 87.67%
#   Test:  12.33%
#   Val:   0.00%
# Canada:
#   Train: 81.32%
#   Test:  10.16%
#   Val:   8.52%
# Russia:
#   Train: 83.02%
#   Test:  10.38%
#   Val:   6.60%
# Peru:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bolivia:
#   Train: 85.01%
#   Test:  10.63%
#   Val:   4.36%
# Ghana:
#   Train: 83.33%
#   Test:  10.42%
#   Val:   6.25%
# Indonesia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 86.25%
#   Test:  10.78%
#   Val:   2.97%
# New Zealand:
#   Train: 85.27%
#   Test:  10.66%
#   Val:   4.08%
# Taiwan:
#   Train: 88.32%
#   Test:  11.68%
#   Val:   0.00%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 81.50%
#   Test:  10.19%
#   Val:   8.31%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 80.27%
#   Test:  10.03%
#   Val:   9.70%
# Estonia:
#   Train: 88.34%
#   Test:  11.66%
#   Val:   0.00%
# Bhutan:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Argentina:
#   Train: 81.12%
#   Test:  10.14%
#   Val:   8.74%
# Guatemala:
#   Train: 80.79%
#   Test:  10.10%
#   Val:   9.11%
# Finland:
#   Train: 81.51%
#   Test:  10.19%
#   Val:   8.30%
# Mexico:
#   Train: 80.50%
#   Test:  10.06%
#   Val:   9.43%
# Czechia:
#   Train: 88.81%
#   Test:  11.19%
#   Val:   0.00%
# Mongolia:
#   Train: 82.54%
#   Test:  10.32%
#   Val:   7.14%
# Greece:
#   Train: 87.91%
#   Test:  10.99%
#   Val:   1.10%
# Singapore:
#   Train: 84.96%
#   Test:  10.62%
#   Val:   4.42%
# Austria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Arab Emirates:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# Romania:
#   Train: 82.21%
#   Test:  10.28%
#   Val:   7.51%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 81.91%
#   Test:  10.24%
#   Val:   7.85%
# Albania:
#   Train: 87.67%
#   Test:  10.96%
#   Val:   1.37%
# Netherlands:
#   Train: 81.46%
#   Test:  10.18%
#   Val:   8.36%
# Uruguay:
#   Train: 85.63%
#   Test:  10.70%
#   Val:   3.66%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 86.15%
#   Test:  10.77%
#   Val:   3.08%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 85.44%
#   Test:  10.68%
#   Val:   3.88%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 80.92%
#   Test:  10.12%
#   Val:   8.96%
# Turkey:
#   Train: 85.16%
#   Test:  10.65%
#   Val:   4.19%
# Ireland:
#   Train: 83.04%
#   Test:  10.38%
#   Val:   6.57%
# North Macedonia:
#   Train: 81.63%
#   Test:  10.20%
#   Val:   8.16%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 85.99%
#   Test:  10.75%
#   Val:   3.26%
# Dominican Republic:
#   Train: 81.95%
#   Test:  10.24%
#   Val:   7.80%
# Lesotho:
#   Train: 84.78%
#   Test:  10.60%
#   Val:   4.62%
# Greenland:
#   Train: 84.51%
#   Test:  10.56%
#   Val:   4.93%
# Latvia:
#   Train: 81.28%
#   Test:  10.16%
#   Val:   8.56%
# Denmark:
#   Train: 82.19%
#   Test:  10.27%
#   Val:   7.53%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 85.33%
#   Test:  10.67%
#   Val:   4.00%
# United Kingdom:
#   Train: 86.09%
#   Test:  10.76%
#   Val:   3.15%
# Thailand:
#   Train: 82.86%
#   Test:  10.36%
#   Val:   6.79%
# Chile:
#   Train: 81.16%
#   Test:  10.14%
#   Val:   8.70%
# Cambodia:
#   Train: 88.60%
#   Test:  11.40%
#   Val:   0.00%
# Brazil:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Palestine:
#   Train: 82.47%
#   Test:  10.31%
#   Val:   7.22%
# Spain:
#   Train: 82.24%
#   Test:  10.28%
#   Val:   7.48%
# Senegal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovenia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lithuania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Croatia:
#   Train: 88.54%
#   Test:  11.07%
#   Val:   0.40%
# Malaysia:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Philippines:
#   Train: 88.38%
#   Test:  11.62%
#   Val:   0.00%
# Andorra:
#   Train: 87.10%
#   Test:  10.89%
#   Val:   2.02%
#
# building:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 82.57%
#   Test:  10.32%
#   Val:   7.11%
# Australia:
#   Train: 82.44%
#   Test:  10.30%
#   Val:   7.26%
# Kenya:
#   Train: 80.90%
#   Test:  10.11%
#   Val:   8.99%
# Belgium:
#   Train: 81.52%
#   Test:  10.19%
#   Val:   8.29%
# Ecuador:
#   Train: 81.11%
#   Test:  10.14%
#   Val:   8.76%
# Bulgaria:
#   Train: 81.13%
#   Test:  10.14%
#   Val:   8.73%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 84.31%
#   Test:  10.54%
#   Val:   5.15%
# Russia:
#   Train: 86.33%
#   Test:  10.79%
#   Val:   2.88%
# Peru:
#   Train: 82.49%
#   Test:  10.31%
#   Val:   7.19%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Indonesia:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 80.58%
#   Test:  10.07%
#   Val:   9.35%
# Slovakia:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# New Zealand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Taiwan:
#   Train: 84.41%
#   Test:  10.55%
#   Val:   5.04%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.75%
#   Test:  10.09%
#   Val:   9.15%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 81.90%
#   Test:  10.24%
#   Val:   7.86%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bhutan:
#   Train: 82.44%
#   Test:  10.31%
#   Val:   7.25%
# Argentina:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Guatemala:
#   Train: 83.14%
#   Test:  10.39%
#   Val:   6.47%
# Finland:
#   Train: 84.59%
#   Test:  10.57%
#   Val:   4.83%
# Mexico:
#   Train: 82.89%
#   Test:  10.36%
#   Val:   6.75%
# Czechia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mongolia:
#   Train: 83.50%
#   Test:  10.44%
#   Val:   6.07%
# Greece:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Singapore:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# Austria:
#   Train: 81.67%
#   Test:  10.21%
#   Val:   8.12%
# United Arab Emirates:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# Romania:
#   Train: 84.42%
#   Test:  10.55%
#   Val:   5.03%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 80.96%
#   Test:  10.12%
#   Val:   8.92%
# Albania:
#   Train: 82.95%
#   Test:  10.37%
#   Val:   6.68%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 80.92%
#   Test:  10.11%
#   Val:   8.97%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.87%
#   Test:  10.11%
#   Val:   9.02%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 81.63%
#   Test:  10.20%
#   Val:   8.16%
# Turkey:
#   Train: 81.25%
#   Test:  10.16%
#   Val:   8.59%
# Ireland:
#   Train: 88.83%
#   Test:  11.17%
#   Val:   0.00%
# North Macedonia:
#   Train: 81.52%
#   Test:  10.19%
#   Val:   8.29%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 80.37%
#   Test:  10.05%
#   Val:   9.59%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 81.32%
#   Test:  10.17%
#   Val:   8.51%
# Latvia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Denmark:
#   Train: 87.61%
#   Test:  10.95%
#   Val:   1.44%
# Serbia:
#   Train: 82.24%
#   Test:  10.28%
#   Val:   7.48%
# Eswatini:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Norway:
#   Train: 81.59%
#   Test:  10.20%
#   Val:   8.22%
# United Kingdom:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Cambodia:
#   Train: 80.71%
#   Test:  10.09%
#   Val:   9.20%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 81.59%
#   Test:  10.20%
#   Val:   8.21%
# Slovenia:
#   Train: 82.24%
#   Test:  10.28%
#   Val:   7.48%
# Lithuania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Croatia:
#   Train: 83.85%
#   Test:  10.48%
#   Val:   5.67%
# Malaysia:
#   Train: 88.72%
#   Test:  11.28%
#   Val:   0.00%
# Philippines:
#   Train: 80.40%
#   Test:  10.05%
#   Val:   9.55%
# Andorra:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
#
# pole:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ecuador:
#   Train: 88.66%
#   Test:  11.08%
#   Val:   0.25%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Russia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Peru:
#   Train: 82.35%
#   Test:  10.29%
#   Val:   7.35%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Indonesia:
#   Train: 82.00%
#   Test:  10.25%
#   Val:   7.75%
# Jordan:
#   Train: 82.49%
#   Test:  10.31%
#   Val:   7.19%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 87.11%
#   Test:  10.89%
#   Val:   2.01%
# New Zealand:
#   Train: 88.67%
#   Test:  11.33%
#   Val:   0.00%
# Taiwan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Luxembourg:
#   Train: 86.80%
#   Test:  10.85%
#   Val:   2.35%
# United States:
#   Train: 84.85%
#   Test:  10.61%
#   Val:   4.55%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 86.38%
#   Test:  10.80%
#   Val:   2.83%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bhutan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Argentina:
#   Train: 84.89%
#   Test:  10.61%
#   Val:   4.50%
# Guatemala:
#   Train: 81.75%
#   Test:  10.22%
#   Val:   8.03%
# Finland:
#   Train: 80.83%
#   Test:  10.10%
#   Val:   9.07%
# Mexico:
#   Train: 81.95%
#   Test:  10.24%
#   Val:   7.80%
# Czechia:
#   Train: 83.38%
#   Test:  10.42%
#   Val:   6.20%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Singapore:
#   Train: 80.73%
#   Test:  10.09%
#   Val:   9.17%
# Austria:
#   Train: 87.50%
#   Test:  10.94%
#   Val:   1.56%
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Romania:
#   Train: 81.89%
#   Test:  10.24%
#   Val:   7.87%
# South Africa:
#   Train: 80.46%
#   Test:  10.06%
#   Val:   9.48%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 86.06%
#   Test:  10.76%
#   Val:   3.18%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 84.00%
#   Test:  10.50%
#   Val:   5.50%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 86.06%
#   Test:  10.76%
#   Val:   3.18%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 82.96%
#   Test:  10.37%
#   Val:   6.67%
# Turkey:
#   Train: 85.39%
#   Test:  10.67%
#   Val:   3.93%
# Ireland:
#   Train: 80.24%
#   Test:  10.03%
#   Val:   9.73%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 80.77%
#   Test:  10.10%
#   Val:   9.13%
# Japan:
#   Train: 83.81%
#   Test:  10.48%
#   Val:   5.71%
# Dominican Republic:
#   Train: 82.95%
#   Test:  10.37%
#   Val:   6.68%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 85.16%
#   Test:  10.65%
#   Val:   4.19%
# Denmark:
#   Train: 88.67%
#   Test:  11.33%
#   Val:   0.00%
# Serbia:
#   Train: 84.94%
#   Test:  10.62%
#   Val:   4.44%
# Eswatini:
#   Train: 84.08%
#   Test:  10.51%
#   Val:   5.41%
# Norway:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Kingdom:
#   Train: 81.84%
#   Test:  10.23%
#   Val:   7.93%
# Thailand:
#   Train: 80.99%
#   Test:  10.12%
#   Val:   8.89%
# Chile:
#   Train: 81.63%
#   Test:  10.20%
#   Val:   8.16%
# Cambodia:
#   Train: 84.33%
#   Test:  10.54%
#   Val:   5.13%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 88.64%
#   Test:  11.36%
#   Val:   0.00%
# Spain:
#   Train: 83.99%
#   Test:  10.50%
#   Val:   5.51%
# Senegal:
#   Train: 88.79%
#   Test:  11.21%
#   Val:   0.00%
# Slovenia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lithuania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Croatia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 80.21%
#   Test:  10.03%
#   Val:   9.76%
# Andorra:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
#
# vegetation:
# Montenegro:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Australia:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 81.63%
#   Test:  10.20%
#   Val:   8.16%
# Ecuador:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bulgaria:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# Hungary:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Russia:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Peru:
#   Train: 80.55%
#   Test:  10.07%
#   Val:   9.38%
# Bolivia:
#   Train: 81.26%
#   Test:  10.16%
#   Val:   8.58%
# Ghana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Indonesia:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# New Zealand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Taiwan:
#   Train: 80.54%
#   Test:  10.07%
#   Val:   9.40%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Portugal:
#   Train: 81.08%
#   Test:  10.14%
#   Val:   8.78%
# South Korea:
#   Train: 82.95%
#   Test:  10.37%
#   Val:   6.68%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bhutan:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Argentina:
#   Train: 81.45%
#   Test:  10.18%
#   Val:   8.37%
# Guatemala:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Finland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mexico:
#   Train: 81.08%
#   Test:  10.14%
#   Val:   8.78%
# Czechia:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
# Mongolia:
#   Train: 80.37%
#   Test:  10.05%
#   Val:   9.59%
# Greece:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Singapore:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Austria:
#   Train: 82.69%
#   Test:  10.34%
#   Val:   6.97%
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Romania:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# South Africa:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Poland:
#   Train: 80.90%
#   Test:  10.11%
#   Val:   8.99%
# Albania:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Turkey:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ireland:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 80.90%
#   Test:  10.11%
#   Val:   8.99%
# Dominican Republic:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Lesotho:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.80%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Denmark:
#   Train: 81.26%
#   Test:  10.16%
#   Val:   8.58%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Eswatini:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Norway:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Kingdom:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovenia:
#   Train: 80.36%
#   Test:  10.04%
#   Val:   9.60%
# Lithuania:
#   Train: 81.45%
#   Test:  10.18%
#   Val:   8.37%
# Croatia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Andorra:
#   Train: 80.72%
#   Test:  10.09%
#   Val:   9.19%
#
# rider:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 84.92%
#   Test:  15.08%
#   Val:   0.00%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Belgium:
#   Train: 84.62%
#   Test:  15.38%
#   Val:   0.00%
# Ecuador:
#   Train: 85.19%
#   Test:  14.81%
#   Val:   0.00%
# Bulgaria:
#   Train: 71.43%
#   Test:  28.57%
#   Val:   0.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Russia:
#   Train: 80.65%
#   Test:  19.35%
#   Val:   0.00%
# Peru:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Indonesia:
#   Train: 84.68%
#   Test:  15.32%
#   Val:   0.00%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 80.77%
#   Test:  19.23%
#   Val:   0.00%
# New Zealand:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Taiwan:
#   Train: 84.62%
#   Test:  15.38%
#   Val:   0.00%
# United States:
#   Train: 83.78%
#   Test:  16.22%
#   Val:   0.00%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 85.29%
#   Test:  14.71%
#   Val:   0.00%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bhutan:
#   Train: 76.19%
#   Test:  23.81%
#   Val:   0.00%
# Argentina:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Guatemala:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Finland:
#   Train: 76.67%
#   Test:  23.33%
#   Val:   0.00%
# Mexico:
#   Train: 82.05%
#   Test:  10.26%
#   Val:   7.69%
# Czechia:
#   Train: 88.00%
#   Test:  12.00%
#   Val:   0.00%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 79.31%
#   Test:  20.69%
#   Val:   0.00%
# Singapore:
#   Train: 78.57%
#   Test:  21.43%
#   Val:   0.00%
# Austria:
#   Train: 82.46%
#   Test:  17.54%
#   Val:   0.00%
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 88.46%
#   Test:  11.54%
#   Val:   0.00%
# Poland:
#   Train: 80.00%
#   Test:  20.00%
#   Val:   0.00%
# Albania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Netherlands:
#   Train: 82.86%
#   Test:  17.14%
#   Val:   0.00%
# Uruguay:
#   Train: 86.67%
#   Test:  13.33%
#   Val:   0.00%
# Iceland:
#   Train: 81.82%
#   Test:  18.18%
#   Val:   0.00%
# Kyrgyzstan:
#   Train: 84.85%
#   Test:  15.15%
#   Val:   0.00%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# France:
#   Train: 83.67%
#   Test:  16.33%
#   Val:   0.00%
# Turkey:
#   Train: 80.65%
#   Test:  19.35%
#   Val:   0.00%
# Ireland:
#   Train: 84.85%
#   Test:  15.15%
#   Val:   0.00%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 82.35%
#   Test:  17.65%
#   Val:   0.00%
# Serbia:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Eswatini:
#   Train: 86.67%
#   Test:  13.33%
#   Val:   0.00%
# Norway:
#   Train: 86.96%
#   Test:  13.04%
#   Val:   0.00%
# United Kingdom:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Thailand:
#   Train: 86.67%
#   Test:  13.33%
#   Val:   0.00%
# Chile:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Spain:
#   Train: 76.67%
#   Test:  23.33%
#   Val:   0.00%
# Senegal:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# Slovenia:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Croatia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 87.50%
#   Test:  10.94%
#   Val:   1.56%
# Andorra:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
#
# traffic_light:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 82.98%
#   Test:  17.02%
#   Val:   0.00%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 87.34%
#   Test:  12.66%
#   Val:   0.00%
# Ecuador:
#   Train: 87.58%
#   Test:  12.42%
#   Val:   0.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 86.84%
#   Test:  13.16%
#   Val:   0.00%
# Russia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Peru:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bolivia:
#   Train: 83.87%
#   Test:  10.48%
#   Val:   5.65%
# Ghana:
#   Train: 85.87%
#   Test:  14.13%
#   Val:   0.00%
# Indonesia:
#   Train: 86.44%
#   Test:  13.56%
#   Val:   0.00%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 86.84%
#   Test:  13.16%
#   Val:   0.00%
# New Zealand:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Taiwan:
#   Train: 83.48%
#   Test:  10.43%
#   Val:   6.09%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Portugal:
#   Train: 88.57%
#   Test:  11.43%
#   Val:   0.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 88.75%
#   Test:  11.25%
#   Val:   0.00%
# Estonia:
#   Train: 88.46%
#   Test:  11.54%
#   Val:   0.00%
# Bhutan:
#   Train: 85.00%
#   Test:  15.00%
#   Val:   0.00%
# Argentina:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Guatemala:
#   Train: 88.44%
#   Test:  11.56%
#   Val:   0.00%
# Finland:
#   Train: 88.33%
#   Test:  11.67%
#   Val:   0.00%
# Mexico:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Czechia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mongolia:
#   Train: 85.86%
#   Test:  14.14%
#   Val:   0.00%
# Greece:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Singapore:
#   Train: 86.02%
#   Test:  13.98%
#   Val:   0.00%
# Austria:
#   Train: 88.57%
#   Test:  11.43%
#   Val:   0.00%
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 88.52%
#   Test:  11.48%
#   Val:   0.00%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Netherlands:
#   Train: 86.32%
#   Test:  13.68%
#   Val:   0.00%
# Uruguay:
#   Train: 81.75%
#   Test:  10.22%
#   Val:   8.03%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 87.97%
#   Test:  12.03%
#   Val:   0.00%
# Switzerland:
#   Train: 83.08%
#   Test:  16.92%
#   Val:   0.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 83.54%
#   Test:  16.46%
#   Val:   0.00%
# Turkey:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 84.62%
#   Test:  10.58%
#   Val:   4.81%
# Japan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Denmark:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Serbia:
#   Train: 87.38%
#   Test:  12.62%
#   Val:   0.00%
# Eswatini:
#   Train: 87.27%
#   Test:  10.91%
#   Val:   1.82%
# Norway:
#   Train: 86.44%
#   Test:  13.56%
#   Val:   0.00%
# United Kingdom:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 87.69%
#   Test:  12.31%
#   Val:   0.00%
# Cambodia:
#   Train: 85.42%
#   Test:  14.58%
#   Val:   0.00%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 84.71%
#   Test:  15.29%
#   Val:   0.00%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 87.67%
#   Test:  12.33%
#   Val:   0.00%
# Slovenia:
#   Train: 87.18%
#   Test:  12.82%
#   Val:   0.00%
# Lithuania:
#   Train: 85.96%
#   Test:  14.04%
#   Val:   0.00%
# Croatia:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 88.17%
#   Test:  11.83%
#   Val:   0.00%
# Andorra:
#   Train: 86.00%
#   Test:  14.00%
#   Val:   0.00%
#
# bicycle:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 87.43%
#   Test:  12.57%
#   Val:   0.00%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 83.67%
#   Test:  16.33%
#   Val:   0.00%
# Belgium:
#   Train: 82.81%
#   Test:  17.19%
#   Val:   0.00%
# Ecuador:
#   Train: 87.83%
#   Test:  12.17%
#   Val:   0.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Canada:
#   Train: 84.93%
#   Test:  15.07%
#   Val:   0.00%
# Russia:
#   Train: 87.72%
#   Test:  12.28%
#   Val:   0.00%
# Peru:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Bolivia:
#   Train: 88.79%
#   Test:  11.21%
#   Val:   0.00%
# Ghana:
#   Train: 87.34%
#   Test:  12.66%
#   Val:   0.00%
# Indonesia:
#   Train: 82.90%
#   Test:  10.36%
#   Val:   6.74%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 86.11%
#   Test:  13.89%
#   Val:   0.00%
# Slovakia:
#   Train: 84.44%
#   Test:  15.56%
#   Val:   0.00%
# New Zealand:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Taiwan:
#   Train: 87.62%
#   Test:  12.38%
#   Val:   0.00%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 88.16%
#   Test:  11.84%
#   Val:   0.00%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Bhutan:
#   Train: 86.89%
#   Test:  13.11%
#   Val:   0.00%
# Argentina:
#   Train: 81.01%
#   Test:  10.13%
#   Val:   8.86%
# Guatemala:
#   Train: 87.30%
#   Test:  12.70%
#   Val:   0.00%
# Finland:
#   Train: 81.03%
#   Test:  18.97%
#   Val:   0.00%
# Mexico:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Czechia:
#   Train: 88.52%
#   Test:  11.48%
#   Val:   0.00%
# Mongolia:
#   Train: 85.19%
#   Test:  14.81%
#   Val:   0.00%
# Greece:
#   Train: 88.42%
#   Test:  11.58%
#   Val:   0.00%
# Singapore:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# Austria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Arab Emirates:
#   Train: 88.31%
#   Test:  11.69%
#   Val:   0.00%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 88.41%
#   Test:  11.59%
#   Val:   0.00%
# Poland:
#   Train: 84.31%
#   Test:  15.69%
#   Val:   0.00%
# Albania:
#   Train: 82.47%
#   Test:  10.31%
#   Val:   7.22%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.81%
#   Test:  10.10%
#   Val:   9.09%
# Iceland:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Kyrgyzstan:
#   Train: 84.93%
#   Test:  15.07%
#   Val:   0.00%
# Switzerland:
#   Train: 86.44%
#   Test:  13.56%
#   Val:   0.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 85.26%
#   Test:  14.74%
#   Val:   0.00%
# Turkey:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ireland:
# ...
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 78.95%
#   Test:  21.05%
#   Val:   0.00%
# Poland:
#   Train: 88.64%
#   Test:  11.36%
#   Val:   0.00%
# Albania:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Netherlands:
#   Train: 88.06%
#   Test:  11.94%
#   Val:   0.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 81.16%
#   Test:  10.14%
#   Val:   8.70%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Turkey:
#   Train: 85.53%
#   Test:  14.47%
#   Val:   0.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 88.71%
#   Test:  11.29%
#   Val:   0.00%
# Japan:
#   Train: 86.08%
#   Test:  13.92%
#   Val:   0.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Greenland:
#   Train: 87.97%
#   Test:  12.03%
#   Val:   0.00%
# Latvia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Denmark:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 87.76%
#   Test:  12.24%
#   Val:   0.00%
# United Kingdom:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 87.27%
#   Test:  12.73%
#   Val:   0.00%
# Cambodia:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 86.15%
#   Test:  13.85%
#   Val:   0.00%
# Slovenia:
#   Train: 86.49%
#   Test:  13.51%
#   Val:   0.00%
# Lithuania:
#   Train: 84.21%
#   Test:  15.79%
#   Val:   0.00%
# Croatia:
#   Train: 86.49%
#   Test:  10.81%
#   Val:   2.70%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 85.71%
#   Test:  10.71%
#   Val:   3.57%
# Andorra:
#   Train: 88.10%
#   Test:  11.90%
#   Val:   0.00%
#
# sidewalk:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 83.17%
#   Test:  10.40%
#   Val:   6.44%
# Germany:
#   Train: 82.95%
#   Test:  10.37%
#   Val:   6.68%
# Australia:
#   Train: 83.61%
#   Test:  10.45%
#   Val:   5.94%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 86.15%
#   Test:  10.77%
#   Val:   3.08%
# Ecuador:
#   Train: 84.82%
#   Test:  10.60%
#   Val:   4.58%
# Bulgaria:
#   Train: 88.75%
#   Test:  11.25%
#   Val:   0.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Russia:
#   Train: 85.28%
#   Test:  10.66%
#   Val:   4.06%
# Peru:
#   Train: 87.78%
#   Test:  10.97%
#   Val:   1.25%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Indonesia:
#   Train: 86.54%
#   Test:  10.82%
#   Val:   2.64%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 88.16%
#   Test:  11.84%
#   Val:   0.00%
# New Zealand:
#   Train: 85.37%
#   Test:  10.67%
#   Val:   3.96%
# Taiwan:
#   Train: 81.07%
#   Test:  10.13%
#   Val:   8.80%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 82.44%
#   Test:  10.30%
#   Val:   7.26%
# Portugal:
#   Train: 87.64%
#   Test:  10.96%
#   Val:   1.40%
# South Korea:
#   Train: 84.11%
#   Test:  10.51%
#   Val:   5.38%
# Sri Lanka:
#   Train: 83.20%
#   Test:  10.40%
#   Val:   6.40%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Estonia:
#   Train: 86.02%
#   Test:  10.75%
#   Val:   3.23%
# Bhutan:
#   Train: 82.54%
#   Test:  10.32%
#   Val:   7.14%
# Argentina:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Guatemala:
#   Train: 85.57%
#   Test:  10.70%
#   Val:   3.73%
# Finland:
#   Train: 85.46%
#   Test:  10.68%
#   Val:   3.86%
# Mexico:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Czechia:
#   Train: 83.48%
#   Test:  10.43%
#   Val:   6.09%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 80.45%
#   Test:  10.06%
#   Val:   9.50%
# Singapore:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Austria:
#   Train: 84.31%
#   Test:  10.54%
#   Val:   5.15%
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Romania:
#   Train: 85.80%
#   Test:  10.72%
#   Val:   3.48%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 84.00%
#   Test:  10.50%
#   Val:   5.50%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 81.68%
#   Test:  10.21%
#   Val:   8.12%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 81.32%
#   Test:  10.17%
#   Val:   8.51%
# Switzerland:
#   Train: 87.05%
#   Test:  10.88%
#   Val:   2.07%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 84.21%
#   Test:  10.53%
#   Val:   5.26%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Turkey:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 81.42%
#   Test:  10.18%
#   Val:   8.40%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 82.19%
#   Test:  10.27%
#   Val:   7.53%
# Dominican Republic:
#   Train: 80.18%
#   Test:  10.02%
#   Val:   9.79%
# Lesotho:
#   Train: 84.55%
#   Test:  10.57%
#   Val:   4.88%
# Greenland:
#   Train: 80.59%
#   Test:  10.07%
#   Val:   9.34%
# Latvia:
#   Train: 87.80%
#   Test:  10.98%
#   Val:   1.22%
# Denmark:
#   Train: 88.38%
#   Test:  11.62%
#   Val:   0.00%
# Serbia:
#   Train: 88.66%
#   Test:  11.34%
#   Val:   0.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Kingdom:
#   Train: 80.55%
#   Test:  10.07%
#   Val:   9.38%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Cambodia:
#   Train: 81.48%
#   Test:  10.19%
#   Val:   8.33%
# Brazil:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Palestine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovenia:
#   Train: 88.35%
#   Test:  11.65%
#   Val:   0.00%
# Lithuania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Croatia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# Andorra:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
#
# motorcycle:
# Ukraine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Germany:
#   Train: 86.47%
#   Test:  13.53%
#   Val:   0.00%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Belgium:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ecuador:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Russia:
#   Train: 85.29%
#   Test:  14.71%
#   Val:   0.00%
# Peru:
#   Train: 86.67%
#   Test:  13.33%
#   Val:   0.00%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Indonesia:
#   Train: 86.15%
#   Test:  10.77%
#   Val:   3.08%
# Jordan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Botswana:
#   Train: 86.67%
#   Test:  13.33%
#   Val:   0.00%
# Slovakia:
#   Train: 77.78%
#   Test:  22.22%
#   Val:   0.00%
# New Zealand:
#   Train: 84.00%
#   Test:  16.00%
#   Val:   0.00%
# Taiwan:
#   Train: 87.50%
#   Test:  10.94%
#   Val:   1.56%
# Luxembourg:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United States:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bhutan:
#   Train: 82.14%
#   Test:  17.86%
#   Val:   0.00%
# Argentina:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Guatemala:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Finland:
#   Train: 84.21%
#   Test:  15.79%
#   Val:   0.00%
# Mexico:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# Czechia:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Mongolia:
#   Train: 84.85%
#   Test:  10.61%
#   Val:   4.55%
# Greece:
#   Train: 82.05%
#   Test:  17.95%
#   Val:   0.00%
# Singapore:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Austria:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# United Arab Emirates:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 85.00%
#   Test:  15.00%
#   Val:   0.00%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 87.23%
#   Test:  12.77%
#   Val:   0.00%
# Switzerland:
#   Train: 83.33%
#   Test:  16.67%
#   Val:   0.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 83.02%
#   Test:  16.98%
#   Val:   0.00%
# Turkey:
#   Train: 87.23%
#   Test:  12.77%
#   Val:   0.00%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Israel:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Japan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Dominican Republic:
#   Train: 87.84%
#   Test:  12.16%
#   Val:   0.00%
# Lesotho:
#   Train: 85.71%
#   Test:  14.29%
#   Val:   0.00%
# Greenland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Latvia:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# Denmark:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 81.08%
#   Test:  18.92%
#   Val:   0.00%
# United Kingdom:
#   Train: 84.78%
#   Test:  15.22%
#   Val:   0.00%
# Thailand:
#   Train: 86.27%
#   Test:  13.73%
#   Val:   0.00%
# Chile:
#   Train: 87.50%
#   Test:  12.50%
#   Val:   0.00%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 84.09%
#   Test:  15.91%
#   Val:   0.00%
# Palestine:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Spain:
#   Train: 79.25%
#   Test:  20.75%
#   Val:   0.00%
# Senegal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovenia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Croatia:
#   Train: 80.00%
#   Test:  20.00%
#   Val:   0.00%
# Malaysia:
#   Train: 88.68%
#   Test:  11.32%
#   Val:   0.00%
# Philippines:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Andorra:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
#
# traffic_sign:
# Montenegro:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ukraine:
#   Train: 80.35%
#   Test:  10.04%
#   Val:   9.61%
# Germany:
#   Train: 87.92%
#   Test:  12.08%
#   Val:   0.00%
# Australia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kenya:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Belgium:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ecuador:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bulgaria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Hungary:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Italy:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Canada:
#   Train: 83.68%
#   Test:  10.46%
#   Val:   5.86%
# Russia:
#   Train: 88.34%
#   Test:  11.66%
#   Val:   0.00%
# Peru:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bolivia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Ghana:
#   Train: 88.85%
#   Test:  11.15%
#   Val:   0.00%
# Indonesia:
#   Train: 86.64%
#   Test:  10.83%
#   Val:   2.53%
# Jordan:
#   Train: 88.57%
#   Test:  11.07%
#   Val:   0.36%
# Botswana:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Slovakia:
#   Train: 83.58%
#   Test:  10.45%
#   Val:   5.97%
# New Zealand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Taiwan:
#   Train: 88.58%
#   Test:  11.07%
#   Val:   0.35%
# Luxembourg:
#   Train: 88.89%
#   Test:  11.11%
#   Val:   0.00%
# United States:
#   Train: 85.47%
#   Test:  10.68%
#   Val:   3.85%
# Portugal:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Korea:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sri Lanka:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Bangladesh:
#   Train: 83.33%
#   Test:  10.42%
#   Val:   6.25%
# Estonia:
#   Train: 87.00%
#   Test:  13.00%
#   Val:   0.00%
# Bhutan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Argentina:
#   Train: 81.16%
#   Test:  10.14%
#   Val:   8.70%
# Guatemala:
#   Train: 87.57%
#   Test:  10.95%
#   Val:   1.48%
# Finland:
#   Train: 87.10%
#   Test:  12.90%
#   Val:   0.00%
# Mexico:
#   Train: 80.33%
#   Test:  10.04%
#   Val:   9.62%
# Czechia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Mongolia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greece:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Singapore:
#   Train: 88.59%
#   Test:  11.07%
#   Val:   0.34%
# Austria:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# United Arab Emirates:
#   Train: 85.11%
#   Test:  10.64%
#   Val:   4.26%
# Romania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# South Africa:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Poland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Albania:
#   Train: 88.50%
#   Test:  11.50%
#   Val:   0.00%
# Netherlands:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Uruguay:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Iceland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Kyrgyzstan:
#   Train: 82.13%
#   Test:  10.27%
#   Val:   7.60%
# Switzerland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Sweden:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Nigeria:
#   Train: 88.24%
#   Test:  11.76%
#   Val:   0.00%
# Colombia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# France:
#   Train: 87.35%
#   Test:  12.65%
#   Val:   0.00%
# Turkey:
#   Train: 85.19%
#   Test:  10.65%
#   Val:   4.17%
# Ireland:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# North Macedonia:
#   Train: 88.03%
#   Test:  11.97%
#   Val:   0.00%
# Israel:
#   Train: 88.71%
#   Test:  11.29%
#   Val:   0.00%
# Japan:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Dominican Republic:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lesotho:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Greenland:
#   Train: 88.62%
#   Test:  11.38%
#   Val:   0.00%
# Latvia:
#   Train: 86.72%
#   Test:  13.28%
#   Val:   0.00%
# Denmark:
#   Train: 85.64%
#   Test:  14.36%
#   Val:   0.00%
# Serbia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Eswatini:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Norway:
#   Train: 87.62%
#   Test:  10.95%
#   Val:   1.43%
# United Kingdom:
#   Train: 87.97%
#   Test:  12.03%
#   Val:   0.00%
# Thailand:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Chile:
#   Train: 87.77%
#   Test:  12.23%
#   Val:   0.00%
# Cambodia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Brazil:
#   Train: 88.62%
#   Test:  11.38%
#   Val:   0.00%
# Palestine:
#   Train: 87.07%
#   Test:  10.88%
#   Val:   2.04%
# Spain:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Senegal:
#   Train: 86.58%
#   Test:  10.82%
#   Val:   2.60%
# Slovenia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Lithuania:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Croatia:
#   Train: 85.88%
#   Test:  10.73%
#   Val:   3.39%
# Malaysia:
#   Train: 80.00%
#   Test:  10.00%
#   Val:   10.00%
# Philippines:
#   Train: 81.31%
#   Test:  10.16%
#   Val:   8.52%
# Andorra:
#   Train: 86.44%
#   Test:  13.56%
#   Val:   0.00%
#
# Segments with zero images (skipped):
# - bus/Botswana
# - bus/Latvia
# - bus/Cambodia
# - bus/Croatia
# - train/Estonia
# - rider/Jordan
# - rider/Luxembourg
# - rider/Estonia
# - rider/Romania
# - rider/Denmark
# - rider/Lithuania
# - truck/Sweden
# - motorcycle/Montenegro
# - motorcycle/Italy
# - motorcycle/Estonia
# - motorcycle/Albania
# - motorcycle/Eswatini
# - motorcycle/Lithuania

# %%
segments_to_skip = list(set([i.split("/")[0] for i in segments_to_skip]))

# %%
COUNTRIES = ['Albania', 'Andorra', 'Australia', 'Austria', 'Bangladesh', 'Belgium', 'Bhutan', 'Bolivia', 'Brazil', 'Bulgaria', 'Cambodia', 'Canada', 'Chile', 'Colombia', 'Croatia', 'Czechia', 'Denmark', 'Dominican Republic', 'Ecuador', 'Estonia', 'Eswatini', 'Finland', 'France', 'Germany', 'Greece', 'Guatemala', 'Hungary', 'Iceland', 'Indonesia', 'Ireland', 'Israel', 'Italy', 'Japan', 'Jordan', 'Latvia', 'Lesotho', 'Lithuania', 'Luxembourg', 'Malaysia', 'Mexico', 'Montenegro', 'Netherlands', 'New Zealand', 'North Macedonia', 'Norway', 'Palestine', 'Peru', 'Poland', 'Portugal', 'Romania', 'Russia', 'Serbia', 'Singapore', 'Slovakia', 'Slovenia', 'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'United Arab Emirates', 'United Kingdom', 'United States']
# Create final_datasets directory structure for each segment type
for segment_type in segment_type_country_image_counts.keys():
    if segment_type in segments_to_skip:
        continue
        
    # Create segment-specific final_datasets directory
    segment_final_dir = os.path.join(base_dir, segment_type, "final_datasets")
    
    # Create train/test/val splits
    for split in ["train", "test", "val"]:
        split_dir = os.path.join(segment_final_dir, split)
        os.makedirs(split_dir, exist_ok=True)
        
        # Create country subdirectories
        for country in COUNTRIES:
            country_dir = os.path.join(split_dir, country)
            os.makedirs(country_dir, exist_ok=True)
    
    # Copy images to new structure
    for country in segment_type_country_image_counts[segment_type].keys():
        # Source directories for each split
        train_src = os.path.join(base_dir, segment_type, country, "train")
        test_src = os.path.join(base_dir, segment_type, country, "test")
        val_src = os.path.join(base_dir, segment_type, country, "val")
        
        # Destination directories
        train_dst = os.path.join(segment_final_dir, "train", country)
        test_dst = os.path.join(segment_final_dir, "test", country)
        val_dst = os.path.join(segment_final_dir, "val", country)
        
        # Copy files for each split
        for src, dst in [(train_src, train_dst), (test_src, test_dst), (val_src, val_dst)]:
            if os.path.exists(src):
                for img in os.listdir(src):
                    src_path = os.path.join(src, img)
                    dst_path = os.path.join(dst, img)
                    shutil.copy2(src_path, dst_path)

print("Dataset restructuring completed!")
# Out:
# Dataset restructuring completed!
