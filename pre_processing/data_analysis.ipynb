# %% [markdown]
# # Understanding which segments contain most information

# %%
import os
from PIL import Image
import numpy as np
from tqdm import tqdm

# Root folder containing the segmentation classes
ROOT_DIR = "/home/andreafabbricatore/rainbot/pre_processing/segmented"  # <- CHANGE THIS

def compute_mask_ratio(image_path):
    img = Image.open(image_path).convert("L")  # grayscale
    arr = np.array(img)
    total_pixels = arr.size
    non_black_pixels = np.count_nonzero(arr)
    return non_black_pixels / total_pixels

segment_ratios = {}

segment_classes = sorted([d for d in os.listdir(ROOT_DIR) if os.path.isdir(os.path.join(ROOT_DIR, d))])

for segment_class in tqdm(segment_classes, desc="Segment Classes"):
    class_path = os.path.join(ROOT_DIR, segment_class)

    ratios = []
    country_dirs = sorted([d for d in os.listdir(class_path) if os.path.isdir(os.path.join(class_path, d))])

    for country in country_dirs:
        country_path = os.path.join(class_path, country)

        image_files = sorted([f for f in os.listdir(country_path) if f.endswith(".png")])
        print(f"Country: {country}. Images: {len(image_files)}")
        for file in image_files:
            image_path = os.path.join(country_path, file)
            try:
                ratio = compute_mask_ratio(image_path)
                ratios.append(ratio)
            except Exception as e:
                print(f"Error reading {image_path}: {e}")

    if ratios:
        avg_ratio = np.mean(ratios)
        segment_ratios[segment_class] = avg_ratio

# Sort and print results
print("\n--- Segment Scores ---")
sorted_segments = sorted(segment_ratios.items(), key=lambda x: x[1], reverse=True)
for segment, score in sorted_segments:
    print(f"{segment}: {score:.4f}")
# Out:
# Segment Classes:   0%|          | 0/17 [00:00<?, ?it/s]
# Country: New Zealand. Images: 132
# Country: United Kingdom. Images: 697
# Country: United States. Images: 456
# Segment Classes:   6%|▌         | 1/17 [00:03<00:54,  3.41s/it]
# Country: New Zealand. Images: 1270
# Country: United Kingdom. Images: 4176
# Country: United States. Images: 3810
# Segment Classes:  12%|█▏        | 2/17 [00:38<05:26, 21.78s/it]
# Country: New Zealand. Images: 260
# Country: United Kingdom. Images: 499
# Country: United States. Images: 484
# Segment Classes:  18%|█▊        | 3/17 [00:41<03:07, 13.36s/it]
# Country: New Zealand. Images: 1111
# Country: United Kingdom. Images: 3773
# Segment Classes:  18%|█▊        | 3/17 [00:47<03:43, 15.99s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 34
#      32 image_path = os.path.join(country_path, file)
#      33 try:
# ---> 34     ratio = compute_mask_ratio(image_path)
#      35     ratios.append(ratio)
#      36 except Exception as e:
#
# Cell In[1], line 13, in compute_mask_ratio(image_path)
#      11 arr = np.array(img)
#      12 total_pixels = arr.size
# ---> 13 non_black_pixels = np.count_nonzero(arr)
#      14 return non_black_pixels / total_pixels
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/numeric.py:476, in count_nonzero(a, axis, keepdims)
#     417 """
#     418 Counts the number of non-zero values in the array ``a``.
#     419
#    (...)
#     473        [3]])
#     474 """
#     475 if axis is None and not keepdims:
# --> 476     return multiarray.count_nonzero(a)
#     478 a = asanyarray(a)
#     480 # TODO: this works around .astype(bool) not working properly (gh-9847)
#
# KeyboardInterrupt:

# %%
def delete_black_images(root_dir):
    """
    Delete images that have more than threshold% black pixels
    """
    deleted_count = 0
    total_count = 0
    
    for segment_class in tqdm(os.listdir(root_dir), desc="Processing classes"):
        class_path = os.path.join(root_dir, segment_class)
        if not os.path.isdir(class_path):
            continue
            
        for country in os.listdir(class_path):
            country_path = os.path.join(class_path, country)
            if not os.path.isdir(country_path):
                continue
                
            for file in os.listdir(country_path):
                if not file.endswith('.png'):
                    continue
                    
                image_path = os.path.join(country_path, file)
                total_count += 1
                
                try:
                    ratio = compute_mask_ratio(image_path)
                    if ratio <0.05:  # If more than 95% is black
                        os.remove(image_path)
                        deleted_count += 1
                except Exception as e:
                    print(f"Error processing {image_path}: {e}")
    
    print(f"\nDeleted {deleted_count} out of {total_count} images")
    print(f"Remaining images: {total_count - deleted_count}")

# Execute the deletion
delete_black_images(ROOT_DIR)
# Out:
# Processing classes: 100%|██████████| 17/17 [05:45<00:00, 20.33s/it]
# Deleted 59851 out of 93308 images
# Remaining images: 33457

# %%
def analyze_segment_coverage():
    # Initialize scores dictionary
    image_scores = {}
    
    # Get all original images
    original_images_dir = "/home/andreafabbricatore/rainbot/pre_processing/datasets/extra_data"
    segmented_dir = "/home/andreafabbricatore/rainbot/pre_processing/segmented"
    
    # First, initialize scores for all original images
    for country in os.listdir(original_images_dir):
        country_path = os.path.join(original_images_dir, country)
        if not os.path.isdir(country_path):
            continue
            
        for image_file in os.listdir(country_path):
            if image_file.lower().endswith(('.png', '.jpg', '.jpeg')):
                base_name = os.path.splitext(image_file)[0]
                image_scores[f"{country}/{base_name}"] = 0
    
    # Check each segment class folder
    for segment_class in os.listdir(segmented_dir):
        segment_path = os.path.join(segmented_dir, segment_class)
        if not os.path.isdir(segment_path):
            continue
            
        # Check each country in the segment class
        for country in os.listdir(segment_path):
            country_path = os.path.join(segment_path, country)
            if not os.path.isdir(country_path):
                continue
                
            # Check each segmented image
            for segment_file in os.listdir(country_path):
                if not segment_file.endswith('.png'):
                    continue
                    
                # Extract original image name from segment filename
                # Format is: original_name_segmentname.png
                original_name = '_'.join(segment_file.split('_')[:-1])
                
                # Increment score for this original image
                key = f"{country}/{original_name}"
                if key in image_scores:
                    image_scores[key] += 1
    
    # Sort images by score in descending order
    sorted_scores = sorted(image_scores.items(), key=lambda x: x[1], reverse=True)
    
    # Print results
    print("\nImage Coverage Analysis:")
    print("-----------------------")
    for image_path, score in sorted_scores:
        print(f"{image_path}: {score} segments")
    
    return sorted_scores

# Execute the analysis
segment_coverage = analyze_segment_coverage()
# Out:
# Image Coverage Analysis:
# -----------------------
# United States/3477: 7 segments
# United States/0695: 6 segments
# United States/3187: 6 segments
# United States/3973: 6 segments
# United States/4162: 6 segments
# United States/3594: 6 segments
# United Kingdom/2507: 6 segments
# United Kingdom/0899: 6 segments
# United Kingdom/4612: 6 segments
# United Kingdom/4750: 6 segments
# United Kingdom/3910: 6 segments
# United Kingdom/4418: 6 segments
# United Kingdom/1486: 6 segments
# United Kingdom/0228: 6 segments
# United Kingdom/1274: 6 segments
# United Kingdom/1768: 6 segments
#  ('United Kingdom/3336', 5),
#  ('United Kingdom/1965', 5),
#  ('United Kingdom/4082', 5),
#  ('United Kingdom/1866', 5),
#  ('United Kingdom/2442', 5),
#  ('United Kingdom/4186', 5),
#  ('United Kingdom/1224', 5),
#  ('United Kingdom/3219', 5),
#  ('United Kingdom/4527', 5),
#  ('United Kingdom/1820', 5),
#  ('United Kingdom/2687', 5),
#  ('United Kingdom/4806', 5),
#  ('United Kingdom/3741', 5),
#  ('United Kingdom/4743', 5),
#  ('United Kingdom/3928', 5),
#  ('United Kingdom/0042', 5),
#  ('New Zealand/1536', 4),
#  ('New Zealand/1680', 4),
#  ('New Zealand/0348', 4),
#  ('New Zealand/0753', 4),
#  ('New Zealand/0528', 4),
#  ('New Zealand/0195', 4),
#  ('New Zealand/1016', 4),
#  ('New Zealand/0686', 4),
#  ('New Zealand/0765', 4),
#  ('New Zealand/1445', 4),
#  ('New Zealand/0089', 4),
#  ('New Zealand/1091', 4),
#  ('New Zealand/0235', 4),
#  ('New Zealand/0050', 4),
#  ('New Zealand/0177', 4),
#  ('New Zealand/0062', 4),
#  ('New Zealand/0386', 4),
#  ('New Zealand/1511', 4),
#  ('New Zealand/1492', 4),
#  ('New Zealand/1647', 4),
#  ('New Zealand/1174', 4),
#  ('New Zealand/0823', 4),
#  ('New Zealand/0136', 4),
#  ('New Zealand/0220', 4),
#  ('New Zealand/0424', 4),
#  ('New Zealand/1021', 4),
#  ('New Zealand/1321', 4),
#  ('New Zealand/0713', 4),
#  ('New Zealand/1406', 4),
#  ('New Zealand/1058', 4),
#  ('New Zealand/0733', 4),
#  ('New Zealand/0929', 4),
#  ('New Zealand/0452', 4),
#  ('New Zealand/0075', 4),
#  ('New Zealand/0335', 4),
#  ('New Zealand/0658', 4),
#  ('New Zealand/0978', 4),
#  ('New Zealand/0460', 4),
#  ('New Zealand/0533', 4),
#  ('New Zealand/1133', 4),
#  ('New Zealand/1415', 4),
#  ('New Zealand/0074', 4),
#  ('New Zealand/0103', 4),
#  ('New Zealand/0307', 4),
#  ('New Zealand/0704', 4),
#  ('New Zealand/0449', 4),
#  ('New Zealand/0716', 4),
#  ('New Zealand/0692', 4),
#  ('New Zealand/0797', 4),
#  ('New Zealand/0693', 4),
#  ('New Zealand/0299', 4),
#  ('New Zealand/0580', 4),
#  ('New Zealand/0607', 4),
#  ('New Zealand/0229', 4),
#  ('New Zealand/0233', 4),
#  ('New Zealand/1081', 4),
#  ('New Zealand/0669', 4),
#  ('New Zealand/1545', 4),
#  ('New Zealand/1360', 4),
#  ('New Zealand/0279', 4),
#  ('New Zealand/0657', 4),
#  ('New Zealand/1537', 4),
#  ('New Zealand/0935', 4),
#  ('New Zealand/1106', 4),
#  ('New Zealand/0193', 4),
#  ('New Zealand/0119', 4),
#  ('New Zealand/0387', 4),
#  ('New Zealand/0313', 4),
#  ('New Zealand/0019', 4),
#  ('New Zealand/0678', 4),
#  ('New Zealand/0082', 4),
#  ('New Zealand/1540', 4),
#  ('New Zealand/0788', 4),
#  ('New Zealand/0527', 4),
#  ('New Zealand/0413', 4),
#  ('New Zealand/1096', 4),
#  ('New Zealand/0940', 4),
#  ('New Zealand/0565', 4),
#  ('New Zealand/0581', 4),
#  ('New Zealand/0225', 4),
#  ('New Zealand/0410', 4),
#  ('New Zealand/0560', 4),
#  ('New Zealand/0115', 4),
#  ('New Zealand/0740', 4),
#  ('New Zealand/0567', 4),
#  ('New Zealand/1025', 4),
#  ('New Zealand/1648', 4),
#  ('New Zealand/0719', 4),
#  ('New Zealand/1512', 4),
#  ('New Zealand/0532', 4),
#  ('New Zealand/1274', 4),
#  ('New Zealand/0300', 4),
#  ('New Zealand/1678', 4),
#  ('New Zealand/1400', 4),
#  ('New Zealand/0743', 4),
#  ('New Zealand/0569', 4),
#  ('New Zealand/0006', 4),
#  ('New Zealand/0960', 4),
#  ('New Zealand/0440', 4),
#  ('New Zealand/0467', 4),
#  ('New Zealand/1203', 4),
#  ('New Zealand/1095', 4),
#  ('New Zealand/0747', 4),
#  ('New Zealand/0132', 4),
#  ('New Zealand/0898', 4),
#  ('New Zealand/1059', 4),
#  ('New Zealand/0291', 4),
#  ('New Zealand/0801', 4),
#  ('New Zealand/0118', 4),
#  ('New Zealand/1284', 4),
#  ('New Zealand/0294', 4),
#  ('New Zealand/1001', 4),
#  ('New Zealand/0947', 4),
#  ('New Zealand/1621', 4),
#  ('New Zealand/1288', 4),
#  ('New Zealand/1447', 4),
#  ('New Zealand/0121', 4),
#  ('New Zealand/1496', 4),
#  ('New Zealand/0675', 4),
#  ('New Zealand/0628', 4),
#  ('New Zealand/0175', 4),
#  ('New Zealand/0323', 4),
#  ('New Zealand/0185', 4),
#  ('New Zealand/1408', 4),
#  ('New Zealand/1048', 4),
#  ('New Zealand/0566', 4),
#  ('New Zealand/0016', 4),
#  ('New Zealand/0739', 4),
#  ('New Zealand/0808', 4),
#  ('New Zealand/0396', 4),
#  ('New Zealand/0356', 4),
#  ('New Zealand/0368', 4),
#  ('New Zealand/0057', 4),
#  ('New Zealand/0377', 4),
#  ('New Zealand/0078', 4),
#  ('New Zealand/0709', 4),
#  ('New Zealand/0752', 4),
#  ('New Zealand/0645', 4),
#  ('New Zealand/1542', 4),
#  ('New Zealand/1449', 4),
#  ('New Zealand/0701', 4),
#  ('New Zealand/0910', 4),
#  ('New Zealand/1172', 4),
#  ('New Zealand/1401', 4),
#  ('United States/1686', 4),
#  ('United States/4941', 4),
#  ('United States/1050', 4),
#  ('United States/1680', 4),
#  ('United States/3838', 4),
#  ('United States/1206', 4),
#  ('United States/3276', 4),
#  ('United States/0348', 4),
#  ('United States/4118', 4),
#  ('United States/4127', 4),
#  ('United States/4482', 4),
#  ('United States/4450', 4),
#  ('United States/3087', 4),
#  ('United States/1669', 4),
#  ('United States/1583', 4),
#  ('United States/5000', 4),
#  ('United States/2177', 4),
#  ('United States/2506', 4),
#  ('United States/0421', 4),
#  ('United States/2792', 4),
#  ('United States/1603', 4),
#  ('United States/3958', 4),
#  ('United States/4679', 4),
#  ('United States/3343', 4),
#  ...]

# %%
# Create a new directory for filtered images
import shutil
import os

filtered_dir = os.path.join(ROOT_DIR, "filtered_images")
os.makedirs(filtered_dir, exist_ok=True)

# Group images by country
country_images = {}
for image_path, score in segment_coverage:
    country = image_path.split('/')[0]
    if country not in country_images:
        country_images[country] = []
    country_images[country].append((image_path, score))

# Process each country
for country, images in country_images.items():
    # Sort images by score and take top 450
    top_images = sorted(images, key=lambda x: x[1], reverse=True)[:450]
    
    # Create country directory in filtered folder
    country_filtered_dir = os.path.join(filtered_dir, country)
    os.makedirs(country_filtered_dir, exist_ok=True)
    
    # Copy top images to filtered directory
    for image_path, _ in top_images:
        # Get the original image name
        # Define the image directory path
        IMAGE_DIR = "/home/andreafabbricatore/rainbot/pre_processing/datasets/extra_data"

        # Extract the image ID from the path
        image_id = image_path.split('/')[-1]
        
        # Construct source path with .jpg extension
        source_path = os.path.join(IMAGE_DIR, country, f"{image_id}.jpg")
        
        # Verify source file exists before copying
        if not os.path.exists(source_path):
            print(f"Warning: Source file not found: {source_path}")
            continue
            
        dest_path = os.path.join(country_filtered_dir, f"{image_id}.jpg")
        
        try:
            # Copy the image
            shutil.copy2(source_path, dest_path)
            print(f"Copied {image_path} to filtered directory")
        except Exception as e:
            print(f"Error copying {image_path}: {str(e)}")

print(f"\nFiltered images have been saved to: {filtered_dir}")
# Out:
# Copied United States/3477 to filtered directory
# Copied United States/0695 to filtered directory
# Copied United States/3187 to filtered directory
# Copied United States/3973 to filtered directory
# Copied United States/4162 to filtered directory
# Copied United States/3594 to filtered directory
# Copied United States/1536 to filtered directory
# Copied United States/0397 to filtered directory
# Copied United States/1612 to filtered directory
# Copied United States/3340 to filtered directory
# Copied United States/3291 to filtered directory
# Copied United States/3641 to filtered directory
# Copied United States/4775 to filtered directory
# Copied United States/3934 to filtered directory
# Copied United States/0216 to filtered directory
# Copied United States/3188 to filtered directory
# Copied United States/1035 to filtered directory
# Copied United States/3602 to filtered directory
# Copied United States/0321 to filtered directory
# Copied United States/0172 to filtered directory
# Copied United States/1967 to filtered directory
# Copied United States/0775 to filtered directory
# Copied United States/1484 to filtered directory
# Copied United States/4976 to filtered directory
# Copied United States/3797 to filtered directory
# Copied United States/1659 to filtered directory
# Copied United States/1914 to filtered directory
# Copied United States/3609 to filtered directory
# Copied United States/2424 to filtered directory
# Copied United States/1165 to filtered directory
# Copied United States/2710 to filtered directory
# Copied United States/2099 to filtered directory
# Copied United States/3355 to filtered directory
# Copied United States/4464 to filtered directory
# Copied United States/1058 to filtered directory
# Copied United States/4935 to filtered directory
# Copied United States/2053 to filtered directory
# Copied United States/1585 to filtered directory
# Copied United States/3314 to filtered directory
# Copied United States/4249 to filtered directory
# Copied United States/2212 to filtered directory
# Copied United States/4601 to filtered directory
# Copied United States/4873 to filtered directory
# Copied United States/1954 to filtered directory
# Copied United States/1394 to filtered directory
# Copied United States/2121 to filtered directory
# Copied United States/3742 to filtered directory
# Copied United States/2724 to filtered directory
# Copied United States/2040 to filtered directory
# Copied United States/3185 to filtered directory
# Copied United States/3119 to filtered directory
# Copied United States/2864 to filtered directory
# Copied United States/2512 to filtered directory
# Copied United States/1125 to filtered directory
# Copied United States/0718 to filtered directory
# Copied United States/2206 to filtered directory
# Copied United States/1109 to filtered directory
# Copied United States/0111 to filtered directory
# Copied United States/4210 to filtered directory
# Copied United States/3118 to filtered directory
# Copied United States/4336 to filtered directory
# Copied United States/4966 to filtered directory
# Copied United States/3383 to filtered directory
# Copied United States/0586 to filtered directory
# Copied United States/2471 to filtered directory
# Copied United States/4551 to filtered directory
# Copied United States/2889 to filtered directory
# Copied United States/0199 to filtered directory
# Copied United States/4216 to filtered directory
# Copied United States/3603 to filtered directory
# Copied United States/0293 to filtered directory
# Copied United States/3360 to filtered directory
# Copied United States/2763 to filtered directory
# Copied United States/3513 to filtered directory
# Copied United States/3044 to filtered directory
# Copied United States/4376 to filtered directory
# Copied United States/0433 to filtered directory
# Copied United States/3467 to filtered directory
# Copied United States/0722 to filtered directory
# Copied United States/3919 to filtered directory
# Copied United States/0344 to filtered directory
# Copied United States/3256 to filtered directory
# Copied United States/1873 to filtered directory
# Copied United States/1113 to filtered directory
# Copied United States/3143 to filtered directory
# Copied United States/0496 to filtered directory
# Copied United States/4752 to filtered directory
# Copied United States/2007 to filtered directory
# Copied United States/2585 to filtered directory
# Copied United States/0837 to filtered directory
# Copied United States/2183 to filtered directory
# Copied United States/2167 to filtered directory
# Copied United States/1053 to filtered directory
# Copied United States/3204 to filtered directory
# Copied United States/0565 to filtered directory
# Copied United States/1403 to filtered directory
# Copied United States/2298 to filtered directory
# Copied United States/1827 to filtered directory
# Copied United States/0905 to filtered directory
# Copied United States/1576 to filtered directory
# Copied United States/3664 to filtered directory
# Copied United States/1347 to filtered directory
# Copied United States/3193 to filtered directory
# Copied United States/1879 to filtered directory
# Copied United States/3063 to filtered directory
# Copied United States/0592 to filtered directory
# Copied United States/4660 to filtered directory
# Copied United States/0202 to filtered directory
# Copied United States/3940 to filtered directory
# Copied United States/1341 to filtered directory
# Copied United States/3454 to filtered directory
# Copied United States/0960 to filtered directory
# Copied United States/1935 to filtered directory
# Copied United States/4321 to filtered directory
# Copied United States/2785 to filtered directory
# Copied United States/4776 to filtered directory
# Copied United States/4930 to filtered directory
# Copied United States/3591 to filtered directory
# Copied United States/3443 to filtered directory
# Copied United States/1605 to filtered directory
# Copied United States/0480 to filtered directory
# Copied United States/2472 to filtered directory
# Copied United States/1297 to filtered directory
# Copied United States/1789 to filtered directory
# Copied United States/3120 to filtered directory
# Copied United States/4393 to filtered directory
# Copied United States/1875 to filtered directory
# Copied United States/2830 to filtered directory
# Copied United States/3025 to filtered directory
# Copied United States/1088 to filtered directory
# Copied United States/1795 to filtered directory
# Copied United States/2416 to filtered directory
# Copied United States/0723 to filtered directory
# Copied United States/0947 to filtered directory
# Copied United States/1621 to filtered directory
# Copied United States/3258 to filtered directory
# Copied United States/1066 to filtered directory
# Copied United States/3150 to filtered directory
# Copied United States/1534 to filtered directory
# Copied United States/0582 to filtered directory
# Copied United States/0246 to filtered directory
# Copied United States/3449 to filtered directory
# Copied United States/2912 to filtered directory
# Copied United States/1710 to filtered directory
# Copied United States/2272 to filtered directory
# Copied United States/1265 to filtered directory
# Copied United States/0078 to filtered directory
# Copied United States/0752 to filtered directory
# Copied United States/1759 to filtered directory
# Copied United States/4237 to filtered directory
# Copied United States/2644 to filtered directory
# Copied United States/0422 to filtered directory
# Copied United States/1686 to filtered directory
# Copied United States/4941 to filtered directory
# Copied United States/1050 to filtered directory
# Copied United States/1680 to filtered directory
# Copied United States/3838 to filtered directory
# Copied United States/1206 to filtered directory
# Copied United States/3276 to filtered directory
# Copied United States/0348 to filtered directory
# Copied United States/4118 to filtered directory
# Copied United States/4127 to filtered directory
# Copied United States/4482 to filtered directory
# Copied United States/4450 to filtered directory
# Copied United States/3087 to filtered directory
# Copied United States/1669 to filtered directory
# Copied United States/1583 to filtered directory
# Copied United States/5000 to filtered directory
# Copied United States/2177 to filtered directory
# Copied United States/2506 to filtered directory
# Copied United States/0421 to filtered directory
# Copied United States/2792 to filtered directory
# Copied United States/1603 to filtered directory
# Copied United States/3958 to filtered directory
# Copied United States/2337 to filtered directory
# Copied United States/2466 to filtered directory
# Copied United States/4340 to filtered directory
# Copied United States/3325 to filtered directory
# Copied United States/4815 to filtered directory
# Copied United States/0983 to filtered directory
# Copied United States/1793 to filtered directory
# Copied United States/1697 to filtered directory
# Copied United States/2791 to filtered directory
# Copied United States/1535 to filtered directory
# Copied United States/0980 to filtered directory
# Copied United States/2895 to filtered directory
# Copied United States/0492 to filtered directory
# Copied United States/4997 to filtered directory
# Copied United States/4059 to filtered directory
# Copied United States/4309 to filtered directory
# Copied United States/0578 to filtered directory
# Copied United States/2182 to filtered directory
# Copied United States/3341 to filtered directory
# Copied United States/4635 to filtered directory
# Copied United States/1064 to filtered directory
# Copied United States/0308 to filtered directory
# Copied United States/4203 to filtered directory
# Copied United States/3726 to filtered directory
# Copied United States/1457 to filtered directory
# Copied United States/4916 to filtered directory
# Copied United States/4312 to filtered directory
# Copied United States/2940 to filtered directory
# Copied United States/0973 to filtered directory
# Copied United States/2576 to filtered directory
# Copied United States/3759 to filtered directory
# Copied United States/3693 to filtered directory
# Copied United States/2045 to filtered directory
# Copied United States/0169 to filtered directory
# Copied United States/0665 to filtered directory
# Copied United States/0751 to filtered directory
# Copied United States/1927 to filtered directory
# Copied United States/4062 to filtered directory
# Copied United States/3880 to filtered directory
# Copied United States/2157 to filtered directory
# Copied United States/2074 to filtered directory
# Copied United States/3398 to filtered directory
# Copied United States/3064 to filtered directory
# Copied United States/1249 to filtered directory
# Copied United States/1663 to filtered directory
# Copied United States/2939 to filtered directory
# Copied United States/0700 to filtered directory
# Copied United States/4665 to filtered directory
# Copied United States/0501 to filtered directory
# Copied United States/4106 to filtered directory
# Copied United States/3456 to filtered directory
# Copied United States/1392 to filtered directory
# Copied United States/2817 to filtered directory
# Copied United States/0771 to filtered directory
# Copied United States/3615 to filtered directory
# Copied United States/2422 to filtered directory
# Copied United States/0798 to filtered directory
# Copied United States/3775 to filtered directory
# Copied United States/1881 to filtered directory
# Copied United States/0171 to filtered directory
# Copied United States/4070 to filtered directory
# Copied United States/4233 to filtered directory
# Copied United States/0214 to filtered directory
# Copied United States/0635 to filtered directory
# Copied United States/4702 to filtered directory
# Copied United States/2049 to filtered directory
# Copied United States/2717 to filtered directory
# Copied United States/0872 to filtered directory
# Copied United States/3198 to filtered directory
# Copied United States/4335 to filtered directory
# Copied United States/1500 to filtered directory
# Copied United States/2096 to filtered directory
# Copied United States/0113 to filtered directory
# Copied United States/0268 to filtered directory
# Copied United States/1979 to filtered directory
# Copied United States/4426 to filtered directory
# Copied United States/4047 to filtered directory
# Copied United States/2546 to filtered directory
# Copied United States/4599 to filtered directory
# Copied United States/4529 to filtered directory
# Copied United States/3201 to filtered directory
# Copied United States/0842 to filtered directory
# Copied United States/2405 to filtered directory
# Copied United States/2730 to filtered directory
# Copied United States/0859 to filtered directory
# Copied United States/4293 to filtered directory
# Copied United States/1418 to filtered directory
# Copied United States/3224 to filtered directory
# Copied United States/1210 to filtered directory
# Copied United States/1411 to filtered directory
# Copied United States/1309 to filtered directory
# Copied United States/2528 to filtered directory
# Copied United States/4739 to filtered directory
# Copied United States/3747 to filtered directory
# Copied United States/2804 to filtered directory
# Copied United States/4698 to filtered directory
# Copied United States/2310 to filtered directory
# Copied United States/4024 to filtered directory
# Copied United States/3977 to filtered directory
# Copied United States/4795 to filtered directory
# Copied United States/0812 to filtered directory
# Copied United States/0439 to filtered directory
# Copied United States/0007 to filtered directory
# Copied United States/3251 to filtered directory
# Copied United States/1804 to filtered directory
# Copied United States/2329 to filtered directory
# Copied United States/2441 to filtered directory
# Copied United States/4829 to filtered directory
# Copied United States/0818 to filtered directory
# Copied United States/3302 to filtered directory
# Copied United States/3897 to filtered directory
# Copied United States/2148 to filtered directory
# Copied United States/1316 to filtered directory
# Copied United States/1286 to filtered directory
# Copied United States/2002 to filtered directory
# Copied United States/2859 to filtered directory
# Copied United States/1584 to filtered directory
# Copied United States/3186 to filtered directory
# Copied United States/3281 to filtered directory
# Copied United States/1888 to filtered directory
# Copied United States/3194 to filtered directory
# Copied United States/3318 to filtered directory
# Copied United States/4452 to filtered directory
# Copied United States/0245 to filtered directory
# Copied United States/4433 to filtered directory
# Copied United States/3146 to filtered directory
# Copied United States/4435 to filtered directory
# Copied United States/3163 to filtered directory
# Copied United States/2962 to filtered directory
# Copied United States/2985 to filtered directory
# Copied United States/0283 to filtered directory
# Copied United States/0149 to filtered directory
# Copied United States/1018 to filtered directory
# Copied United States/3095 to filtered directory
# Copied United States/1322 to filtered directory
# Copied United States/4387 to filtered directory
# Copied United States/0913 to filtered directory
# Copied United States/4063 to filtered directory
# Copied United States/0039 to filtered directory
# Copied United States/3269 to filtered directory
# Copied United States/3389 to filtered directory
# Copied United States/2489 to filtered directory
# Copied United States/4484 to filtered directory
# Copied United States/3310 to filtered directory
# Copied United States/2082 to filtered directory
# Copied United States/0145 to filtered directory
# Copied United States/3091 to filtered directory
# Copied United States/4644 to filtered directory
# Copied United States/3922 to filtered directory
# Copied United States/0181 to filtered directory
# Copied United States/2088 to filtered directory
# Copied United States/1798 to filtered directory
# Copied United States/1722 to filtered directory
# Copied United States/3601 to filtered directory
# Copied United States/2023 to filtered directory
# Copied United States/4365 to filtered directory
# Copied United States/3656 to filtered directory
# Copied United States/4308 to filtered directory
# Copied United States/1769 to filtered directory
# Copied United States/1622 to filtered directory
# Copied United States/3465 to filtered directory
# Copied United States/0374 to filtered directory
# Copied United States/4994 to filtered directory
# Copied United States/0262 to filtered directory
# Copied United States/3981 to filtered directory
# Copied United States/1493 to filtered directory
# Copied United States/2818 to filtered directory
# Copied United States/3199 to filtered directory
# Copied United States/3009 to filtered directory
# Copied United States/2371 to filtered directory
# Copied United States/2390 to filtered directory
# Copied United States/2745 to filtered directory
# Copied United States/2511 to filtered directory
# Copied United States/1995 to filtered directory
# Copied United States/0079 to filtered directory
# Copied United States/1275 to filtered directory
# Copied United States/1490 to filtered directory
# Copied United States/4933 to filtered directory
# Copied United States/0096 to filtered directory
# Copied United States/4013 to filtered directory
# Copied United States/2892 to filtered directory
# Copied United States/0161 to filtered directory
# Copied United States/3931 to filtered directory
# Copied United States/2015 to filtered directory
# Copied United States/2752 to filtered directory
# Copied United States/1329 to filtered directory
# Copied United States/1604 to filtered directory
# Copied United States/0507 to filtered directory
# Copied United States/1706 to filtered directory
# Copied United States/0159 to filtered directory
# Copied United States/3475 to filtered directory
# Copied United States/1551 to filtered directory
# Copied United States/0164 to filtered directory
# Copied United States/1410 to filtered directory
# Copied United States/1918 to filtered directory
# Copied United States/0076 to filtered directory
# Copied United States/3627 to filtered directory
# Copied United States/0797 to filtered directory
# Copied United States/1920 to filtered directory
# Copied United States/1516 to filtered directory
# Copied United States/1195 to filtered directory
# Copied United States/1785 to filtered directory
# Copied United States/3851 to filtered directory
# Copied United States/1624 to filtered directory
# Copied United States/2394 to filtered directory
# Copied United States/2811 to filtered directory
# Copied United States/4741 to filtered directory
# Copied United States/4539 to filtered directory
# Copied United States/1030 to filtered directory
# Copied United States/2840 to filtered directory
# Copied United States/0612 to filtered directory
# Copied United States/2350 to filtered directory
# Copied United States/3499 to filtered directory
# Copied United States/4701 to filtered directory
# Copied United States/3855 to filtered directory
# Copied United States/2174 to filtered directory
# Copied United States/0183 to filtered directory
# Copied United States/2154 to filtered directory
# Copied United States/1480 to filtered directory
# Copied United States/1428 to filtered directory
# Copied United States/0306 to filtered directory
# Copied United States/2301 to filtered directory
# Copied United States/3388 to filtered directory
# Copied United States/0204 to filtered directory
# Copied United States/2149 to filtered directory
# Copied United States/0391 to filtered directory
# Copied United States/1135 to filtered directory
# Copied United States/4690 to filtered directory
# Copied United States/3035 to filtered directory
# Copied United States/2008 to filtered directory
# Copied United States/4159 to filtered directory
# Copied United States/1514 to filtered directory
# Copied United States/3652 to filtered directory
# Copied United States/2066 to filtered directory
# Copied United States/2421 to filtered directory
# Copied United States/2711 to filtered directory
# Copied United States/1379 to filtered directory
# Copied United States/1186 to filtered directory
# Copied United States/0259 to filtered directory
# Copied United States/4655 to filtered directory
# Copied United States/3998 to filtered directory
# Copied United States/1545 to filtered directory
# Copied United States/4547 to filtered directory
# Copied United States/4111 to filtered directory
# Copied United States/2307 to filtered directory
# Copied United States/4243 to filtered directory
# Copied United States/3195 to filtered directory
# Copied United States/2504 to filtered directory
# Copied United States/3703 to filtered directory
# Copied United States/4973 to filtered directory
# Copied United States/4584 to filtered directory
# Copied United States/3825 to filtered directory
# Copied United States/0763 to filtered directory
# Copied United States/0049 to filtered directory
# Copied United States/4680 to filtered directory
# Copied United States/2622 to filtered directory
# Copied United States/0824 to filtered directory
# Copied United States/4969 to filtered directory
# Copied United States/0165 to filtered directory
# Copied United States/0655 to filtered directory
# Copied United States/4328 to filtered directory
# Copied United States/0749 to filtered directory
# Copied United States/0862 to filtered directory
# Copied United States/1126 to filtered directory
# Copied United States/4861 to filtered directory
# Copied United States/4923 to filtered directory
# Copied United States/2493 to filtered directory
# Copied United States/0616 to filtered directory
# Copied United States/2276 to filtered directory
# Copied United States/1454 to filtered directory
# Copied United States/3932 to filtered directory
# Copied United States/4627 to filtered directory
# Copied United States/3290 to filtered directory
# Copied United States/0711 to filtered directory
# Copied United States/1108 to filtered directory
# Copied United States/1026 to filtered directory
# Copied United Kingdom/2507 to filtered directory
# Copied United Kingdom/0899 to filtered directory
# Copied United Kingdom/4612 to filtered directory
# Copied United Kingdom/4750 to filtered directory
# Copied United Kingdom/3910 to filtered directory
# Copied United Kingdom/4418 to filtered directory
# Copied United Kingdom/1486 to filtered directory
# Copied United Kingdom/0228 to filtered directory
# Copied United Kingdom/1274 to filtered directory
# Copied United Kingdom/1768 to filtered directory
# Copied United Kingdom/1786 to filtered directory
# Copied United Kingdom/3864 to filtered directory
# Copied United Kingdom/0977 to filtered directory
# Copied United Kingdom/3249 to filtered directory
# Copied United Kingdom/3226 to filtered directory
# Copied United Kingdom/2809 to filtered directory
# Copied United Kingdom/0535 to filtered directory
# Copied United Kingdom/2705 to filtered directory
# Copied United Kingdom/3077 to filtered directory
# Copied United Kingdom/1014 to filtered directory
# Copied United Kingdom/2399 to filtered directory
# Copied United Kingdom/3734 to filtered directory
# Copied United Kingdom/2699 to filtered directory
# Copied United Kingdom/3069 to filtered directory
# Copied United Kingdom/2415 to filtered directory
# Copied United Kingdom/2792 to filtered directory
# Copied United Kingdom/2640 to filtered directory
# Copied United Kingdom/4207 to filtered directory
# Copied United Kingdom/1602 to filtered directory
# Copied United Kingdom/3500 to filtered directory
# Copied United Kingdom/1687 to filtered directory
# Copied United Kingdom/1570 to filtered directory
# Copied United Kingdom/3980 to filtered directory
# Copied United Kingdom/1911 to filtered directory
# Copied United Kingdom/4003 to filtered directory
# Copied United Kingdom/1173 to filtered directory
# Copied United Kingdom/1927 to filtered directory
# Copied United Kingdom/3535 to filtered directory
# Copied United Kingdom/0700 to filtered directory
# Copied United Kingdom/4412 to filtered directory
# Copied United Kingdom/0099 to filtered directory
# Copied United Kingdom/3602 to filtered directory
# Copied United Kingdom/0171 to filtered directory
# Copied United Kingdom/3124 to filtered directory
# Copied United Kingdom/4459 to filtered directory
# Copied United Kingdom/0922 to filtered directory
# Copied United Kingdom/2380 to filtered directory
# Copied United Kingdom/4529 to filtered directory
# Copied United Kingdom/2828 to filtered directory
# Copied United Kingdom/1749 to filtered directory
# Copied United Kingdom/3175 to filtered directory
# Copied United Kingdom/1120 to filtered directory
# Copied United Kingdom/0712 to filtered directory
# Copied United Kingdom/3948 to filtered directory
# Copied United Kingdom/4259 to filtered directory
# Copied United Kingdom/2807 to filtered directory
# Copied United Kingdom/0525 to filtered directory
# Copied United Kingdom/2099 to filtered directory
# Copied United Kingdom/0415 to filtered directory
# Copied United Kingdom/0731 to filtered directory
# Copied United Kingdom/0314 to filtered directory
# Copied United Kingdom/2398 to filtered directory
# Copied United Kingdom/2440 to filtered directory
# Copied United Kingdom/4747 to filtered directory
# Copied United Kingdom/4353 to filtered directory
# Copied United Kingdom/3685 to filtered directory
# Copied United Kingdom/2369 to filtered directory
# Copied United Kingdom/4873 to filtered directory
# Copied United Kingdom/0450 to filtered directory
# Copied United Kingdom/2737 to filtered directory
# Copied United Kingdom/0830 to filtered directory
# Copied United Kingdom/1604 to filtered directory
# Copied United Kingdom/3177 to filtered directory
# Copied United Kingdom/3475 to filtered directory
# Copied United Kingdom/1410 to filtered directory
# Copied United Kingdom/1478 to filtered directory
# Copied United Kingdom/2510 to filtered directory
# Copied United Kingdom/4905 to filtered directory
# Copied United Kingdom/3262 to filtered directory
# Copied United Kingdom/0778 to filtered directory
# Copied United Kingdom/4619 to filtered directory
# Copied United Kingdom/2394 to filtered directory
# Copied United Kingdom/4065 to filtered directory
# Copied United Kingdom/0143 to filtered directory
# Copied United Kingdom/1013 to filtered directory
# Copied United Kingdom/2864 to filtered directory
# Copied United Kingdom/1681 to filtered directory
# Copied United Kingdom/4303 to filtered directory
# Copied United Kingdom/4008 to filtered directory
# Copied United Kingdom/3855 to filtered directory
# Copied United Kingdom/4226 to filtered directory
# Copied United Kingdom/2178 to filtered directory
# Copied United Kingdom/1480 to filtered directory
# Copied United Kingdom/1731 to filtered directory
# Copied United Kingdom/2303 to filtered directory
# Copied United Kingdom/1781 to filtered directory
# Copied United Kingdom/2280 to filtered directory
# Copied United Kingdom/3470 to filtered directory
# Copied United Kingdom/3847 to filtered directory
# Copied United Kingdom/1080 to filtered directory
# Copied United Kingdom/4477 to filtered directory
# Copied United Kingdom/4390 to filtered directory
# Copied United Kingdom/1454 to filtered directory
# Copied United Kingdom/0339 to filtered directory
# Copied United Kingdom/0711 to filtered directory
# Copied United Kingdom/1106 to filtered directory
# Copied United Kingdom/2353 to filtered directory
# Copied United Kingdom/4510 to filtered directory
# Copied United Kingdom/4779 to filtered directory
# Copied United Kingdom/0064 to filtered directory
# Copied United Kingdom/1376 to filtered directory
# Copied United Kingdom/2558 to filtered directory
# Copied United Kingdom/1754 to filtered directory
# Copied United Kingdom/3950 to filtered directory
# Copied United Kingdom/0015 to filtered directory
# Copied United Kingdom/2951 to filtered directory
# Copied United Kingdom/3036 to filtered directory
# Copied United Kingdom/4491 to filtered directory
# Copied United Kingdom/2238 to filtered directory
# Copied United Kingdom/3157 to filtered directory
# Copied United Kingdom/4575 to filtered directory
# Copied United Kingdom/1215 to filtered directory
# Copied United Kingdom/2022 to filtered directory
# Copied United Kingdom/1566 to filtered directory
# Copied United Kingdom/1301 to filtered directory
# Copied United Kingdom/0861 to filtered directory
# Copied United Kingdom/1587 to filtered directory
# Copied United Kingdom/3096 to filtered directory
# Copied United Kingdom/2738 to filtered directory
# Copied United Kingdom/2975 to filtered directory
# Copied United Kingdom/1783 to filtered directory
# Copied United Kingdom/4310 to filtered directory
# Copied United Kingdom/1872 to filtered directory
# Copied United Kingdom/1269 to filtered directory
# Copied United Kingdom/4458 to filtered directory
# Copied United Kingdom/1502 to filtered directory
# Copied United Kingdom/0640 to filtered directory
# Copied United Kingdom/0931 to filtered directory
# Copied United Kingdom/4666 to filtered directory
# Copied United Kingdom/2534 to filtered directory
# Copied United Kingdom/0633 to filtered directory
# Copied United Kingdom/2031 to filtered directory
# Copied United Kingdom/2259 to filtered directory
# Copied United Kingdom/2871 to filtered directory
# Copied United Kingdom/1547 to filtered directory
# Copied United Kingdom/3018 to filtered directory
# Copied United Kingdom/3055 to filtered directory
# Copied United Kingdom/1902 to filtered directory
# Copied United Kingdom/3592 to filtered directory
# Copied United Kingdom/0767 to filtered directory
# Copied United Kingdom/2780 to filtered directory
# Copied United Kingdom/2943 to filtered directory
# Copied United Kingdom/1598 to filtered directory
# Copied United Kingdom/1938 to filtered directory
# Copied United Kingdom/2599 to filtered directory
# Copied United Kingdom/3997 to filtered directory
# Copied United Kingdom/4631 to filtered directory
# Copied United Kingdom/1187 to filtered directory
# Copied United Kingdom/2334 to filtered directory
# Copied United Kingdom/4857 to filtered directory
# Copied United Kingdom/2320 to filtered directory
# Copied United Kingdom/1095 to filtered directory
# Copied United Kingdom/2902 to filtered directory
# Copied United Kingdom/1059 to filtered directory
# Copied United Kingdom/4816 to filtered directory
# Copied United Kingdom/3120 to filtered directory
# Copied United Kingdom/0201 to filtered directory
# Copied United Kingdom/0146 to filtered directory
# Copied United Kingdom/4189 to filtered directory
# Copied United Kingdom/1037 to filtered directory
# Copied United Kingdom/0724 to filtered directory
# Copied United Kingdom/1288 to filtered directory
# Copied United Kingdom/2996 to filtered directory
# Copied United Kingdom/2732 to filtered directory
# Copied United Kingdom/1716 to filtered directory
# Copied United Kingdom/1924 to filtered directory
# Copied United Kingdom/0991 to filtered directory
# Copied United Kingdom/1438 to filtered directory
# Copied United Kingdom/2322 to filtered directory
# Copied United Kingdom/2708 to filtered directory
# Copied United Kingdom/4020 to filtered directory
# Copied United Kingdom/4748 to filtered directory
# Copied United Kingdom/1460 to filtered directory
# Copied United Kingdom/3208 to filtered directory
# Copied United Kingdom/3206 to filtered directory
# Copied United Kingdom/1391 to filtered directory
# Copied United Kingdom/4242 to filtered directory
# Copied United Kingdom/4812 to filtered directory
# Copied United Kingdom/4044 to filtered directory
# Copied United Kingdom/4294 to filtered directory
# Copied United Kingdom/4456 to filtered directory
# Copied United Kingdom/2515 to filtered directory
# Copied United Kingdom/0419 to filtered directory
# Copied United Kingdom/4763 to filtered directory
# Copied United Kingdom/1398 to filtered directory
# Copied United Kingdom/3651 to filtered directory
# Copied United Kingdom/0949 to filtered directory
# Copied United Kingdom/4395 to filtered directory
# Copied United Kingdom/2345 to filtered directory
# Copied United Kingdom/0515 to filtered directory
# Copied United Kingdom/2338 to filtered directory
# Copied United Kingdom/0986 to filtered directory
# Copied United Kingdom/3336 to filtered directory
# Copied United Kingdom/1965 to filtered directory
# Copied United Kingdom/4082 to filtered directory
# Copied United Kingdom/1866 to filtered directory
# Copied United Kingdom/2442 to filtered directory
# Copied United Kingdom/4186 to filtered directory
# Copied United Kingdom/1224 to filtered directory
# Copied United Kingdom/3219 to filtered directory
# Copied United Kingdom/4527 to filtered directory
# Copied United Kingdom/1820 to filtered directory
# Copied United Kingdom/2687 to filtered directory
# Copied United Kingdom/4806 to filtered directory
# Copied United Kingdom/3741 to filtered directory
# Copied United Kingdom/4743 to filtered directory
# Copied United Kingdom/3928 to filtered directory
# Copied United Kingdom/0042 to filtered directory
# Copied United Kingdom/2634 to filtered directory
# Copied United Kingdom/1413 to filtered directory
# Copied United Kingdom/2142 to filtered directory
# Copied United Kingdom/3557 to filtered directory
# Copied United Kingdom/4941 to filtered directory
# Copied United Kingdom/2218 to filtered directory
# Copied United Kingdom/4120 to filtered directory
# Copied United Kingdom/0835 to filtered directory
# Copied United Kingdom/4074 to filtered directory
# Copied United Kingdom/1131 to filtered directory
# Copied United Kingdom/2414 to filtered directory
# Copied United Kingdom/4600 to filtered directory
# Copied United Kingdom/3105 to filtered directory
# Copied United Kingdom/2659 to filtered directory
# Copied United Kingdom/4622 to filtered directory
# Copied United Kingdom/2823 to filtered directory
# Copied United Kingdom/3885 to filtered directory
# Copied United Kingdom/3017 to filtered directory
# Copied United Kingdom/3867 to filtered directory
# Copied United Kingdom/1550 to filtered directory
# Copied United Kingdom/1075 to filtered directory
# Copied United Kingdom/4118 to filtered directory
# Copied United Kingdom/1673 to filtered directory
# Copied United Kingdom/1461 to filtered directory
# Copied United Kingdom/3650 to filtered directory
# Copied United Kingdom/4165 to filtered directory
# Copied United Kingdom/2635 to filtered directory
# Copied United Kingdom/3560 to filtered directory
# Copied United Kingdom/0891 to filtered directory
# Copied United Kingdom/3955 to filtered directory
# Copied United Kingdom/3799 to filtered directory
# Copied United Kingdom/1811 to filtered directory
# Copied United Kingdom/0652 to filtered directory
# Copied United Kingdom/3087 to filtered directory
# Copied United Kingdom/0029 to filtered directory
# Copied United Kingdom/4859 to filtered directory
# Copied United Kingdom/3112 to filtered directory
# Copied United Kingdom/0729 to filtered directory
# Copied United Kingdom/0878 to filtered directory
# Copied United Kingdom/1016 to filtered directory
# Copied United Kingdom/3245 to filtered directory
# Copied United Kingdom/0357 to filtered directory
# Copied United Kingdom/2652 to filtered directory
# Copied United Kingdom/0846 to filtered directory
# Copied United Kingdom/0194 to filtered directory
# Copied United Kingdom/2337 to filtered directory
# Copied United Kingdom/0680 to filtered directory
# Copied United Kingdom/0095 to filtered directory
# Copied United Kingdom/4862 to filtered directory
# Copied United Kingdom/0166 to filtered directory
# Copied United Kingdom/2791 to filtered directory
# Copied United Kingdom/3641 to filtered directory
# Copied United Kingdom/0492 to filtered directory
# Copied United Kingdom/4727 to filtered directory
# Copied United Kingdom/2246 to filtered directory
# Copied United Kingdom/4818 to filtered directory
# Copied United Kingdom/3622 to filtered directory
# Copied United Kingdom/4132 to filtered directory
# Copied United Kingdom/0135 to filtered directory
# Copied United Kingdom/0328 to filtered directory
# Copied United Kingdom/1470 to filtered directory
# Copied United Kingdom/3526 to filtered directory
# Copied United Kingdom/1945 to filtered directory
# Copied United Kingdom/3448 to filtered directory
# Copied United Kingdom/3649 to filtered directory
# Copied United Kingdom/0890 to filtered directory
# Copied United Kingdom/0995 to filtered directory
# Copied United Kingdom/3934 to filtered directory
# Copied United Kingdom/4886 to filtered directory
# Copied United Kingdom/2102 to filtered directory
# Copied United Kingdom/2882 to filtered directory
# Copied United Kingdom/0892 to filtered directory
# Copied United Kingdom/4955 to filtered directory
# Copied United Kingdom/3301 to filtered directory
# Copied United Kingdom/0973 to filtered directory
# Copied United Kingdom/2239 to filtered directory
# Copied United Kingdom/4324 to filtered directory
# Copied United Kingdom/3222 to filtered directory
# Copied United Kingdom/2576 to filtered directory
# Copied United Kingdom/0200 to filtered directory
# Copied United Kingdom/2171 to filtered directory
# Copied United Kingdom/3342 to filtered directory
# Copied United Kingdom/3752 to filtered directory
# Copied United Kingdom/0038 to filtered directory
# Copied United Kingdom/1491 to filtered directory
# Copied United Kingdom/0273 to filtered directory
# Copied United Kingdom/4062 to filtered directory
# Copied United Kingdom/3760 to filtered directory
# Copied United Kingdom/3507 to filtered directory
# Copied United Kingdom/0062 to filtered directory
# Copied United Kingdom/3328 to filtered directory
# Copied United Kingdom/0886 to filtered directory
# Copied United Kingdom/2157 to filtered directory
# Copied United Kingdom/3398 to filtered directory
# Copied United Kingdom/3064 to filtered directory
# Copied United Kingdom/2208 to filtered directory
# Copied United Kingdom/4032 to filtered directory
# Copied United Kingdom/3911 to filtered directory
# Copied United Kingdom/0955 to filtered directory
# Copied United Kingdom/1663 to filtered directory
# Copied United Kingdom/3907 to filtered directory
# Copied United Kingdom/0643 to filtered directory
# Copied United Kingdom/1185 to filtered directory
# Copied United Kingdom/2592 to filtered directory
# Copied United Kingdom/3944 to filtered directory
# Copied United Kingdom/4708 to filtered directory
# Copied United Kingdom/1699 to filtered directory
# Copied United Kingdom/0627 to filtered directory
# Copied United Kingdom/1555 to filtered directory
# Copied United Kingdom/4399 to filtered directory
# Copied United Kingdom/3519 to filtered directory
# Copied United Kingdom/3450 to filtered directory
# Copied United Kingdom/3715 to filtered directory
# Copied United Kingdom/1399 to filtered directory
# Copied United Kingdom/3452 to filtered directory
# Copied United Kingdom/2366 to filtered directory
# Copied United Kingdom/0511 to filtered directory
# Copied United Kingdom/2601 to filtered directory
# Copied United Kingdom/2665 to filtered directory
# Copied United Kingdom/3837 to filtered directory
# Copied United Kingdom/3696 to filtered directory
# Copied United Kingdom/4009 to filtered directory
# Copied United Kingdom/3615 to filtered directory
# Copied United Kingdom/2422 to filtered directory
# Copied United Kingdom/1314 to filtered directory
# Copied United Kingdom/2181 to filtered directory
# Copied United Kingdom/3815 to filtered directory
# Copied United Kingdom/0871 to filtered directory
# Copied United Kingdom/2229 to filtered directory
# Copied United Kingdom/3929 to filtered directory
# Copied United Kingdom/3879 to filtered directory
# Copied United Kingdom/1226 to filtered directory
# Copied United Kingdom/3254 to filtered directory
# Copied United Kingdom/2872 to filtered directory
# Copied United Kingdom/2663 to filtered directory
# Copied United Kingdom/0040 to filtered directory
# Copied United Kingdom/0214 to filtered directory
# Copied United Kingdom/1082 to filtered directory
# Copied United Kingdom/3966 to filtered directory
# Copied United Kingdom/3361 to filtered directory
# Copied United Kingdom/2717 to filtered directory
# Copied United Kingdom/4992 to filtered directory
# Copied United Kingdom/1691 to filtered directory
# Copied United Kingdom/0473 to filtered directory
# Copied United Kingdom/2400 to filtered directory
# Copied United Kingdom/0557 to filtered directory
# Copied United Kingdom/1500 to filtered directory
# Copied United Kingdom/2559 to filtered directory
# Copied United Kingdom/2305 to filtered directory
# Copied United Kingdom/2894 to filtered directory
# Copied United Kingdom/0113 to filtered directory
# Copied United Kingdom/2245 to filtered directory
# Copied United Kingdom/1928 to filtered directory
# Copied United Kingdom/3202 to filtered directory
# Copied United Kingdom/0184 to filtered directory
# Copied United Kingdom/4241 to filtered directory
# Copied United Kingdom/2555 to filtered directory
# Copied United Kingdom/1987 to filtered directory
# Copied United Kingdom/3717 to filtered directory
# Copied United Kingdom/3887 to filtered directory
# Copied United Kingdom/2827 to filtered directory
# Copied United Kingdom/1465 to filtered directory
# Copied United Kingdom/3439 to filtered directory
# Copied United Kingdom/4573 to filtered directory
# Copied United Kingdom/0699 to filtered directory
# Copied United Kingdom/2735 to filtered directory
# Copied United Kingdom/1086 to filtered directory
# Copied United Kingdom/0052 to filtered directory
# Copied United Kingdom/2837 to filtered directory
# Copied United Kingdom/0338 to filtered directory
# Copied United Kingdom/2159 to filtered directory
# Copied United Kingdom/4264 to filtered directory
# Copied United Kingdom/1174 to filtered directory
# Copied United Kingdom/3224 to filtered directory
# Copied United Kingdom/4914 to filtered directory
# Copied United Kingdom/2528 to filtered directory
# Copied United Kingdom/3747 to filtered directory
# Copied United Kingdom/2804 to filtered directory
# Copied United Kingdom/4888 to filtered directory
# Copied United Kingdom/2260 to filtered directory
# Copied United Kingdom/3701 to filtered directory
# Copied United Kingdom/3003 to filtered directory
# Copied United Kingdom/2310 to filtered directory
# Copied United Kingdom/2055 to filtered directory
# Copied United Kingdom/3427 to filtered directory
# Copied United Kingdom/2113 to filtered directory
# Copied United Kingdom/4735 to filtered directory
# Copied United Kingdom/4991 to filtered directory
# Copied United Kingdom/1970 to filtered directory
# Copied United Kingdom/1804 to filtered directory
# Copied United Kingdom/1321 to filtered directory
# Copied United Kingdom/1393 to filtered directory
# Copied United Kingdom/2062 to filtered directory
# Copied United Kingdom/1350 to filtered directory
# Copied United Kingdom/4829 to filtered directory
# Copied United Kingdom/0105 to filtered directory
# Copied United Kingdom/0017 to filtered directory
# Copied United Kingdom/2790 to filtered directory
# Copied United Kingdom/1326 to filtered directory
# Copied United Kingdom/1051 to filtered directory
# Copied United Kingdom/3536 to filtered directory
# Copied United Kingdom/3302 to filtered directory
# Copied United Kingdom/2148 to filtered directory
# Copied United Kingdom/2285 to filtered directory
# Copied United Kingdom/4288 to filtered directory
# Copied United Kingdom/1286 to filtered directory
# Copied United Kingdom/0854 to filtered directory
# Copied United Kingdom/1584 to filtered directory
# Copied United Kingdom/3186 to filtered directory
# Copied United Kingdom/3281 to filtered directory
# Copied United Kingdom/3166 to filtered directory
# Copied United Kingdom/4187 to filtered directory
# Copied United Kingdom/3387 to filtered directory
# Copied United Kingdom/2851 to filtered directory
# Copied United Kingdom/3891 to filtered directory
# Copied United Kingdom/2584 to filtered directory
# Copied United Kingdom/4866 to filtered directory
# Copied United Kingdom/3633 to filtered directory
# Copied United Kingdom/4555 to filtered directory
# Copied United Kingdom/2053 to filtered directory
# Copied United Kingdom/0149 to filtered directory
# Copied United Kingdom/1018 to filtered directory
# Copied United Kingdom/4596 to filtered directory
# Copied United Kingdom/0875 to filtered directory
# Copied United Kingdom/3095 to filtered directory
# Copied United Kingdom/4756 to filtered directory
# Copied United Kingdom/2109 to filtered directory
# Copied United Kingdom/0674 to filtered directory
# Copied United Kingdom/3349 to filtered directory
# Copied United Kingdom/2581 to filtered directory
# Copied United Kingdom/2931 to filtered directory
# Copied United Kingdom/2068 to filtered directory
# Copied New Zealand/0329 to filtered directory
# Copied New Zealand/0955 to filtered directory
# Copied New Zealand/0366 to filtered directory
# Copied New Zealand/0192 to filtered directory
# Copied New Zealand/0830 to filtered directory
# Copied New Zealand/1681 to filtered directory
# Copied New Zealand/1677 to filtered directory
# Copied New Zealand/1126 to filtered directory
# Copied New Zealand/0822 to filtered directory
# Copied New Zealand/0364 to filtered directory
# Copied New Zealand/0257 to filtered directory
# Copied New Zealand/1227 to filtered directory
# Copied New Zealand/0325 to filtered directory
# Copied New Zealand/0023 to filtered directory
# Copied New Zealand/0725 to filtered directory
# Copied New Zealand/1311 to filtered directory
# Copied New Zealand/0493 to filtered directory
# Copied New Zealand/0714 to filtered directory
# Copied New Zealand/0874 to filtered directory
# Copied New Zealand/0542 to filtered directory
# Copied New Zealand/1232 to filtered directory
# Copied New Zealand/1111 to filtered directory
# Copied New Zealand/1089 to filtered directory
# Copied New Zealand/0925 to filtered directory
# Copied New Zealand/0769 to filtered directory
# Copied New Zealand/0292 to filtered directory
# Copied New Zealand/1536 to filtered directory
# Copied New Zealand/1680 to filtered directory
# Copied New Zealand/0348 to filtered directory
# Copied New Zealand/0753 to filtered directory
# Copied New Zealand/0528 to filtered directory
# Copied New Zealand/0195 to filtered directory
# Copied New Zealand/1016 to filtered directory
# Copied New Zealand/0686 to filtered directory
# Copied New Zealand/0765 to filtered directory
# Copied New Zealand/1445 to filtered directory
# Copied New Zealand/0089 to filtered directory
# Copied New Zealand/1091 to filtered directory
# Copied New Zealand/0235 to filtered directory
# Copied New Zealand/0050 to filtered directory
# Copied New Zealand/0177 to filtered directory
# Copied New Zealand/0062 to filtered directory
# Copied New Zealand/0386 to filtered directory
# Copied New Zealand/1511 to filtered directory
# Copied New Zealand/1492 to filtered directory
# Copied New Zealand/1647 to filtered directory
# Copied New Zealand/1174 to filtered directory
# Copied New Zealand/0823 to filtered directory
# Copied New Zealand/0136 to filtered directory
# Copied New Zealand/0220 to filtered directory
# Copied New Zealand/0424 to filtered directory
# Copied New Zealand/1021 to filtered directory
# Copied New Zealand/1321 to filtered directory
# Copied New Zealand/0713 to filtered directory
# Copied New Zealand/1406 to filtered directory
# Copied New Zealand/1058 to filtered directory
# Copied New Zealand/0733 to filtered directory
# Copied New Zealand/0929 to filtered directory
# Copied New Zealand/0452 to filtered directory
# Copied New Zealand/0075 to filtered directory
# Copied New Zealand/0335 to filtered directory
# Copied New Zealand/0658 to filtered directory
# Copied New Zealand/0978 to filtered directory
# Copied New Zealand/0460 to filtered directory
# Copied New Zealand/0533 to filtered directory
# Copied New Zealand/1133 to filtered directory
# Copied New Zealand/1415 to filtered directory
# Copied New Zealand/0074 to filtered directory
# Copied New Zealand/0103 to filtered directory
# Copied New Zealand/0307 to filtered directory
# Copied New Zealand/0704 to filtered directory
# Copied New Zealand/0449 to filtered directory
# Copied New Zealand/0716 to filtered directory
# Copied New Zealand/0692 to filtered directory
# Copied New Zealand/0797 to filtered directory
# Copied New Zealand/0693 to filtered directory
# Copied New Zealand/0299 to filtered directory
# Copied New Zealand/0580 to filtered directory
# Copied New Zealand/0607 to filtered directory
# Copied New Zealand/0229 to filtered directory
# Copied New Zealand/0233 to filtered directory
# Copied New Zealand/1081 to filtered directory
# Copied New Zealand/0669 to filtered directory
# Copied New Zealand/1545 to filtered directory
# Copied New Zealand/1360 to filtered directory
# Copied New Zealand/0279 to filtered directory
# Copied New Zealand/0657 to filtered directory
# Copied New Zealand/1537 to filtered directory
# Copied New Zealand/0935 to filtered directory
# Copied New Zealand/1106 to filtered directory
# Copied New Zealand/0193 to filtered directory
# Copied New Zealand/0119 to filtered directory
# Copied New Zealand/0387 to filtered directory
# Copied New Zealand/0313 to filtered directory
# ...
# Copied New Zealand/0225 to filtered directory
# Copied New Zealand/0410 to filtered directory
# Copied New Zealand/0560 to filtered directory
# Copied New Zealand/0115 to filtered directory
# Copied New Zealand/0740 to filtered directory
# Copied New Zealand/0567 to filtered directory
# Copied New Zealand/1025 to filtered directory
# Copied New Zealand/1648 to filtered directory
# Copied New Zealand/0719 to filtered directory
# Copied New Zealand/1512 to filtered directory
# Copied New Zealand/0532 to filtered directory
# Copied New Zealand/1274 to filtered directory
# Copied New Zealand/0300 to filtered directory
# Copied New Zealand/1678 to filtered directory
# Copied New Zealand/1400 to filtered directory
# Copied New Zealand/0743 to filtered directory
# Copied New Zealand/0569 to filtered directory
# Copied New Zealand/0006 to filtered directory
# Copied New Zealand/0960 to filtered directory
# Copied New Zealand/0440 to filtered directory
# Copied New Zealand/0467 to filtered directory
# Copied New Zealand/1203 to filtered directory
# Copied New Zealand/1095 to filtered directory
# Copied New Zealand/0747 to filtered directory
# Copied New Zealand/0132 to filtered directory
# Copied New Zealand/0898 to filtered directory
# Copied New Zealand/1059 to filtered directory
# Copied New Zealand/0291 to filtered directory
# Copied New Zealand/0801 to filtered directory
# Copied New Zealand/0118 to filtered directory
# Copied New Zealand/1284 to filtered directory
# Copied New Zealand/0294 to filtered directory
# Copied New Zealand/1001 to filtered directory
# Copied New Zealand/0947 to filtered directory
# Copied New Zealand/1621 to filtered directory
# Copied New Zealand/1288 to filtered directory
# Copied New Zealand/1447 to filtered directory
# Copied New Zealand/0121 to filtered directory
# Copied New Zealand/1496 to filtered directory
# Copied New Zealand/0675 to filtered directory
# Copied New Zealand/0628 to filtered directory
# Copied New Zealand/0175 to filtered directory
# Copied New Zealand/0323 to filtered directory
# Copied New Zealand/0185 to filtered directory
# Copied New Zealand/1408 to filtered directory
# Copied New Zealand/1048 to filtered directory
# Copied New Zealand/0566 to filtered directory
# Copied New Zealand/0016 to filtered directory
# Copied New Zealand/0739 to filtered directory
# Copied New Zealand/0808 to filtered directory
# Copied New Zealand/0396 to filtered directory
# Copied New Zealand/0356 to filtered directory
# Copied New Zealand/0368 to filtered directory
# Copied New Zealand/0057 to filtered directory
# Copied New Zealand/0377 to filtered directory
# Copied New Zealand/0078 to filtered directory
# Copied New Zealand/0709 to filtered directory
# Copied New Zealand/0752 to filtered directory
# Copied New Zealand/0645 to filtered directory
# Copied New Zealand/1542 to filtered directory
# Copied New Zealand/1449 to filtered directory
# Copied New Zealand/0701 to filtered directory
# Copied New Zealand/0910 to filtered directory
# Copied New Zealand/1172 to filtered directory
# Copied New Zealand/1401 to filtered directory
# Copied New Zealand/0092 to filtered directory
# Copied New Zealand/1686 to filtered directory
# Copied New Zealand/0535 to filtered directory
# Copied New Zealand/0212 to filtered directory
# Copied New Zealand/1050 to filtered directory
# Copied New Zealand/0835 to filtered directory
# Copied New Zealand/1131 to filtered directory
# Copied New Zealand/0950 to filtered directory
# Copied New Zealand/0027 to filtered directory
# Copied New Zealand/1595 to filtered directory
# Copied New Zealand/0588 to filtered directory
# Copied New Zealand/1075 to filtered directory
# Copied New Zealand/1546 to filtered directory
# Copied New Zealand/0058 to filtered directory
# Copied New Zealand/1461 to filtered directory
# Copied New Zealand/0352 to filtered directory
# Copied New Zealand/0620 to filtered directory
# Copied New Zealand/1640 to filtered directory
# Copied New Zealand/0392 to filtered directory
# Copied New Zealand/0596 to filtered directory
# Copied New Zealand/0219 to filtered directory
# Copied New Zealand/1642 to filtered directory
# Copied New Zealand/1039 to filtered directory
# Copied New Zealand/0652 to filtered directory
# Copied New Zealand/0632 to filtered directory
# Copied New Zealand/0029 to filtered directory
# Copied New Zealand/0077 to filtered directory
# Copied New Zealand/0878 to filtered directory
# Copied New Zealand/1137 to filtered directory
# Copied New Zealand/0357 to filtered directory
# Copied New Zealand/1652 to filtered directory
# Copied New Zealand/0846 to filtered directory
# Copied New Zealand/1588 to filtered directory
# Copied New Zealand/0095 to filtered directory
# Copied New Zealand/0454 to filtered directory
# Copied New Zealand/0166 to filtered directory
# Copied New Zealand/0492 to filtered directory
# Copied New Zealand/0296 to filtered directory
# Copied New Zealand/0779 to filtered directory
# Copied New Zealand/0626 to filtered directory
# Copied New Zealand/1470 to filtered directory
# Copied New Zealand/1464 to filtered directory
# Copied New Zealand/1064 to filtered directory
# Copied New Zealand/0308 to filtered directory
# Copied New Zealand/0807 to filtered directory
# Copied New Zealand/0896 to filtered directory
# Copied New Zealand/0173 to filtered directory
# Copied New Zealand/0502 to filtered directory
# Copied New Zealand/0995 to filtered directory
# Copied New Zealand/0989 to filtered directory
# Copied New Zealand/1457 to filtered directory
# Copied New Zealand/1608 to filtered directory
# Copied New Zealand/1245 to filtered directory
# Copied New Zealand/1602 to filtered directory
# Copied New Zealand/0892 to filtered directory
# Copied New Zealand/0715 to filtered directory
# Copied New Zealand/1570 to filtered directory
# Copied New Zealand/0216 to filtered directory
# Copied New Zealand/0408 to filtered directory
# Copied New Zealand/0404 to filtered directory
# Copied New Zealand/0267 to filtered directory
# Copied New Zealand/0169 to filtered directory
# Copied New Zealand/0038 to filtered directory
# Copied New Zealand/0665 to filtered directory
# Copied New Zealand/0780 to filtered directory
# Copied New Zealand/0196 to filtered directory
# Copied New Zealand/1173 to filtered directory
# Copied New Zealand/0751 to filtered directory
# Copied New Zealand/1560 to filtered directory
# Copied New Zealand/1190 to filtered directory
# Copied New Zealand/0263 to filtered directory
# Copied New Zealand/1491 to filtered directory
# Copied New Zealand/0273 to filtered directory
# Copied New Zealand/0601 to filtered directory
# Copied New Zealand/0886 to filtered directory
# Copied New Zealand/1249 to filtered directory
# Copied New Zealand/1663 to filtered directory
# Copied New Zealand/0287 to filtered directory
# Copied New Zealand/0434 to filtered directory
# Copied New Zealand/0970 to filtered directory
# Copied New Zealand/1040 to filtered directory
# Copied New Zealand/1374 to filtered directory
# Copied New Zealand/0513 to filtered directory
# Copied New Zealand/0511 to filtered directory
# Copied New Zealand/1507 to filtered directory
# Copied New Zealand/0771 to filtered directory
# Copied New Zealand/0904 to filtered directory
# Copied New Zealand/0160 to filtered directory
# Copied New Zealand/0321 to filtered directory
# Copied New Zealand/0798 to filtered directory
# Copied New Zealand/0871 to filtered directory
# Copied New Zealand/0899 to filtered directory
# Copied New Zealand/0172 to filtered directory
# Copied New Zealand/1226 to filtered directory
# Copied New Zealand/0327 to filtered directory
# Copied New Zealand/0040 to filtered directory
# Copied New Zealand/0009 to filtered directory
# Copied New Zealand/1082 to filtered directory
# Copied New Zealand/0635 to filtered directory
# Copied New Zealand/1144 to filtered directory
# Copied New Zealand/0191 to filtered directory
# Copied New Zealand/0355 to filtered directory
# Copied New Zealand/0250 to filtered directory
# Copied New Zealand/0441 to filtered directory
# Copied New Zealand/0868 to filtered directory
# Copied New Zealand/0872 to filtered directory
# Copied New Zealand/0611 to filtered directory
# Copied New Zealand/0557 to filtered directory
# Copied New Zealand/1500 to filtered directory
# Copied New Zealand/0448 to filtered directory
# Copied New Zealand/0539 to filtered directory
# Copied New Zealand/0065 to filtered directory
# Copied New Zealand/0639 to filtered directory
# Copied New Zealand/1230 to filtered directory
# Copied New Zealand/0695 to filtered directory
# Copied New Zealand/0026 to filtered directory
# Copied New Zealand/0276 to filtered directory
# Copied New Zealand/0376 to filtered directory
# Copied New Zealand/0842 to filtered directory
# Copied New Zealand/0927 to filtered directory
# Copied New Zealand/0699 to filtered directory
# Copied New Zealand/0005 to filtered directory
# Copied New Zealand/0247 to filtered directory
# Copied New Zealand/1418 to filtered directory
# Copied New Zealand/1411 to filtered directory
# Copied New Zealand/1309 to filtered directory
# Copied New Zealand/0178 to filtered directory
# Copied New Zealand/0570 to filtered directory
# Copied New Zealand/0226 to filtered directory
# Copied New Zealand/0852 to filtered directory
# Copied New Zealand/0275 to filtered directory
# Copied New Zealand/1476 to filtered directory
# Copied New Zealand/0812 to filtered directory
# Copied New Zealand/1600 to filtered directory
# Copied New Zealand/1467 to filtered directory
# Copied New Zealand/0712 to filtered directory
# Copied New Zealand/0369 to filtered directory
# Copied New Zealand/1548 to filtered directory
# Copied New Zealand/0468 to filtered directory
# Copied New Zealand/0499 to filtered directory
# Copied New Zealand/0783 to filtered directory
# Copied New Zealand/1639 to filtered directory
# Copied New Zealand/0105 to filtered directory
# Copied New Zealand/0525 to filtered directory
# Copied New Zealand/1051 to filtered directory
# Copied New Zealand/1316 to filtered directory
# Copied New Zealand/0393 to filtered directory
# Copied New Zealand/1541 to filtered directory
# Copied New Zealand/0223 to filtered directory
# Copied New Zealand/0266 to filtered directory
# Copied New Zealand/0889 to filtered directory
# Copied New Zealand/0302 to filtered directory
# Copied New Zealand/0415 to filtered directory
# Copied New Zealand/1472 to filtered directory
# Copied New Zealand/1279 to filtered directory
# Copied New Zealand/0809 to filtered directory
# Copied New Zealand/1344 to filtered directory
# Copied New Zealand/1416 to filtered directory
# Copied New Zealand/0149 to filtered directory
# Copied New Zealand/0731 to filtered directory
# Copied New Zealand/1018 to filtered directory
# Copied New Zealand/0875 to filtered directory
# Copied New Zealand/1585 to filtered directory
# Copied New Zealand/1458 to filtered directory
# Copied New Zealand/0314 to filtered directory
# Copied New Zealand/1136 to filtered directory
# Copied New Zealand/1180 to filtered directory
# Copied New Zealand/1641 to filtered directory
# Copied New Zealand/0145 to filtered directory
# Copied New Zealand/1593 to filtered directory
# Copied New Zealand/0334 to filtered directory
# Copied New Zealand/0938 to filtered directory
# Copied New Zealand/0477 to filtered directory
# Copied New Zealand/0340 to filtered directory
# Copied New Zealand/0552 to filtered directory
# Copied New Zealand/0375 to filtered directory
# Copied New Zealand/0206 to filtered directory
# Copied New Zealand/0981 to filtered directory
# Copied New Zealand/0003 to filtered directory
# Copied New Zealand/0186 to filtered directory
# Copied New Zealand/1667 to filtered directory
# Copied New Zealand/0432 to filtered directory
# Copied New Zealand/1024 to filtered directory
# Copied New Zealand/1069 to filtered directory
# Copied New Zealand/0696 to filtered directory
# Copied New Zealand/1688 to filtered directory
# Copied New Zealand/1336 to filtered directory
# Copied New Zealand/0100 to filtered directory
# Copied New Zealand/0757 to filtered directory
# Copied New Zealand/0544 to filtered directory
# Copied New Zealand/0514 to filtered directory
# Copied New Zealand/0945 to filtered directory
# Copied New Zealand/0130 to filtered directory
# Copied New Zealand/0916 to filtered directory
# Copied New Zealand/0374 to filtered directory
# Copied New Zealand/0072 to filtered directory
# Copied New Zealand/0821 to filtered directory
# Copied New Zealand/1665 to filtered directory
# Copied New Zealand/1352 to filtered directory
# Copied New Zealand/0262 to filtered directory
# Copied New Zealand/0450 to filtered directory
# Copied New Zealand/1493 to filtered directory
# Copied New Zealand/0677 to filtered directory
# Copied New Zealand/1240 to filtered directory
# Copied New Zealand/0310 to filtered directory
# Copied New Zealand/1046 to filtered directory
# Copied New Zealand/0382 to filtered directory
# Copied New Zealand/0079 to filtered directory
# Copied New Zealand/1241 to filtered directory
# Copied New Zealand/1275 to filtered directory
# Copied New Zealand/0799 to filtered directory
# Copied New Zealand/1420 to filtered directory
# Copied New Zealand/1554 to filtered directory
# Copied New Zealand/0286 to filtered directory
# Copied New Zealand/0787 to filtered directory
# Copied New Zealand/1199 to filtered directory
# Copied New Zealand/0455 to filtered directory
# Copied New Zealand/0571 to filtered directory
# Copied New Zealand/0161 to filtered directory
# Copied New Zealand/0198 to filtered directory
# Copied New Zealand/1166 to filtered directory
# Copied New Zealand/0330 to filtered directory
# Copied New Zealand/0838 to filtered directory
# Copied New Zealand/0420 to filtered directory
# Copied New Zealand/0116 to filtered directory
# Copied New Zealand/0507 to filtered directory
# Copied New Zealand/0593 to filtered directory
# Copied New Zealand/0475 to filtered directory
# Copied New Zealand/0085 to filtered directory
# Copied New Zealand/0164 to filtered directory
# Copied New Zealand/0661 to filtered directory
# Copied New Zealand/1251 to filtered directory
# Copied New Zealand/1410 to filtered directory
# Copied New Zealand/1448 to filtered directory
# Copied New Zealand/1478 to filtered directory
# Copied New Zealand/1674 to filtered directory
# Copied New Zealand/1118 to filtered directory
# Copied New Zealand/1469 to filtered directory
# Copied New Zealand/0378 to filtered directory
# Copied New Zealand/0717 to filtered directory
# Copied New Zealand/0637 to filtered directory
# Copied New Zealand/0721 to filtered directory
# Copied New Zealand/0634 to filtered directory
# Copied New Zealand/0053 to filtered directory
# Copied New Zealand/0342 to filtered directory
# Copied New Zealand/0907 to filtered directory
# Copied New Zealand/0097 to filtered directory
# Copied New Zealand/0011 to filtered directory
# Copied New Zealand/1592 to filtered directory
# Copied New Zealand/0589 to filtered directory
# Copied New Zealand/1030 to filtered directory
# Copied New Zealand/1335 to filtered directory
# Copied New Zealand/1127 to filtered directory
# Copied New Zealand/0820 to filtered directory
# Copied New Zealand/1000 to filtered directory
# Copied New Zealand/0073 to filtered directory
# Copied New Zealand/0242 to filtered directory
# Copied New Zealand/0746 to filtered directory
# Copied New Zealand/0612 to filtered directory
# Copied New Zealand/0102 to filtered directory
# Copied New Zealand/0811 to filtered directory
# Copied New Zealand/0170 to filtered directory
# Copied New Zealand/1103 to filtered directory
# Copied New Zealand/0399 to filtered directory
# Copied New Zealand/1125 to filtered directory
# Copied New Zealand/0934 to filtered directory
# Copied New Zealand/1649 to filtered directory
# Copied New Zealand/1112 to filtered directory
# Copied New Zealand/0482 to filtered directory
# Copied New Zealand/1109 to filtered directory
# Copied New Zealand/0183 to filtered directory
# Copied New Zealand/0158 to filtered directory
# Copied New Zealand/1116 to filtered directory
# Copied New Zealand/0985 to filtered directory
# Copied New Zealand/0204 to filtered directory
# Copied New Zealand/0951 to filtered directory
# Copied New Zealand/1169 to filtered directory
# Copied New Zealand/1041 to filtered directory
# Copied New Zealand/0668 to filtered directory
# Copied New Zealand/1038 to filtered directory
#
# Filtered images have been saved to: /home/andreafabbricatore/rainbot/pre_processing/segmented/filtered_images

# %%
import os
import shutil
import random
from pathlib import Path

# Set random seed for reproducibility
random.seed(42)

# Define split ratios
TRAIN_RATIO = 0.8
TEST_RATIO = 0.1
VAL_RATIO = 0.1

filtered_dir = "/home/andreafabbricatore/rainbot/pre_processing/datasets/extra_data/filtered_images"
# Create train, test, and val directories
for split in ['train', 'test', 'val']:
    split_dir = os.path.join(filtered_dir, split)
    os.makedirs(split_dir, exist_ok=True)

# Process each country
for country in os.listdir(filtered_dir):
    country_path = os.path.join(filtered_dir, country)
    
    # Skip if not a directory or if it's one of our split directories
    if not os.path.isdir(country_path) or country in ['train', 'test', 'val']:
        continue
    
    # Get all images for this country
    images = [f for f in os.listdir(country_path) if f.endswith(('.jpg', '.jpeg', '.png'))]
    random.shuffle(images)
    
    # Calculate split indices
    n_images = len(images)
    train_end = int(n_images * TRAIN_RATIO)
    test_end = train_end + int(n_images * TEST_RATIO)
    
    # Split images
    train_images = images[:train_end]
    test_images = images[train_end:test_end]
    val_images = images[test_end:]
    
    # Create country subdirectories in each split
    for split in ['train', 'test', 'val']:
        country_split_dir = os.path.join(filtered_dir, split, country)
        os.makedirs(country_split_dir, exist_ok=True)
    
    # Copy images to their respective split directories
    for img_list, split in [(train_images, 'train'), (test_images, 'test'), (val_images, 'val')]:
        for img in img_list:
            src = os.path.join(country_path, img)
            dst = os.path.join(filtered_dir, split, country, img)
            shutil.copy2(src, dst)
    
    print(f"Processed {country}: {len(train_images)} train, {len(test_images)} test, {len(val_images)} val images")

print("\nDataset split complete!")
